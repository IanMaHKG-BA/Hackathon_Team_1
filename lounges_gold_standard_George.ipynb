# %% [markdown]
# ## Connect to ICW:

# %%
import cadspy

# %%
username = str(input('User number'))
icw = cadspy.DatabaseConnection(system='ICW', user=username)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\engine\base.py", line 3361, in _wrap_pool_connect
#     return fn()
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\impl.py", line 382, in connect
#     return _ConnectionFairy._checkout(self, self._fairy)
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py", line 894, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py", line 493, in checkout
#     rec = pool._do_get()
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\impl.py", line 364, in _do_get
#     c = self._create_connection()
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py", line 273, in _create_connection
#     return _ConnectionRecord(self)
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py", line 388, in __init__
#     self.__connect()
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py", line 691, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\util\langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\util\compat.py", line 211, in raise_
#     raise exception
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py", line 686, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\engine\create.py", line 578, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\engine\default.py", line 598, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\teradatasql\__init__.py", line 188, in __init__
#     raise OperationalError(sErr)
# teradatasql.OperationalError: [Version 17.20.0.31] [Session 0] [Teradata SQL Driver] [Error 545] LDAP logon mechanism requires username and password, or logdata
#  at gosqldriver/teradatasql.formatError ErrorUtil.go:89
#  at gosqldriver/teradatasql.(*teradataConnection).makeDriverErrorCode ErrorUtil.go:199
#  at gosqldriver/teradatasql.newTeradataConnection TeradataConnection.go:315
#  at gosqldriver/teradatasql.(*teradataDriver).Open TeradataDriver.go:32
#  at database/sql.dsnConnector.Connect sql.go:759
#  at database/sql.(*DB).conn sql.go:1393
#  at database/sql.(*DB).Conn sql.go:1926
#  at main.goCreateConnection goside.go:298
#  at _cgoexp_2fd0e7537524_goCreateConnection _cgo_gotypes.go:263
#  at runtime.cgocallbackg1 cgocall.go:316
#  at runtime.cgocallbackg cgocall.go:235
#  at runtime.cgocallback asm_amd64.s:994
#  at runtime.goexit asm_amd64.s:1594
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\cadspy\database.py", line 119, in __init__
#     with self as conn: #pylint: disable=unused-variable
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\cadspy\database.py", line 251, in __enter__
#     self.__conn = self.connect()
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\cadspy\database.py", line 172, in connect
#     return self.connect()
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\cadspy\database.py", line 148, in connect
#     return self.engine.raw_connection()
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\engine\base.py", line 3394, in raw_connection
#     return self._wrap_pool_connect(self.pool.connect, _connection)
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\engine\base.py", line 3365, in _wrap_pool_connect
#     e, dialect, self
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\engine\base.py", line 2199, in _handle_dbapi_exception_noconnection
#     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\util\compat.py", line 211, in raise_
#     raise exception
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\engine\base.py", line 3361, in _wrap_pool_connect
#     return fn()
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\impl.py", line 382, in connect
#     return _ConnectionFairy._checkout(self, self._fairy)
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py", line 894, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py", line 493, in checkout
#     rec = pool._do_get()
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\impl.py", line 364, in _do_get
#     c = self._create_connection()
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py", line 273, in _create_connection
#     return _ConnectionRecord(self)
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py", line 388, in __init__
#     self.__connect()
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py", line 691, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\util\langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\util\compat.py", line 211, in raise_
#     raise exception
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py", line 686, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\engine\create.py", line 578, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\engine\default.py", line 598, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\teradatasql\__init__.py", line 188, in __init__
#     raise OperationalError(sErr)
# sqlalchemy.exc.OperationalError: (teradatasql.OperationalError) [Version 17.20.0.31] [Session 0] [Teradata SQL Driver] [Error 545] LDAP logon mechanism requires username and password, or logdata
#  at gosqldriver/teradatasql.formatError ErrorUtil.go:89
#  at gosqldriver/teradatasql.(*teradataConnection).makeDriverErrorCode ErrorUtil.go:199
#  at gosqldriver/teradatasql.newTeradataConnection TeradataConnection.go:315
#  at gosqldriver/teradatasql.(*teradataDriver).Open TeradataDriver.go:32
#  at database/sql.dsnConnector.Connect sql.go:759
#  at database/sql.(*DB).conn sql.go:1393
#  at database/sql.(*DB).Conn sql.go:1926
#  at main.goCreateConnection goside.go:298
#  at _cgoexp_2fd0e7537524_goCreateConnection _cgo_gotypes.go:263
#  at runtime.cgocallbackg1 cgocall.go:316
#  at runtime.cgocallbackg cgocall.go:235
#  at runtime.cgocallback asm_amd64.s:994
#  at runtime.goexit asm_amd64.s:1594
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Anaconda3\lib\logging\__init__.py", line 983, in emit
#     msg = self.format(record)
#   File "c:\Anaconda3\lib\logging\__init__.py", line 829, in format
#     return fmt.format(record)
#   File "c:\Anaconda3\lib\logging\__init__.py", line 569, in format
#     record.message = record.getMessage()
#   File "c:\Anaconda3\lib\logging\__init__.py", line 331, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "c:\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "c:\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\Anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "c:\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 499, in start
#     self.io_loop.start()
#   File "c:\Anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Anaconda3\lib\asyncio\base_events.py", line 523, in run_forever
#     self._run_once()
#   File "c:\Anaconda3\lib\asyncio\base_events.py", line 1758, in _run_once
#     handle._run()
#   File "c:\Anaconda3\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "c:\Anaconda3\lib\site-packages\tornado\stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "c:\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "c:\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "c:\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "c:\Anaconda3\lib\site-packages\tornado\stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "c:\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "c:\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "c:\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "c:\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "c:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2901, in run_ast_nodes
#     if self.run_code(code, result):
#   File "c:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2961, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-52-40ae251a3d89>", line 2, in <module>
#     icw = cadspy.DatabaseConnection(system='ICW', user=username)
#   File "C:\Users\u243696\AppData\Roaming\Python\Python37\site-packages\cadspy\database.py", line 125, in __init__
#     logger.error('Unable to establish connection, verify credentials are correct.', UserWarning)
# Message: 'Unable to establish connection, verify credentials are correct.'
# Arguments: (<class 'UserWarning'>,)

# %% [markdown]
# <br>
# <div class="alert alert-" style = "border-radius:10px;border-width:3px;border-color:salmon;font-family:Verdana,sans-serif;font-size:16px;">
#
# <font size="4">Can't connect to ICW? Instructions on how to get access to it in the links below:
#
# </font>
# </div>

# %% [markdown]
# - Step 1: [Requesting Access to GitHub](https://baplc.sharepoint.com/sites/ask/SitePages/Requesting-Access-to-GitHub.aspx)
#
# Once your access to GitHub has been aproved, you need to:
#
# - Step 2: [Request access to British-Ent GitHub organisation](https://github.com/BritishAirways-Ent/insight-processes/blob/main/onboarding/Corporate_Directory_git.md)
#
# And
#
# - Step 3: [Setup Sagemaker Studio to access GitHub](https://github.com/BritishAirways-Ent/insight-processes/blob/main/onboarding/sagemaker_to_github_setup.md)
#
# <br>

# %% [markdown]
# Below are some packages to get you started. You don't have to use them but you may find them useful!

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %%
# diplay all rows and cols when using 'dataframe'.head() or 'dataframe'.tail()
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# <br>
#
# ### Data
#
# #### S19 Lounge Eligibility data

# %%
query = """

sel * from LDB_SBOX_OR.HACKATHON_OPS_LOUNGE_ELIGIBILITY

"""

df_lounge_eligibility = icw.queryToDataframe(query)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3360         try:
# -> 3361             return fn()
#    3362         except dialect.dbapi.Error as e:
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\impl.py in connect(self)
#     381
# --> 382         return _ConnectionFairy._checkout(self, self._fairy)
#     383
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     893         if not fairy:
# --> 894             fairy = _ConnectionRecord.checkout(pool)
#     895
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     492     def checkout(cls, pool):
# --> 493         rec = pool._do_get()
#     494         try:
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     363             pass
# --> 364         c = self._create_connection()
#     365         self._conn.current = weakref.ref(c)
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     272
# --> 273         return _ConnectionRecord(self)
#     274
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     387         if connect:
# --> 388             self.__connect()
#     389         self.finalize_callback = deque()
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     690             with util.safe_reraise():
# --> 691                 pool.logger.debug("Error on connect(): %s", e)
#     692         else:
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     685             self.starttime = time.time()
# --> 686             self.dbapi_connection = connection = pool._invoke_creator(self)
#     687             pool.logger.debug("Created new connection %r", connection)
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     597         # inherits the docstring from interfaces.Dialect.connect
# --> 598         return self.dbapi.connect(*cargs, **cparams)
#     599
#
# ~\AppData\Roaming\Python\Python37\site-packages\teradatasql\__init__.py in __init__(self, sConnectParams, **kwargs)
#     187                 goside.goFreePointer (self.uLog, pcError)
# --> 188                 raise OperationalError(sErr)
#     189
#
# OperationalError: [Version 17.20.0.31] [Session 0] [Teradata SQL Driver] [Error 545] LDAP logon mechanism requires username and password, or logdata
#  at gosqldriver/teradatasql.formatError ErrorUtil.go:89
#  at gosqldriver/teradatasql.(*teradataConnection).makeDriverErrorCode ErrorUtil.go:199
#  at gosqldriver/teradatasql.newTeradataConnection TeradataConnection.go:315
#  at gosqldriver/teradatasql.(*teradataDriver).Open TeradataDriver.go:32
#  at database/sql.dsnConnector.Connect sql.go:759
#  at database/sql.(*DB).conn sql.go:1393
#  at database/sql.(*DB).Conn sql.go:1926
#  at main.goCreateConnection goside.go:298
#  at _cgoexp_2fd0e7537524_goCreateConnection _cgo_gotypes.go:263
#  at runtime.cgocallbackg1 cgocall.go:316
#  at runtime.cgocallbackg cgocall.go:235
#  at runtime.cgocallback asm_amd64.s:994
#  at runtime.goexit asm_amd64.s:1594
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-55-0521da9c5c13> in <module>()
#       5 """
#       6
# ----> 7 df_lounge_eligibility = icw.queryToDataframe(query)
#
# ~\AppData\Roaming\Python\Python37\site-packages\cadspy\database.py in queryToDataframe(self, query, params)
#     202
#     203         if self.engine:
# --> 204             table = pandas.read_sql(query, self.engine, params=params)
#     205         else:
#     206             with self as conn:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     513             coerce_float=coerce_float,
#     514             parse_dates=parse_dates,
# --> 515             chunksize=chunksize,
#     516         )
#     517
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1293         args = _convert_params(sql, params)
#    1294
# -> 1295         result = self.execute(*args)
#    1296         columns = result.keys()
#    1297
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1160         """Simple passthrough to SQLAlchemy connectable"""
#    1161         return self.connectable.execution_options(no_parameters=True).execute(
# -> 1162             *args, **kwargs
#    1163         )
#    1164
#
# <string> in execute(self, statement, *multiparams, **params)
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\util\deprecations.py in warned(fn, *args, **kwargs)
#     466         if not skip_warning:
#     467             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 468         return fn(*args, **kwargs)
#     469
#     470     doc = func.__doc__ is not None and func.__doc__ or ""
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    3254
#    3255         """
# -> 3256         connection = self.connect(close_with_result=True)
#    3257         return connection.execute(statement, *multiparams, **params)
#    3258
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3313         """
#    3314
# -> 3315         return self._connection_cls(self, close_with_result=close_with_result)
#    3316
#    3317     @util.deprecated(
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3392
#    3393         """
# -> 3394         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3395
#    3396
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3363             if connection is None:
#    3364                 Connection._handle_dbapi_exception_noconnection(
# -> 3365                     e, dialect, self
#    3366                 )
#    3367             else:
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2197         elif should_wrap:
#    2198             util.raise_(
# -> 2199                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2200             )
#    2201         else:
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3359         dialect = self.dialect
#    3360         try:
# -> 3361             return fn()
#    3362         except dialect.dbapi.Error as e:
#    3363             if connection is None:
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\impl.py in connect(self)
#     380                 return rec._checkout_existing()
#     381
# --> 382         return _ConnectionFairy._checkout(self, self._fairy)
#     383
#     384     def _return_conn(self, record):
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     892     def _checkout(cls, pool, threadconns=None, fairy=None):
#     893         if not fairy:
# --> 894             fairy = _ConnectionRecord.checkout(pool)
#     895
#     896             fairy._pool = pool
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     @classmethod
#     492     def checkout(cls, pool):
# --> 493         rec = pool._do_get()
#     494         try:
#     495             dbapi_connection = rec.get_connection()
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     362         except AttributeError:
#     363             pass
# --> 364         c = self._create_connection()
#     365         self._conn.current = weakref.ref(c)
#     366         if len(self._all_conns) >= self.size:
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     271         """Called by subclasses to create a new ConnectionRecord."""
#     272
# --> 273         return _ConnectionRecord(self)
#     274
#     275     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     386         self.__pool = pool
#     387         if connect:
# --> 388             self.__connect()
#     389         self.finalize_callback = deque()
#     390
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     689         except BaseException as e:
#     690             with util.safe_reraise():
# --> 691                 pool.logger.debug("Error on connect(): %s", e)
#     692         else:
#     693             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      70                 compat.raise_(
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#      74         else:
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     684         try:
#     685             self.starttime = time.time()
# --> 686             self.dbapi_connection = connection = pool._invoke_creator(self)
#     687             pool.logger.debug("Created new connection %r", connection)
#     688             self.fresh = True
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# ~\AppData\Roaming\Python\Python37\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     596     def connect(self, *cargs, **cparams):
#     597         # inherits the docstring from interfaces.Dialect.connect
# --> 598         return self.dbapi.connect(*cargs, **cparams)
#     599
#     600     def create_connect_args(self, url):
#
# ~\AppData\Roaming\Python\Python37\site-packages\teradatasql\__init__.py in __init__(self, sConnectParams, **kwargs)
#     186                 sErr = ctypes.string_at(pcError).decode('utf-8')
#     187                 goside.goFreePointer (self.uLog, pcError)
# --> 188                 raise OperationalError(sErr)
#     189
#     190             self.uConnHandle = uConnHandle.value
#
# OperationalError: (teradatasql.OperationalError) [Version 17.20.0.31] [Session 0] [Teradata SQL Driver] [Error 545] LDAP logon mechanism requires username and password, or logdata
#  at gosqldriver/teradatasql.formatError ErrorUtil.go:89
#  at gosqldriver/teradatasql.(*teradataConnection).makeDriverErrorCode ErrorUtil.go:199
#  at gosqldriver/teradatasql.newTeradataConnection TeradataConnection.go:315
#  at gosqldriver/teradatasql.(*teradataDriver).Open TeradataDriver.go:32
#  at database/sql.dsnConnector.Connect sql.go:759
#  at database/sql.(*DB).conn sql.go:1393
#  at database/sql.(*DB).Conn sql.go:1926
#  at main.goCreateConnection goside.go:298
#  at _cgoexp_2fd0e7537524_goCreateConnection _cgo_gotypes.go:263
#  at runtime.cgocallbackg1 cgocall.go:316
#  at runtime.cgocallbackg cgocall.go:235
#  at runtime.cgocallback asm_amd64.s:994
#  at runtime.goexit asm_amd64.s:1594
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
df_lounge_eligibility.head(2)
# Out:
#          Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 0  2023-08-05618               BA                   618    2023-08-05
# 1  2023-05-17920               BA                   920    2023-05-17
#
#   UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD  \
# 0        LHR              OLB                 C               C
# 1        LHR              STR                 C               C
#
#      BA_PAX_TIER ONEWORLD_TIER Lounge_eligibility_tier  pax
# 0  Gold For Life          EMER                  Tier 2    2
# 1                                               Tier 3   13

# %%
df_lounge_eligibility.shape
# Out:
# (1534750, 12)

# %%
# a look to a particular flight number and date

#mask = (df_lounge_eligibility['DISCHARGE_STN_CD'] == 'GCM   ') & (df_lounge_eligibility['GMT_UPLIFT_DT'] == dt.date(2019,9,12) )

#df_lounge_eligibility[mask]

# %% [markdown]
# #### S19 Flight info

# %%
query = """

select * from LDB_SBOX_OR.HACKATHON_OPS_FLIGHT_INFO

"""

df_flight_info = icw.queryToDataframe(query)

# %%
df_flight_info.head(2)
df_flight_info.dtypes
# Out:
# GMT_PLND_DEP_TS    datetime64[ns]
# GMT_ACT_DEP_TS     datetime64[ns]
# OPG_ALN_CD                 object
# OPG_FLT_NO                  int64
# ACT_DEP_STN_CD             object
# ACT_DEP_TML_CD             object
# PLND_ARR_STN_CD            object
# ACT_ARR_STN_CD             object
# IATA_AC_TYP_CD             object
# ACT_AC_TYP_CD              object
# ROUTE                      object
# dtype: object

# %% [markdown]
# #### Station Code Decode

# %%
query = """

select * from LDB_SBOX_OR.HACKATHON_OPS_COUNTRY_DECODE

"""

df_country = icw.queryToDataframe(query)

# %%
df_country.head(2)
# Out:
#     ROUTE COUNTRY_CD                           COUNTRY_NM  \
# 0  LHRINV        GB   United Kingdom and Northern Ireland
# 1  LHRSVO        RU                      Russia in Europe
#
#   CORP_GEOG_CTRY_GRP_NM CORP_GEOG_CONTINENT_NM
# 0                    UK                     UK
# 1        EASTERN EUROPE          EUROPE EXC UK

# %% [markdown]
# #### Additional Station Decodes from ICW reference table

# %%
# There are lots of missing destinations which are in lounge_elig but not in df_country.
# They are all new (since ~2019) arrivals to Heathrow.
# They are not in sandbox country dataset, but they are in a reference table on ICW.
# Load that ICW reference table and filter for results not in our merged table, but that are in lounge_elig.
# This should result in zero nan values.
query = """
SELECT STN_CD, COUNTRY_CD, COUNTRY_NM, CORP_GEOG_CTRY_GRP_NM, CORP_GEOG_CONTINENT_NM
FROM REF_GEOG_LOC_HIERARCHY
"""
df_additional_country_decodes=icw.queryToDataframe(query)
df_additional_country_decodes.shape # we will remove destinations already in df_country and not in df_lounge_elig later.
# Out:
# (10975, 5)

# %%
df_additional_country_decodes.head(5)
# Out:
#    STN_CD COUNTRY_CD        COUNTRY_NM CORP_GEOG_CTRY_GRP_NM  \
# 0  RFS        NI             Nicaragua       CENTRAL AMERICA
# 1  COO        BJ                 Benin           WEST AFRICA
# 2  SFY        US         United States                   USA
# 3  HGO        CI         Cote d'Ivoire           WEST AFRICA
# 4  RKA        PF      French Polynesia       PACIFIC ISLANDS
#
#         CORP_GEOG_CONTINENT_NM
# 0  SOUTH AMERICA INC CARIBBEAN
# 1                       AFRICA
# 2                NORTH AMERICA
# 3                       AFRICA
# 4          AUSTRALASIA PACIFIC

# %% [markdown]
# #### Aircraft Type

# %%
query = """

select * from LDB_SBOX_OR.HACKATHON_OPS_AC_TYPE

"""

df_acft_typ = icw.queryToDataframe(query)

# %%
df_acft_typ.head(2)
# Out:
#   IATA_AC_TYP_CD ACT_AC_TYP_CD WB_NB_CAT  FIRST_SEATS_QTY  CLUB_SEATS_QTY  \
# 0            320            A3        NB                0              24
# 1            332            W9        WB                0              30
#
#    PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY
# 0                       0                132
# 1                      21                235

# %%
df_acft_typ.shape
# Out:
# (35, 7)

# %%
df_acft_typ
# Out:
#    IATA_AC_TYP_CD ACT_AC_TYP_CD WB_NB_CAT  FIRST_SEATS_QTY  CLUB_SEATS_QTY  \
# 0             320            A3        NB                0              24
# 1             332            W9        WB                0              30
# 2             339            W9        WB                0              30
# 3             777            K7        WB                0              48
# 4             781            X8        WB                7              49
# 5             351            K5        WB                0              56
# 6             321            M6        NB                0              23
# 7             32Q            N6        NB                0              32
# 8             789            L8        WB                8              42
# 9             32A            H3        NB                0              20
# 10            319            A4        NB                0              16
# 11            788            B8        WB                0              35
# 12            77W            G7        WB               14              56
# 13            744            S4        WB               14              86
# 14            343            W9        WB                0              45
# 15            388            A8        WB               14              97
# 16            320            E9        NB                0              29
# 17            777            L7        WB                0              48
# 18            32N            N3        NB                0              20
# 19            321            V6        NB                0              38
# 20            319            M4        NB                0              21
# 21         77W               F7        WB                8              76
# 22            744            V4        WB               14              52
# 23            320            M2        NB                0              24
# 24            777            P7        WB               17              48
# 25            321            W6        NB                0              42
# 26            320            R3        NB                0              28
# 27            777            V7        WB               14              48
# 28            320            T3        NB                0              26
# 29            777            W7        WB               12              48
# 30            320            Y3        NB                0              22
# 31            777            D7        WB                0              48
# 32            777            J7        WB                0              32
# 33            777            M7        WB                7              50
# 34            777            R7        WB               10              52
#
#     PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY
# 0                        0                132
# 1                       21                235
# 2                       21                234
# 3                       24                203
# 4                       35                165
# 5                       56                219
# 6                        0                131
# 7                        0                172
# 8                       39                127
# 9                        0                150
# 10                       0                119
# 11                      25                154
# 12                      44                183
# 13                      30                145
# 14                       0                212
# 15                      55                303
# 16                       0                130
# 17                      24                203
# 18                       0                150
# 19                       0                160
# 20                       0                113
# 21                      40                130
# 22                      36                235
# 23                       0                144
# 24                      24                127
# 25                       0                154
# 26                       0                139
# 27                      40                124
# 28                       0                142
# 29                      32                127
# 30                       0                144
# 31                      40                184
# 32                      48                252
# 33                      40                138
# 34                      40                134

# %% [markdown]
# <br>
#
# ### Pre-processing

# %% [markdown]
# *Hint:* It is always worth checking the format of each of the columns in your dataframes before trying to do any work with them. To do so, you can make use of the `headers_and_first_row` function below.

# %%
def headers_and_first_row(df):
    '''
    print headers and first row of a df to deal with data types
    '''
    
    headers = df.columns
    first_row = []

    for col in headers:
        first_row.append(df[col][0])
    
    dictionary = dict( zip( headers, first_row) )

    return dictionary

# %%
# applying headers_and_first_row to df_lounge_eligibility
format_df = headers_and_first_row(df_lounge_eligibility)
format_2 = headers_and_first_row(df_flight_info)

# %%
# Note that some columns have blank spaces!
format_df
format_2
# Out:
# {'GMT_PLND_DEP_TS': Timestamp('2023-04-30 20:25:00'),
#  'GMT_ACT_DEP_TS': Timestamp('2023-04-30 20:34:00'),
#  'OPG_ALN_CD': 'BA    ',
#  'OPG_FLT_NO': 57,
#  'ACT_DEP_STN_CD': 'LHR   ',
#  'ACT_DEP_TML_CD': '5 ',
#  'PLND_ARR_STN_CD': 'JNB   ',
#  'ACT_ARR_STN_CD': 'JNB   ',
#  'IATA_AC_TYP_CD': '388   ',
#  'ACT_AC_TYP_CD': 'A8  ',
#  'ROUTE': 'LHRJNB      '}

# %% [markdown]
# <br>
# <div class="alert alert-" style = "border-radius:10px;border-width:3px;border-color:lightblue;font-family:Verdana,sans-serif;font-size:16px;">
#
# <font size="3">**Exercise 1:** Pre-process **all** the tables above (df_lounge_eligibility, df_flight_info, df_country, df_acft_typ).
#
# </font>
#
# </ol>
# </div>

# %% [markdown]
# We will first strip all frames of spaces. We will then go through each frame to properly prepare it.
#
# We will then load some additional datasets that will be useful for analysis.

# %%
# Stripping strings

tables = [df_lounge_eligibility,df_flight_info,df_country,df_acft_typ,df_additional_country_decodes]

# Define a function that fine all string fields and remove all blak spaces
def data_cleaning_string(df):
    # Get names of all fields in a dataframe
    fields = df.columns
    # loop for all fields, if data type is string then remove blank spaces
    for f in fields:
        if type(df[f][0]) == str:
            df[f] = df[f].str.strip()
    return df

for i,t in enumerate(tables):
    tables[i] = data_cleaning_string(t)

# %%
# Removing duplucates of flight_info

# Sort the table
df_flight_info = df_flight_info.sort_values(['GMT_PLND_DEP_TS','OPG_FLT_NO','GMT_ACT_DEP_TS'])
# Remove all duplicates and keep the first rows of all duplicated
df_flight_info = df_flight_info.drop_duplicates(subset = ['OPG_FLT_NO','GMT_PLND_DEP_TS'],keep = "first")

# %%
# 2. Flight info
# Ian's code to clean dataset - identify latest departure date for
# duplicated flights and eliminate it.
df_flight_info['GMT_PLND_DEP_DT'] = df_flight_info['GMT_PLND_DEP_TS'].dt.date
df_flight_info['GMT_PLND_DEP_TIME'] = df_flight_info['GMT_PLND_DEP_TS'].dt.time

# %%
# 3. Country
df_country['DEP_STN_CD'] = df_country['ROUTE'].str.slice(0,3)
df_country['ARR_STN_CD'] = df_country['ROUTE'].str.slice(3,6)

# %%
# 4. Aircraft type
df_acft_typ.sort_values('FIRST_SEATS_QTY').tail(10)
# Out:
#    IATA_AC_TYP_CD ACT_AC_TYP_CD WB_NB_CAT  FIRST_SEATS_QTY  CLUB_SEATS_QTY  \
# 8             789            L8        WB                8              42
# 21            77W            F7        WB                8              76
# 34            777            R7        WB               10              52
# 29            777            W7        WB               12              48
# 12            77W            G7        WB               14              56
# 13            744            S4        WB               14              86
# 22            744            V4        WB               14              52
# 15            388            A8        WB               14              97
# 27            777            V7        WB               14              48
# 24            777            P7        WB               17              48
#
#     PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY
# 8                       39                127
# 21                      40                130
# 34                      40                134
# 29                      32                127
# 12                      44                183
# 13                      30                145
# 22                      36                235
# 15                      55                303
# 27                      40                124
# 24                      24                127

# %%
df_lounge_eligibility.shape
# Out:
# (1534750, 12)

# %% [markdown]
# <br>
# <div class="alert alert-" style = "border-radius:10px;border-width:3px;border-color:lightblue;font-family:Verdana,sans-serif;font-size:16px;">
#
# <font size="3">**Exercise 2:** Join the tables below
#
#     - df_flight_info
#     - df_country
#     - df_acft_typ
#
# to the table df_lounge_eligibility to generate a final dataset.
#
# </font>
#
# </ol>
# </div>

# %%
# df_lounge_eligibility.head(5)

# %%
df_lounge_elig_flight_info = pd.merge(df_lounge_eligibility,# left table
                                     df_flight_info, # right table
                                     left_on = ['OPERATING_AIRLINE_CD','OPERATING_FLT_NO','GMT_UPLIFT_DT'], # left on? e.g. which columns from the left table are you joining on to?
                                     right_on = ['OPG_ALN_CD','OPG_FLT_NO','GMT_PLND_DEP_DT'] , # right on? # left on? e.g. which columns from the right table are you joining on to?
                                     how = "left" # how? e.g. left, right, inner,etc
                                     )

df_lounge_elig_flight_info.head(5)
# Out:
#          Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 0  2023-08-05618                   BA               618    2023-08-05
# 1  2023-05-17920                   BA               920    2023-05-17
# 2  2019-04-15770                   BA               770    2019-04-15
# 3  2019-09-23348                   BA               348    2019-09-23
# 4  2019-09-16155                   BA               155    2019-09-16
#
#   UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD  \
# 0           LHR              OLB               C               C
# 1           LHR              STR               C               C
# 2           LHR              OSL               M               M
# 3           LHR              NCE               M               M
# 4           LHR              CAI               J               J
#
#      BA_PAX_TIER ONEWORLD_TIER Lounge_eligibility_tier  pax  \
# 0  Gold For Life          EMER                  Tier 2    2
# 1                                               Tier 3   13
# 2                                         Not eligible   75
# 3                         EMER                  Tier 2    6
# 4                                               Tier 3   23
#
#       GMT_PLND_DEP_TS      GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO  \
# 0 2023-08-05 14:25:00 2023-08-05 14:57:00         BA       618.0
# 1 2023-05-17 16:35:00 2023-05-17 16:43:00         BA       920.0
# 2 2019-04-15 18:25:00 2019-04-15 18:52:00         BA       770.0
# 3 2019-09-23 14:40:00 2019-09-23 14:45:00         BA       348.0
# 4 2019-09-16 16:15:00 2019-09-16 16:45:00         BA       155.0
#
#   ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD IATA_AC_TYP_CD  \
# 0            LHR              3             OLB            OLB            319
# 1            LHR              3             STR            STR            319
# 2            LHR              5             OSL            OSL            32A
# 3            LHR              5             NCE            NCE            319
# 4            LHR              5             CAI            CAI            343
#
#   ACT_AC_TYP_CD   ROUTE GMT_PLND_DEP_DT GMT_PLND_DEP_TIME
# 0            M4  LHROLB      2023-08-05          14:25:00
# 1            M4  LHRSTR      2023-05-17          16:35:00
# 2            H3  LHROSL      2019-04-15          18:25:00
# 3            A4  LHRNCE      2019-09-23          14:40:00
# 4            W9  LHRCAI      2019-09-16          16:15:00

# %%
# your code here!
df_lounge_elig_flight_info.shape
# Out:
# (1534750, 25)

# %% [markdown]
# Get rows with any null values

# %%
df_lounge_elig_flight_info[df_lounge_elig_flight_info.isna().any(axis=1)].head(5)
# Out:
#               Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 300    2019-09-148642                   BA              8642    2019-09-14
# 466    2019-09-298598                   BA              8598    2019-09-29
# 876    2019-09-148642                   BA              8642    2019-09-14
# 1452   2019-09-148642                   BA              8642    2019-09-14
# 11711  2019-06-168586                   BA              8586    2019-06-16
#
#       UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD  \
# 300             LHR              ADB               M               M
# 466             LHR              CFU               M               M
# 876             LHR              ADB               M               M
# 1452            LHR              ADB               M               M
# 11711           LHR              KLX               M               M
#
#       BA_PAX_TIER ONEWORLD_TIER Lounge_eligibility_tier  pax GMT_PLND_DEP_TS  \
# 300        Silver          SAPP                  Tier 3    2             NaT
# 466                                        Not eligible   43             NaT
# 876        Silver                                Tier 3    1             NaT
# 1452                                       Not eligible  144             NaT
# 11711        Gold          EMER                  Tier 2    1             NaT
#
#       GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO ACT_DEP_STN_CD ACT_DEP_TML_CD  \
# 300              NaT        NaN         NaN            NaN            NaN
# 466              NaT        NaN         NaN            NaN            NaN
# 876              NaT        NaN         NaN            NaN            NaN
# 1452             NaT        NaN         NaN            NaN            NaN
# 11711            NaT        NaN         NaN            NaN            NaN
#
#       PLND_ARR_STN_CD ACT_ARR_STN_CD IATA_AC_TYP_CD ACT_AC_TYP_CD ROUTE  \
# 300               NaN            NaN            NaN           NaN   NaN
# 466               NaN            NaN            NaN           NaN   NaN
# 876               NaN            NaN            NaN           NaN   NaN
# 1452              NaN            NaN            NaN           NaN   NaN
# 11711             NaN            NaN            NaN           NaN   NaN
#
#       GMT_PLND_DEP_DT GMT_PLND_DEP_TIME
# 300               NaN               NaN
# 466               NaN               NaN
# 876               NaN               NaN
# 1452              NaN               NaN
# 11711             NaN               NaN

# %%
df_flight_info[df_flight_info['OPG_FLT_NO'] == 8642]
# Out:
# Empty DataFrame
# Columns: [GMT_PLND_DEP_TS, GMT_ACT_DEP_TS, OPG_ALN_CD, OPG_FLT_NO, ACT_DEP_STN_CD, ACT_DEP_TML_CD, PLND_ARR_STN_CD, ACT_ARR_STN_CD, IATA_AC_TYP_CD, ACT_AC_TYP_CD, ROUTE, GMT_PLND_DEP_DT, GMT_PLND_DEP_TIME]
# Index: []

# %% [markdown]
# ### Merge `df_country` to table

# %%
[headers_and_first_row(d) for d in [df_lounge_elig_flight_info,df_country]]
# Out:
# [{'Skew_Id': '2023-08-05618',
#   'OPERATING_AIRLINE_CD': 'BA',
#   'OPERATING_FLT_NO': 618,
#   'GMT_UPLIFT_DT': datetime.date(2023, 8, 5),
#   'UPLIFT_STN_CD': 'LHR',
#   'DISCHARGE_STN_CD': 'OLB',
#   'BOOKED_CABIN_CD': 'C',
#   'TRAVEL_CABIN_CD': 'C',
#   'BA_PAX_TIER': 'Gold For Life',
#   'ONEWORLD_TIER': 'EMER',
#   'Lounge_eligibility_tier': 'Tier 2',
#   'pax': 2,
#   'GMT_PLND_DEP_TS': Timestamp('2023-08-05 14:25:00'),
#   'GMT_ACT_DEP_TS': Timestamp('2023-08-05 14:57:00'),
#   'OPG_ALN_CD': 'BA',
#   'OPG_FLT_NO': 618.0,
#   'ACT_DEP_STN_CD': 'LHR',
#   'ACT_DEP_TML_CD': '3',
#   'PLND_ARR_STN_CD': 'OLB',
#   'ACT_ARR_STN_CD': 'OLB',
#   'IATA_AC_TYP_CD': '319',
#   'ACT_AC_TYP_CD': 'M4',
#   'ROUTE': 'LHROLB',
#   'GMT_PLND_DEP_DT': datetime.date(2023, 8, 5),
#   'GMT_PLND_DEP_TIME': datetime.time(14, 25)},
#  {'ROUTE': 'LHRINV',
#   'COUNTRY_CD': 'GB',
#   'COUNTRY_NM': 'United Kingdom and Northern Ireland',
#   'CORP_GEOG_CTRY_GRP_NM': 'UK',
#   'CORP_GEOG_CONTINENT_NM': 'UK',
#   'DEP_STN_CD': 'LHR',
#   'ARR_STN_CD': 'INV'}]

# %%
df_additional_country_decodes.columns
df_country.columns
# Out:
# Index(['ROUTE', 'COUNTRY_CD', 'COUNTRY_NM', 'CORP_GEOG_CTRY_GRP_NM',
#        'CORP_GEOG_CONTINENT_NM', 'DEP_STN_CD', 'ARR_STN_CD'],
#       dtype='object')

# %%
# For efficiency, we should merge df_country and df_additional_country_decodes first.
# Firstly, organise df_additional_country_decodes to have the same columns.
# if statement to avoid throwing errors if column renaming from cell below has already been done.
if 'STN_CD' in df_additional_country_decodes.columns:
    station_code_col = 'STN_CD'
elif 'ARR_STN_CD' in df_additional_country_decodes.columns:
    station_code_col = 'ARR_STN_CD'
df_additional_country_decodes = df_additional_country_decodes[~df_additional_country_decodes[station_code_col].isin(df_country['ARR_STN_CD'])]
# for more efficiency, we can remove all those rows which are not needed as there are no lounge elig rows with that destinations.
df_additional_country_decodes = df_additional_country_decodes[df_additional_country_decodes[station_code_col].isin(df_lounge_elig_flight_info['DISCHARGE_STN_CD'])]
print(df_additional_country_decodes.shape)
# Out:
# (30, 5)

# %%
# We need df_additional_country_decodes to have the same column names and order as df_country, ready for pd.concat.
# By merging now, we eliminate the need to merge separately with df_lounge_elig.
df_additional_country_decodes['ROUTE'] = 'LHR' + df_additional_country_decodes['STN_CD']
df_additional_country_decodes['DEP_STN_CD'] = 'LHR'
# We must ensure column names and order of df_additional_country_decodes match df_country.
df_additional_country_decodes.rename(columns={'STN_CD':'ARR_STN_CD'},inplace=True)
df_additional_country_decodes = df_additional_country_decodes[df_country.columns]

# %%
# concat together.
df_country = pd.concat([df_country,df_additional_country_decodes])

# %%
df_lounge_elig_flight_info_country = pd.merge(df_lounge_elig_flight_info,# left table
                                     df_country, # right table
                                     left_on = ['DISCHARGE_STN_CD'], # left on? e.g. which columns from the left table are you joining on to?
                                     right_on = ['ARR_STN_CD'] , # right on? # left on? e.g. which columns from the right table are you joining on to?
                                     how = "left" # how? e.g. left, right, inner,etc
                                     )

# df_lounge_elig_flight_info = df_lounge_elig_flight_info.drop_duplicates()

df_lounge_elig_flight_info_country.head(5)
# Out:
#          Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 0  2023-08-05618                   BA               618    2023-08-05
# 1  2023-05-17920                   BA               920    2023-05-17
# 2  2019-04-15770                   BA               770    2019-04-15
# 3  2019-09-23348                   BA               348    2019-09-23
# 4  2019-09-16155                   BA               155    2019-09-16
#
#   UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD  \
# 0           LHR              OLB               C               C
# 1           LHR              STR               C               C
# 2           LHR              OSL               M               M
# 3           LHR              NCE               M               M
# 4           LHR              CAI               J               J
#
#      BA_PAX_TIER ONEWORLD_TIER Lounge_eligibility_tier  pax  \
# 0  Gold For Life          EMER                  Tier 2    2
# 1                                               Tier 3   13
# 2                                         Not eligible   75
# 3                         EMER                  Tier 2    6
# 4                                               Tier 3   23
#
#       GMT_PLND_DEP_TS      GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO  \
# 0 2023-08-05 14:25:00 2023-08-05 14:57:00         BA       618.0
# 1 2023-05-17 16:35:00 2023-05-17 16:43:00         BA       920.0
# 2 2019-04-15 18:25:00 2019-04-15 18:52:00         BA       770.0
# 3 2019-09-23 14:40:00 2019-09-23 14:45:00         BA       348.0
# 4 2019-09-16 16:15:00 2019-09-16 16:45:00         BA       155.0
#
#   ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD IATA_AC_TYP_CD  \
# 0            LHR              3             OLB            OLB            319
# 1            LHR              3             STR            STR            319
# 2            LHR              5             OSL            OSL            32A
# 3            LHR              5             NCE            NCE            319
# 4            LHR              5             CAI            CAI            343
#
#   ACT_AC_TYP_CD ROUTE_x GMT_PLND_DEP_DT GMT_PLND_DEP_TIME ROUTE_y COUNTRY_CD  \
# 0            M4  LHROLB      2023-08-05          14:25:00  LHROLB         IT
# 1            M4  LHRSTR      2023-05-17          16:35:00  LHRSTR         DE
# 2            H3  LHROSL      2019-04-15          18:25:00  LHROSL         NO
# 3            A4  LHRNCE      2019-09-23          14:40:00  LHRNCE         FR
# 4            W9  LHRCAI      2019-09-16          16:15:00  LHRCAI         EG
#
#   COUNTRY_NM CORP_GEOG_CTRY_GRP_NM CORP_GEOG_CONTINENT_NM DEP_STN_CD  \
# 0      Italy         MEDITERRANEAN          EUROPE EXC UK        LHR
# 1    Germany           WEST EUROPE          EUROPE EXC UK        LHR
# 2     Norway           SCANDINAVIA          EUROPE EXC UK        LHR
# 3     France           WEST EUROPE          EUROPE EXC UK        LHR
# 4      Egypt          NORTH AFRICA                 AFRICA        LHR
#
#   ARR_STN_CD
# 0        OLB
# 1        STR
# 2        OSL
# 3        NCE
# 4        CAI

# %%
df_lounge_elig_flight_info_country.shape
# Out:
# (1534750, 32)

# %% [markdown]
# Check for null values

# %%
df_lounge_elig_flight_info_country[df_lounge_elig_flight_info_country['CORP_GEOG_CONTINENT_NM'].isna()].head(5)
# There are no null values arising from lack of country data.
# Out:
# Empty DataFrame
# Columns: [Skew_Id, OPERATING_AIRLINE_CD, OPERATING_FLT_NO, GMT_UPLIFT_DT, UPLIFT_STN_CD, DISCHARGE_STN_CD, BOOKED_CABIN_CD, TRAVEL_CABIN_CD, BA_PAX_TIER, ONEWORLD_TIER, Lounge_eligibility_tier, pax, GMT_PLND_DEP_TS, GMT_ACT_DEP_TS, OPG_ALN_CD, OPG_FLT_NO, ACT_DEP_STN_CD, ACT_DEP_TML_CD, PLND_ARR_STN_CD, ACT_ARR_STN_CD, IATA_AC_TYP_CD, ACT_AC_TYP_CD, ROUTE_x, GMT_PLND_DEP_DT, GMT_PLND_DEP_TIME, ROUTE_y, COUNTRY_CD, COUNTRY_NM, CORP_GEOG_CTRY_GRP_NM, CORP_GEOG_CONTINENT_NM, DEP_STN_CD, ARR_STN_CD]
# Index: []

# %%
# to avoid breaking anything, we first remove all values we do not need.
# Firstly, remove those values in df_country.
# then remove values not in df_lounge_elig.
df_additional_country_decodes = df_additional_country_decodes[~df_additional_country_decodes['STN_CD'].isin(df_country['ARR_STN_CD'])]
df_additional_country_decodes = df_additional_country_decodes[df_additional_country_decodes['STN_CD'].isin(df_lounge_elig_flight_info_country['DISCHARGE_STN_CD'])]
df_additional_country_decodes.head(40)
#df_lounge_elig_flight_info_country.merge(df_additional_country_decodes)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'STN_CD'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-53c5b63d2320> in <module>()
#       2 # Firstly, remove those values in df_country.
#       3 # then remove values not in df_lounge_elig.
# ----> 4 df_additional_country_decodes = df_additional_country_decodes[~df_additional_country_decodes['STN_CD'].isin(df_country['ARR_STN_CD'])]
#       5 df_additional_country_decodes = df_additional_country_decodes[df_additional_country_decodes['STN_CD'].isin(df_lounge_elig_flight_info_country['DISCHARGE_STN_CD'])]
#       6 df_additional_country_decodes.head(40)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'STN_CD'

# %% [markdown]
# ### `df_acft_typ`

# %%
df_lounge_elig_flight_info_country_acft_typ = pd.merge(
    df_lounge_elig_flight_info_country,
    df_acft_typ,
    left_on = ['IATA_AC_TYP_CD','ACT_AC_TYP_CD'],
    right_on = ['IATA_AC_TYP_CD','ACT_AC_TYP_CD'],
    how = 'left'
)

df_lounge_elig_flight_info_country_acft_typ.head(5)
# Out:
#          Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 0  2023-08-05618                   BA               618    2023-08-05
# 1  2023-05-17920                   BA               920    2023-05-17
# 2  2019-04-15770                   BA               770    2019-04-15
# 3  2019-09-23348                   BA               348    2019-09-23
# 4  2019-09-16155                   BA               155    2019-09-16
#
#   UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD  \
# 0           LHR              OLB               C               C
# 1           LHR              STR               C               C
# 2           LHR              OSL               M               M
# 3           LHR              NCE               M               M
# 4           LHR              CAI               J               J
#
#      BA_PAX_TIER ONEWORLD_TIER Lounge_eligibility_tier  pax  \
# 0  Gold For Life          EMER                  Tier 2    2
# 1                                               Tier 3   13
# 2                                         Not eligible   75
# 3                         EMER                  Tier 2    6
# 4                                               Tier 3   23
#
#       GMT_PLND_DEP_TS      GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO  \
# 0 2023-08-05 14:25:00 2023-08-05 14:57:00         BA       618.0
# 1 2023-05-17 16:35:00 2023-05-17 16:43:00         BA       920.0
# 2 2019-04-15 18:25:00 2019-04-15 18:52:00         BA       770.0
# 3 2019-09-23 14:40:00 2019-09-23 14:45:00         BA       348.0
# 4 2019-09-16 16:15:00 2019-09-16 16:45:00         BA       155.0
#
#   ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD IATA_AC_TYP_CD  \
# 0            LHR              3             OLB            OLB            319
# 1            LHR              3             STR            STR            319
# 2            LHR              5             OSL            OSL            32A
# 3            LHR              5             NCE            NCE            319
# 4            LHR              5             CAI            CAI            343
#
#   ACT_AC_TYP_CD ROUTE_x GMT_PLND_DEP_DT GMT_PLND_DEP_TIME ROUTE_y COUNTRY_CD  \
# 0            M4  LHROLB      2023-08-05          14:25:00  LHROLB         IT
# 1            M4  LHRSTR      2023-05-17          16:35:00  LHRSTR         DE
# 2            H3  LHROSL      2019-04-15          18:25:00  LHROSL         NO
# 3            A4  LHRNCE      2019-09-23          14:40:00  LHRNCE         FR
# 4            W9  LHRCAI      2019-09-16          16:15:00  LHRCAI         EG
#
#   COUNTRY_NM CORP_GEOG_CTRY_GRP_NM CORP_GEOG_CONTINENT_NM DEP_STN_CD  \
# 0      Italy         MEDITERRANEAN          EUROPE EXC UK        LHR
# 1    Germany           WEST EUROPE          EUROPE EXC UK        LHR
# 2     Norway           SCANDINAVIA          EUROPE EXC UK        LHR
# 3     France           WEST EUROPE          EUROPE EXC UK        LHR
# 4      Egypt          NORTH AFRICA                 AFRICA        LHR
#
#   ARR_STN_CD WB_NB_CAT  FIRST_SEATS_QTY  CLUB_SEATS_QTY  \
# 0        OLB        NB              0.0            21.0
# 1        STR        NB              0.0            21.0
# 2        OSL        NB              0.0            20.0
# 3        NCE        NB              0.0            16.0
# 4        CAI        WB              0.0            45.0
#
#    PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY
# 0                     0.0              113.0
# 1                     0.0              113.0
# 2                     0.0              150.0
# 3                     0.0              119.0
# 4                     0.0              212.0

# %%
df_lounge_elig_flight_info_country_acft_typ.shape
# Out:
# (1534750, 37)

# %% [markdown]
# Check for null

# %%
df_lounge_elig_flight_info_country_acft_typ[df_lounge_elig_flight_info_country_acft_typ.isna().any(axis=1)].head(5)
# Out:
#               Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 300    2019-09-148642                   BA              8642    2019-09-14
# 466    2019-09-298598                   BA              8598    2019-09-29
# 876    2019-09-148642                   BA              8642    2019-09-14
# 1452   2019-09-148642                   BA              8642    2019-09-14
# 11711  2019-06-168586                   BA              8586    2019-06-16
#
#       UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD  \
# 300             LHR              ADB               M               M
# 466             LHR              CFU               M               M
# 876             LHR              ADB               M               M
# 1452            LHR              ADB               M               M
# 11711           LHR              KLX               M               M
#
#       BA_PAX_TIER ONEWORLD_TIER Lounge_eligibility_tier  pax GMT_PLND_DEP_TS  \
# 300        Silver          SAPP                  Tier 3    2             NaT
# 466                                        Not eligible   43             NaT
# 876        Silver                                Tier 3    1             NaT
# 1452                                       Not eligible  144             NaT
# 11711        Gold          EMER                  Tier 2    1             NaT
#
#       GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO ACT_DEP_STN_CD ACT_DEP_TML_CD  \
# 300              NaT        NaN         NaN            NaN            NaN
# 466              NaT        NaN         NaN            NaN            NaN
# 876              NaT        NaN         NaN            NaN            NaN
# 1452             NaT        NaN         NaN            NaN            NaN
# 11711            NaT        NaN         NaN            NaN            NaN
#
#       PLND_ARR_STN_CD ACT_ARR_STN_CD IATA_AC_TYP_CD ACT_AC_TYP_CD ROUTE_x  \
# 300               NaN            NaN            NaN           NaN     NaN
# 466               NaN            NaN            NaN           NaN     NaN
# 876               NaN            NaN            NaN           NaN     NaN
# 1452              NaN            NaN            NaN           NaN     NaN
# 11711             NaN            NaN            NaN           NaN     NaN
#
#       GMT_PLND_DEP_DT GMT_PLND_DEP_TIME ROUTE_y COUNTRY_CD COUNTRY_NM  \
# 300               NaN               NaN  LHRADB         TR     Turkey
# 466               NaN               NaN  LHRCFU         GR     Greece
# 876               NaN               NaN  LHRADB         TR     Turkey
# 1452              NaN               NaN  LHRADB         TR     Turkey
# 11711             NaN               NaN  LHRKLX         GR     Greece
#
#       CORP_GEOG_CTRY_GRP_NM CORP_GEOG_CONTINENT_NM DEP_STN_CD ARR_STN_CD  \
# 300           MEDITERRANEAN          EUROPE EXC UK        LHR        ADB
# 466           MEDITERRANEAN          EUROPE EXC UK        LHR        CFU
# 876           MEDITERRANEAN          EUROPE EXC UK        LHR        ADB
# 1452          MEDITERRANEAN          EUROPE EXC UK        LHR        ADB
# 11711         MEDITERRANEAN          EUROPE EXC UK        LHR        KLX
#
#       WB_NB_CAT  FIRST_SEATS_QTY  CLUB_SEATS_QTY  PREM_ECONOMY_SEATS_QTY  \
# 300         NaN              NaN             NaN                     NaN
# 466         NaN              NaN             NaN                     NaN
# 876         NaN              NaN             NaN                     NaN
# 1452        NaN              NaN             NaN                     NaN
# 11711       NaN              NaN             NaN                     NaN
#
#        ECONOMY_SEATS_QTY
# 300                  NaN
# 466                  NaN
# 876                  NaN
# 1452                 NaN
# 11711                NaN

# %%
df_acft_typ[df_acft_typ['ACT_AC_TYP_CD'] == 'M4']
# Out:
#    IATA_AC_TYP_CD ACT_AC_TYP_CD WB_NB_CAT  FIRST_SEATS_QTY  CLUB_SEATS_QTY  \
# 20            319            M4        NB                0              21
#
#     PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY
# 20                       0                113

# %% [markdown]
# ### More cleaning for columns redundancy

# %%
headers_and_first_row(df_lounge_elig_flight_info_country_acft_typ)
# Out:
# {'Skew_Id': '2023-08-05618',
#  'OPERATING_AIRLINE_CD': 'BA',
#  'OPERATING_FLT_NO': 618,
#  'GMT_UPLIFT_DT': datetime.date(2023, 8, 5),
#  'UPLIFT_STN_CD': 'LHR',
#  'DISCHARGE_STN_CD': 'OLB',
#  'BOOKED_CABIN_CD': 'C',
#  'TRAVEL_CABIN_CD': 'C',
#  'BA_PAX_TIER': 'Gold For Life',
#  'ONEWORLD_TIER': 'EMER',
#  'Lounge_eligibility_tier': 'Tier 2',
#  'pax': 2,
#  'GMT_PLND_DEP_TS': Timestamp('2023-08-05 14:25:00'),
#  'GMT_ACT_DEP_TS': Timestamp('2023-08-05 14:57:00'),
#  'OPG_ALN_CD': 'BA',
#  'OPG_FLT_NO': 618.0,
#  'ACT_DEP_STN_CD': 'LHR',
#  'ACT_DEP_TML_CD': '3',
#  'PLND_ARR_STN_CD': 'OLB',
#  'ACT_ARR_STN_CD': 'OLB',
#  'IATA_AC_TYP_CD': '319',
#  'ACT_AC_TYP_CD': 'M4',
#  'ROUTE_x': 'LHROLB',
#  'GMT_PLND_DEP_DT': datetime.date(2023, 8, 5),
#  'GMT_PLND_DEP_TIME': datetime.time(14, 25),
#  'ROUTE_y': 'LHROLB',
#  'COUNTRY_CD': 'IT',
#  'COUNTRY_NM': 'Italy',
#  'CORP_GEOG_CTRY_GRP_NM': 'MEDITERRANEAN',
#  'CORP_GEOG_CONTINENT_NM': 'EUROPE EXC UK',
#  'DEP_STN_CD': 'LHR',
#  'ARR_STN_CD': 'OLB',
#  'WB_NB_CAT': 'NB',
#  'FIRST_SEATS_QTY': 0.0,
#  'CLUB_SEATS_QTY': 21.0,
#  'PREM_ECONOMY_SEATS_QTY': 0.0,
#  'ECONOMY_SEATS_QTY': 113.0}

# %%
# to_drop = ['GMT_PLND_DEP_TS','GMT_ACT_DEP_TS','OPG_ALN_CD','OPG_FLT_NO','ACT_DEP_STN_CD','PLND_ARR_STN_CD','ACT_ARR_STN_CD','GMT_UPLIFT_DT']

# df_lounge_elig_flight_info_country_acft_typ = df_lounge_elig_flight_info_country_acft_typ.drop(columns = to_drop,)

df_lounge_elig_flight_info_country_acft_typ.head(5)
# Out:
#          Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 0  2023-08-05618                   BA               618    2023-08-05
# 1  2023-05-17920                   BA               920    2023-05-17
# 2  2019-04-15770                   BA               770    2019-04-15
# 3  2019-09-23348                   BA               348    2019-09-23
# 4  2019-09-16155                   BA               155    2019-09-16
#
#   UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD  \
# 0           LHR              OLB               C               C
# 1           LHR              STR               C               C
# 2           LHR              OSL               M               M
# 3           LHR              NCE               M               M
# 4           LHR              CAI               J               J
#
#      BA_PAX_TIER ONEWORLD_TIER Lounge_eligibility_tier  pax  \
# 0  Gold For Life          EMER                  Tier 2    2
# 1                                               Tier 3   13
# 2                                         Not eligible   75
# 3                         EMER                  Tier 2    6
# 4                                               Tier 3   23
#
#       GMT_PLND_DEP_TS      GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO  \
# 0 2023-08-05 14:25:00 2023-08-05 14:57:00         BA       618.0
# 1 2023-05-17 16:35:00 2023-05-17 16:43:00         BA       920.0
# 2 2019-04-15 18:25:00 2019-04-15 18:52:00         BA       770.0
# 3 2019-09-23 14:40:00 2019-09-23 14:45:00         BA       348.0
# 4 2019-09-16 16:15:00 2019-09-16 16:45:00         BA       155.0
#
#   ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD IATA_AC_TYP_CD  \
# 0            LHR              3             OLB            OLB            319
# 1            LHR              3             STR            STR            319
# 2            LHR              5             OSL            OSL            32A
# 3            LHR              5             NCE            NCE            319
# 4            LHR              5             CAI            CAI            343
#
#   ACT_AC_TYP_CD ROUTE_x GMT_PLND_DEP_DT GMT_PLND_DEP_TIME ROUTE_y COUNTRY_CD  \
# 0            M4  LHROLB      2023-08-05          14:25:00  LHROLB         IT
# 1            M4  LHRSTR      2023-05-17          16:35:00  LHRSTR         DE
# 2            H3  LHROSL      2019-04-15          18:25:00  LHROSL         NO
# 3            A4  LHRNCE      2019-09-23          14:40:00  LHRNCE         FR
# 4            W9  LHRCAI      2019-09-16          16:15:00  LHRCAI         EG
#
#   COUNTRY_NM CORP_GEOG_CTRY_GRP_NM CORP_GEOG_CONTINENT_NM DEP_STN_CD  \
# 0      Italy         MEDITERRANEAN          EUROPE EXC UK        LHR
# 1    Germany           WEST EUROPE          EUROPE EXC UK        LHR
# 2     Norway           SCANDINAVIA          EUROPE EXC UK        LHR
# 3     France           WEST EUROPE          EUROPE EXC UK        LHR
# 4      Egypt          NORTH AFRICA                 AFRICA        LHR
#
#   ARR_STN_CD WB_NB_CAT  FIRST_SEATS_QTY  CLUB_SEATS_QTY  \
# 0        OLB        NB              0.0            21.0
# 1        STR        NB              0.0            21.0
# 2        OSL        NB              0.0            20.0
# 3        NCE        NB              0.0            16.0
# 4        CAI        WB              0.0            45.0
#
#    PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY
# 0                     0.0              113.0
# 1                     0.0              113.0
# 2                     0.0              150.0
# 3                     0.0              119.0
# 4                     0.0              212.0

# %%
column_names = df_lounge_elig_flight_info_country_acft_typ.columns.tolist()
print(column_names)
# Out:
# ['Skew_Id', 'OPERATING_AIRLINE_CD', 'OPERATING_FLT_NO', 'GMT_UPLIFT_DT', 'UPLIFT_STN_CD', 'DISCHARGE_STN_CD', 'BOOKED_CABIN_CD', 'TRAVEL_CABIN_CD', 'BA_PAX_TIER', 'ONEWORLD_TIER', 'Lounge_eligibility_tier', 'pax', 'GMT_PLND_DEP_TS', 'GMT_ACT_DEP_TS', 'OPG_ALN_CD', 'OPG_FLT_NO', 'ACT_DEP_STN_CD', 'ACT_DEP_TML_CD', 'PLND_ARR_STN_CD', 'ACT_ARR_STN_CD', 'IATA_AC_TYP_CD', 'ACT_AC_TYP_CD', 'ROUTE_x', 'GMT_PLND_DEP_DT', 'GMT_PLND_DEP_TIME', 'ROUTE_y', 'COUNTRY_CD', 'COUNTRY_NM', 'CORP_GEOG_CTRY_GRP_NM', 'CORP_GEOG_CONTINENT_NM', 'DEP_STN_CD', 'ARR_STN_CD', 'WB_NB_CAT', 'FIRST_SEATS_QTY', 'CLUB_SEATS_QTY', 'PREM_ECONOMY_SEATS_QTY', 'ECONOMY_SEATS_QTY']

# %%
# Added Departure year for easier separation 19 and 23 data
df_lounge_elig_flight_info_country_acft_typ['GMT_UPLIFT_YR'] = [dts.year for dts in df_lounge_elig_flight_info_country_acft_typ['GMT_UPLIFT_DT']]

#FINAL DATA 

df = pd.DataFrame(df_lounge_elig_flight_info_country_acft_typ)

selected_columns = ['Skew_Id', 'OPERATING_FLT_NO', 'GMT_UPLIFT_DT', 'BOOKED_CABIN_CD', 'TRAVEL_CABIN_CD', 'BA_PAX_TIER', 'ONEWORLD_TIER', 'Lounge_eligibility_tier', 'pax', 'GMT_PLND_DEP_TS',  'OPG_FLT_NO','ACT_DEP_TML_CD', 'PLND_ARR_STN_CD', 'IATA_AC_TYP_CD', 'ACT_AC_TYP_CD', 'GMT_PLND_DEP_DT', 'GMT_PLND_DEP_TIME', 'COUNTRY_CD', 'COUNTRY_NM', 'CORP_GEOG_CTRY_GRP_NM', 'CORP_GEOG_CONTINENT_NM','WB_NB_CAT', 'FIRST_SEATS_QTY', 'CLUB_SEATS_QTY', 'PREM_ECONOMY_SEATS_QTY', 'ECONOMY_SEATS_QTY', 'GMT_UPLIFT_YR']
new_df = df.loc[:, selected_columns]

# %%
#FINAL DATA - PAX SUMMED PER TIER

# Pivot the DataFrame using pivot_table
pivot_df = pd.pivot_table(new_df, values='pax', index=['Skew_Id', 'OPERATING_FLT_NO', 'GMT_UPLIFT_DT', 'GMT_PLND_DEP_TS', 'OPG_FLT_NO','ACT_DEP_TML_CD', 'PLND_ARR_STN_CD', 'IATA_AC_TYP_CD', 'ACT_AC_TYP_CD', 'GMT_PLND_DEP_DT', 'GMT_PLND_DEP_TIME', 'COUNTRY_CD', 'COUNTRY_NM', 'CORP_GEOG_CTRY_GRP_NM', 'CORP_GEOG_CONTINENT_NM','WB_NB_CAT', 'FIRST_SEATS_QTY', 'CLUB_SEATS_QTY', 'PREM_ECONOMY_SEATS_QTY', 'ECONOMY_SEATS_QTY', 'GMT_UPLIFT_YR'],
                          columns='Lounge_eligibility_tier', aggfunc='sum', fill_value=0).reset_index()

# Display the resulting DataFrame
first_10_column_names = pivot_df.columns[:10].tolist()
print(first_10_column_names)
# Out:
# ['Skew_Id', 'OPERATING_FLT_NO', 'GMT_UPLIFT_DT', 'GMT_PLND_DEP_TS', 'OPG_FLT_NO', 'ACT_DEP_TML_CD', 'PLND_ARR_STN_CD', 'IATA_AC_TYP_CD', 'ACT_AC_TYP_CD', 'GMT_PLND_DEP_DT']

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
print(pivot_df.head(20))
# Out:
# Lounge_eligibility_tier         Skew_Id  OPERATING_FLT_NO GMT_UPLIFT_DT     GMT_PLND_DEP_TS  OPG_FLT_NO ACT_DEP_TML_CD PLND_ARR_STN_CD IATA_AC_TYP_CD ACT_AC_TYP_CD GMT_PLND_DEP_DT GMT_PLND_DEP_TIME COUNTRY_CD                           COUNTRY_NM CORP_GEOG_CTRY_GRP_NM       CORP_GEOG_CONTINENT_NM WB_NB_CAT  FIRST_SEATS_QTY  CLUB_SEATS_QTY  PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY  GMT_UPLIFT_YR  Not eligible  Tier 1  Tier 2  Tier 3
# 0                         2019-03-31103               103    2019-03-31 2019-03-31 17:30:00       103.0              5             YYC            788            B8      2019-03-31          17:30:00         CA                               Canada                CANADA                NORTH AMERICA        WB              0.0            35.0                    25.0              154.0           2019           154       1       9      33
# 1                         2019-03-31105               105    2019-03-31 2019-03-31 21:25:00       105.0              5             DXB            777            V7      2019-03-31          21:25:00         AE                 United Arab Emirates         SOUTHERN GULF                  MIDDLE EAST        WB             14.0            48.0                    40.0              124.0           2019           137      13      13      46
# 2                         2019-03-31107               107    2019-03-31 2019-03-31 11:50:00       107.0              5             DXB            777            V7      2019-03-31          11:50:00         AE                 United Arab Emirates         SOUTHERN GULF                  MIDDLE EAST        WB             14.0            48.0                    40.0              124.0           2019           126      11      18      46
# 3                         2019-03-31109               109    2019-03-31 2019-03-31 20:15:00       109.0              5             DXB            777            V7      2019-03-31          20:15:00         AE                 United Arab Emirates         SOUTHERN GULF                  MIDDLE EAST        WB             14.0            48.0                    40.0              124.0           2019           139      14      22      42
# 4                          2019-03-3111                11    2019-03-31 2019-03-31 18:55:00        11.0              5             SIN            388            A8      2019-03-31          18:55:00         SG                            Singapore     FAR EAST JSA HUBS          AUSTRALASIA PACIFIC        WB             14.0            97.0                    55.0              303.0           2019           308      17      43      75
# 5                         2019-03-31113               113    2019-03-31 2019-03-31 15:15:00       113.0              5             JFK            777            W7      2019-03-31          15:15:00         US                        United States                   USA                NORTH AMERICA        WB             12.0            48.0                    32.0              127.0           2019           135      12      22      43
# 6                         2019-03-31115               115    2019-03-31 2019-03-31 13:30:00       115.0              5             JFK            777            V7      2019-03-31          13:30:00         US                        United States                   USA                NORTH AMERICA        WB             14.0            48.0                    40.0              124.0           2019           132      14      26      40
# 7                         2019-03-31117               117    2019-03-31 2019-03-31 07:30:00       117.0              5             JFK            744            S4      2019-03-31          07:30:00         US                        United States                   USA                NORTH AMERICA        WB             14.0            86.0                    30.0              145.0           2019           138      19      16      61
# 8                         2019-03-31119               119    2019-03-31 2019-03-31 13:15:00       119.0              5             BLR            77W            G7      2019-03-31          13:15:00         IN                                India            SOUTH ASIA  ASIA SOUTH EAST AND CENTRAL        WB             14.0            56.0                    44.0              183.0           2019           204       3      12      42
# 9                         2019-03-31123               123    2019-03-31 2019-03-31 18:45:00       123.0              5             DOH            789            L8      2019-03-31          18:45:00         QA                                Qatar         SOUTHERN GULF                  MIDDLE EAST        WB              8.0            42.0                    39.0              127.0           2019           133       6      11      27
# 10                        2019-03-31125               125    2019-03-31 2019-03-31 11:30:00       125.0              5             BAH            777            P7      2019-03-31          11:30:00         BH                              Bahrain         NORTHERN GULF                  MIDDLE EAST        WB             17.0            48.0                    24.0              127.0           2019           124      15       7      49
# 11                       2019-03-311306              1306    2019-03-31 2019-03-31 07:45:00      1306.0              5             ABZ            319            A4      2019-03-31          07:45:00         GB  United Kingdom and Northern Ireland                    UK                           UK        NB              0.0            16.0                     0.0              119.0           2019            84       0       6      14
# 12                       2019-03-311308              1308    2019-03-31 2019-03-31 10:50:00      1308.0              5             ABZ            319            A4      2019-03-31          10:50:00         GB  United Kingdom and Northern Ireland                    UK                           UK        NB              0.0            16.0                     0.0              119.0           2019           110       0       3      12
# 13                       2019-03-311314              1314    2019-03-31 2019-03-31 14:55:00      1314.0              5             ABZ            32A            H3      2019-03-31          14:55:00         GB  United Kingdom and Northern Ireland                    UK                           UK        NB              0.0            20.0                     0.0              150.0           2019           138       0       2      23
# 14                       2019-03-311316              1316    2019-03-31 2019-03-31 17:00:00      1316.0              5             ABZ            321            W6      2019-03-31          17:00:00         GB  United Kingdom and Northern Ireland                    UK                           UK        NB              0.0            42.0                     0.0              154.0           2019           171       0       5      25
# 15                       2019-03-311318              1318    2019-03-31 2019-03-31 20:00:00      1318.0              5             ABZ            319            A4      2019-03-31          20:00:00         GB  United Kingdom and Northern Ireland                    UK                           UK        NB              0.0            16.0                     0.0              119.0           2019            80       0       3      22
# 16                       2019-03-311324              1324    2019-03-31 2019-03-31 07:25:00      1324.0              5             NCL            320            A3      2019-03-31          07:25:00         GB  United Kingdom and Northern Ireland                    UK                           UK        NB              0.0            24.0                     0.0              132.0           2019            61       2       4       5
# 17                       2019-03-311326              1326    2019-03-31 2019-03-31 08:20:00      1326.0              5             NCL            321            V6      2019-03-31          08:20:00         GB  United Kingdom and Northern Ireland                    UK                           UK        NB              0.0            38.0                     0.0              160.0           2019            91       1       5      21
# 18                        2019-03-31133               133    2019-03-31 2019-03-31 20:35:00       133.0              5             JED            788            B8      2019-03-31          20:35:00         SA                         Saudi Arabia          SAUDI ARABIA                  MIDDLE EAST        WB              0.0            35.0                    25.0              154.0           2019           141       0      11      27
# 19                       2019-03-311334              1334    2019-03-31 2019-03-31 13:25:00      1334.0              5             NCL            32N            N3      2019-03-31          13:25:00         GB  United Kingdom and Northern Ireland                    UK                           UK        NB              0.0            20.0                     0.0              150.0           2019           122       0       6      29

# %% [markdown]
# Save as CSV

# %%
df_lounge_elig_flight_info_country_acft_typ.to_csv('Merged.csv')

pivot_df.to_csv('TiersTallyPerFlight.csv')

# %% [markdown]
# <br><br>
# <div class="alert alert-" style = "border-radius:10px;border-width:3px;border-color:lightblue;font-family:Verdana,sans-serif;font-size:16px;">
#
# <font size="3">Exercise 3: Based on S2019/S2023 data, provide a lookup table of Lounge eligibility assumptions that can be applied to a future schedule. To do so, answer each of the following questions in the Markdown cell provided below.
#
# - What level of granularity do you use?
# - What metric do you use to come up with Lounge eligibility profiles?
#
#
# Note 1: **Provide evidence for your assumptions.** This can be in the form of tables, graphs, correlation matrix, etc.
#
# Note 2: Make use of the examples below to give structure to your answer. Feel free to attend the Hackathon Clinics if you have any questions.
# </font>
#
#
#
# </ol>
# </div>

# %% [markdown]
# **Reasoning (Example 1)**:

# %% [markdown]
# Assume:
# - Data has been preprocessed.
# - Data has been joined, and a final dataset has been created. This dataset is the result of joining the 4 tables.
#
# The final dataset has been called `df_lounge_elig_flight_info_country_acft_typ`.

# %% [markdown]
# <u>What level of granularity do you use?</u>
# - I have decided to split all flights in the network based on their aircraft type. I will therefore have a lookup table with two categories: Narrowbody and Widebody.
#
# <u>What metric do you use to come up with Lounge eligibility profiles?</u>
# - I have sumed up all the passengers by Aircraft Type, by Tier. Then I have divided them by the total number of passengers by Aircraft Type. For example:
#     - For NB aircrafts, and for Tier 1 passengers: In S19 we had 41,728 pax eligible for Tier 1 out of 7,222,830 pax flying on Narrowbody aircraft. This represents 0.6% of the costumers and I assume that this will be the number of costumers elegible for this specific Lounge in a future schedule.

# %%
# your code here!

# %%
# columns that you want to group by
list_groupby = ['WB_NB_CAT','Lounge_eligibility_tier']

# grouping by WB_NB_CAT and Lounge_eligibility_tier
df_groupby_wb_nb = df_lounge_elig_flight_info_country_acft_typ.groupby(list_groupby).agg(
                pax_count = ('pax','sum')
).reset_index()

# %%
# a look at the data
df_groupby_wb_nb
# Out:
#   WB_NB_CAT Lounge_eligibility_tier  pax_count
# 0        NB            Not eligible    9741188
# 1        NB                  Tier 1      53292
# 2        NB                  Tier 2     744829
# 3        NB                  Tier 3    2240579
# 4        WB            Not eligible    5730922
# 5        WB                  Tier 1     236775
# 6        WB                  Tier 2     391264
# 7        WB                  Tier 3    1523611

# %%
# getting the number of pax by aircraft type

# columns that you want to group by
list_groupby = ['WB_NB_CAT']

# grouping by WB_NB_CAT
df_groupby_wb_nb_ttl = df_lounge_elig_flight_info_country_acft_typ.groupby(list_groupby).agg(
                pax_count_ttl = ('pax','sum')
).reset_index()

# %%
# a look at the data
df_groupby_wb_nb_ttl
# Out:
#   WB_NB_CAT  pax_count_ttl
# 0        NB       12779888
# 1        WB        7882572

# %%
# now, let's left join df_groupby_wb_nb_ttl onto df_groupby_wb_nb
# this adds a new column to the df_groupby_wb_nb table (pax_count_ttl) that will be used to get the percentage of passenger eligible by Tier

df_groupby_wb_nb = pd.merge(df_groupby_wb_nb,
                            df_groupby_wb_nb_ttl,
                            on = ['WB_NB_CAT'],
                            how = 'left'
                           )

# %%
# a look at the data
df_groupby_wb_nb
# Out:
#   WB_NB_CAT Lounge_eligibility_tier  pax_count  pax_count_ttl
# 0        NB            Not eligible    9741188       12779888
# 1        NB                  Tier 1      53292       12779888
# 2        NB                  Tier 2     744829       12779888
# 3        NB                  Tier 3    2240579       12779888
# 4        WB            Not eligible    5730922        7882572
# 5        WB                  Tier 1     236775        7882572
# 6        WB                  Tier 2     391264        7882572
# 7        WB                  Tier 3    1523611        7882572

# %%
# getting the percentage of pax elegible for each of the Tiers

df_groupby_wb_nb['pax_eligible%'] = (df_groupby_wb_nb['pax_count'] / df_groupby_wb_nb['pax_count_ttl'] )*100 

# getting the pax_elegible% column in the right format
df_groupby_wb_nb['pax_eligible%'] = df_groupby_wb_nb['pax_eligible%'].map('{:,.1f}%'.format)

# %%
# dropping pax_count, pax_count_ttl columns - not needed anymore
df_groupby_wb_nb.drop(columns=['pax_count','pax_count_ttl'],inplace = True)

# %%
# a look at the data
df_groupby_wb_nb
# Out:
#   WB_NB_CAT Lounge_eligibility_tier pax_eligible%
# 0        NB            Not eligible         76.2%
# 1        NB                  Tier 1          0.4%
# 2        NB                  Tier 2          5.8%
# 3        NB                  Tier 3         17.5%
# 4        WB            Not eligible         72.7%
# 5        WB                  Tier 1          3.0%
# 6        WB                  Tier 2          5.0%
# 7        WB                  Tier 3         19.3%

# %%
# dropping 'not eligible' rows - not needed anymore
mask = df_groupby_wb_nb['Lounge_eligibility_tier'] == 'Not eligible'

df_groupby_wb_nb = df_groupby_wb_nb[~mask].copy()

# %% [markdown]
# <br>
#
# Please save your final lookup table below in the form of a pandas dataframe. It must contain the categories you have come up with as rows, and the Tier 1, Tier 2, and Tier 3 percentage of costumers as columns.

# %%
# using set_index to come up with the final lookup table
df_groupby_wb_nb = df_groupby_wb_nb.set_index(['WB_NB_CAT','Lounge_eligibility_tier'],drop = True).unstack('Lounge_eligibility_tier')

# %%
# final table
df_groupby_wb_nb
# Out:
#                         pax_eligible%
# Lounge_eligibility_tier        Tier 1 Tier 2 Tier 3
# WB_NB_CAT
# NB                               0.4%   5.8%  17.5%
# WB                               3.0%   5.0%  19.3%

# %% [markdown]
# <br>
#
# **Feedback:** This analysis provides a lookup table in the format needed to be input into a future schedule. Nevertheless, this analysis is too high level and you haven't provided any evidence for your assumptions. To further enhance your answer use insights from the data and provide evidence for your assumptions. Please find some ideas below:
#
# - Using the same categories (WB,NB), plot data overtime to better understand the peaks for the different lounges.
# - Is there a way to split Widebody into more categories? Do the Haul, Region, Time of Day, or Country play a role in the number of passengers that are eligible in Tier 1, Tier 2 and Tier 3? Etc...

# %% [markdown]
# <br><br>
#
# **Reasoning (Example 2)**:

# %% [markdown]
# <u>What level of granularity do you use?</u>
# - I have decided to split all flights in the network based on their flight number. I will therefore have a lookup table with a lot of categories as each flight number is a category.
#
# <u>What metric do you use to come up with Lounge eligibility profiles?</u>
# - I have sumed up all the passengers by flight number, by Tier. Then I have divided them by the total number of passengers flight number.

# %%
# your code here!

# %%
# columns that you want to group by
list_groupby = ['OPERATING_FLT_NO','DISCHARGE_STN_CD','Lounge_eligibility_tier']

# grouping by OPERATING_FLT_NO, DISCHARGE_STN_CD and Lounge_eligibility_tier
df_groupby_flt_no = df_lounge_elig_flight_info_country_acft_typ.groupby(list_groupby).agg(
                pax_count = ('pax','sum')
).reset_index()

# a look at the data
df_groupby_flt_no.head(4)
# Out:
#    OPERATING_FLT_NO DISCHARGE_STN_CD Lounge_eligibility_tier  pax_count
# 0                 5              HND            Not eligible      15825
# 1                 5              HND                  Tier 1        220
# 2                 5              HND                  Tier 2        888
# 3                 5              HND                  Tier 3       4469

# %%
# getting the number of pax by OPERATING_FLT_NO and DISCHARGE_STN_CD

# columns that you want to group by
list_groupby = ['OPERATING_FLT_NO','DISCHARGE_STN_CD']

# grouping by WB_NB_CAT
df_groupby_flt_no_ttl = df_lounge_elig_flight_info_country_acft_typ.groupby(list_groupby).agg(
                pax_count_ttl = ('pax','sum')
).reset_index()

# %%
# a look at the data
df_groupby_flt_no_ttl.head(2)
# Out:
#    OPERATING_FLT_NO DISCHARGE_STN_CD  pax_count_ttl
# 0                 5              HND          21402
# 1                 5              NRT          38378

# %%
# now, let's left join df_groupby_flt_no_ttl onto df_groupby_flt_no
# this adds a new column to the df_groupby_flt_no table (pax_count_ttl) that will be used to get the percentage of passenger eligible by Tier

df_groupby_flt_no = pd.merge(df_groupby_flt_no,
                            df_groupby_flt_no_ttl,
                            on = ['OPERATING_FLT_NO','DISCHARGE_STN_CD'],
                            how = 'left'
                           )

# %%
# a look at the data
df_groupby_flt_no.head(4)
# Out:
#    OPERATING_FLT_NO DISCHARGE_STN_CD Lounge_eligibility_tier  pax_count  pax_count_ttl
# 0                 5              HND            Not eligible      15825          21402
# 1                 5              HND                  Tier 1        220          21402
# 2                 5              HND                  Tier 2        888          21402
# 3                 5              HND                  Tier 3       4469          21402

# %%
# getting the percentage of pax elegible for each of the Tiers

df_groupby_flt_no['pax_eligible%'] = (df_groupby_flt_no['pax_count'] / df_groupby_flt_no['pax_count_ttl'] )*100 

# getting the pax_elegible% column in the right format
df_groupby_flt_no['pax_eligible%'] = df_groupby_flt_no['pax_eligible%'].map('{:,.1f}%'.format)

# dropping pax_count, pax_count_ttl columns - not needed anymore
df_groupby_flt_no.drop(columns=['pax_count','pax_count_ttl'],inplace = True)

# %%
# a look at the data
df_groupby_flt_no.head(4)
# Out:
#    OPERATING_FLT_NO DISCHARGE_STN_CD Lounge_eligibility_tier pax_eligible%
# 0                 5              HND            Not eligible         73.9%
# 1                 5              HND                  Tier 1          1.0%
# 2                 5              HND                  Tier 2          4.1%
# 3                 5              HND                  Tier 3         20.9%

# %%
# dropping 'not eligible' rows - not needed anymore
mask = df_groupby_flt_no['Lounge_eligibility_tier'] == 'Not eligible'

df_groupby_flt_no = df_groupby_flt_no[~mask].copy()

# %% [markdown]
# <br>
#
# Please save your final lookup table below in the form of a pandas dataframe. It must contain the categories you have come up with as rows, and the Tier 1, Tier 2, and Tier 3 percentage of costumers as columns.

# %%
# using set_index to come up with the final lookup table
df_groupby_flt_no = df_groupby_flt_no.set_index(['OPERATING_FLT_NO','DISCHARGE_STN_CD','Lounge_eligibility_tier'],drop = True).unstack('Lounge_eligibility_tier')

# %%
# final table
df_groupby_flt_no.head(4)
# Out:
#                                   pax_eligible%
# Lounge_eligibility_tier                  Tier 1 Tier 2 Tier 3
# OPERATING_FLT_NO DISCHARGE_STN_CD
# 5                HND                       1.0%   4.1%  20.9%
#                  NRT                       3.6%   4.8%  19.1%
# 7                HND                       3.3%   5.2%  19.8%
# 9                BKK                       0.3%   4.2%  15.9%

# %% [markdown]
# <br>
#
# **Feedback:** This analysis goes at a very granular level, we might come up with missing values if we apply this lounge eligibility profiles to a future schedule. Here are some ideas to further enhance your answer:
#
# - What would happen if we fly to a new destination in the future? How do we ensure we have a lounge eligibility profile for this new route?
# - As you can see in the example above: Pax eligible for Tier 1 for the BKK flight is significantly different from the rest. What's the most used aircraft type for this route? And why it differs that much from the rest? Is it because of the route characteristics instead?
# - For SH routes, we might change the time of departure for a specific flight number from one year to the next. Explore the possibility of using a clasification that takes that into account, like using Time of Day instead of flight number.

# %% [markdown]
# ### Ian
# First of all I would like to be able to split the data into 2019/23 data separately, which can be done by adding a year field into the table.

# %%
# Original merged table
headers_and_first_row(df_lounge_elig_flight_info_country_acft_typ)
# Out:
# {'Skew_Id': '2023-08-05618',
#  'OPERATING_AIRLINE_CD': 'BA',
#  'OPERATING_FLT_NO': 618,
#  'GMT_UPLIFT_DT': datetime.date(2023, 8, 5),
#  'UPLIFT_STN_CD': 'LHR',
#  'DISCHARGE_STN_CD': 'OLB',
#  'BOOKED_CABIN_CD': 'C',
#  'TRAVEL_CABIN_CD': 'C',
#  'BA_PAX_TIER': 'Gold For Life',
#  'ONEWORLD_TIER': 'EMER',
#  'Lounge_eligibility_tier': 'Tier 2',
#  'pax': 2,
#  'GMT_PLND_DEP_TS': Timestamp('2023-08-05 14:25:00'),
#  'GMT_ACT_DEP_TS': Timestamp('2023-08-05 14:57:00'),
#  'OPG_ALN_CD': 'BA',
#  'OPG_FLT_NO': 618.0,
#  'ACT_DEP_STN_CD': 'LHR',
#  'ACT_DEP_TML_CD': '3',
#  'PLND_ARR_STN_CD': 'OLB',
#  'ACT_ARR_STN_CD': 'OLB',
#  'IATA_AC_TYP_CD': '319',
#  'ACT_AC_TYP_CD': 'M4',
#  'ROUTE_x': 'LHROLB',
#  'GMT_PLND_DEP_DT': datetime.date(2023, 8, 5),
#  'GMT_PLND_DEP_TIME': datetime.time(14, 25),
#  'ROUTE_y': 'LHROLB',
#  'COUNTRY_CD': 'IT',
#  'COUNTRY_NM': 'Italy',
#  'CORP_GEOG_CTRY_GRP_NM': 'MEDITERRANEAN',
#  'CORP_GEOG_CONTINENT_NM': 'EUROPE EXC UK',
#  'DEP_STN_CD': 'LHR',
#  'ARR_STN_CD': 'OLB',
#  'WB_NB_CAT': 'NB',
#  'FIRST_SEATS_QTY': 0.0,
#  'CLUB_SEATS_QTY': 21.0,
#  'PREM_ECONOMY_SEATS_QTY': 0.0,
#  'ECONOMY_SEATS_QTY': 113.0,
#  'GMT_UPLIFT_YR': 2023}

# %%
# # df_lounge_elig_flight_info_country_acft_typ['GMT_PLND_DEPT_YR'] = df_lounge_elig_flight_info_country_acft_typ['GMT_PLND_DEP_DT'].year

# # headers_and_first_row(df_lounge_elig_flight_info_country_acft_typ)
# df_lounge_elig_flight_info_country_acft_typ['GMT_UPLIFT_YR'] = [dts.year for dts in df_lounge_elig_flight_info_country_acft_typ['GMT_UPLIFT_DT']]

# df_lounge_elig_flight_info_country_acft_typ.head(10)

# %%
# columns that you want to group by
list_groupby = ['GMT_UPLIFT_YR','Lounge_eligibility_tier']

# grouping by OPERATING_FLT_NO, DISCHARGE_STN_CD and Lounge_eligibility_tier
df_groupby_year = df_lounge_elig_flight_info_country_acft_typ.groupby(list_groupby).agg(
                pax_count = ('pax','sum')
).reset_index()

# a look at the data
df_groupby_year
# Out:
#    GMT_UPLIFT_YR Lounge_eligibility_tier  pax_count
# 0           2019            Not eligible    8147159
# 1           2019                  Tier 1     196564
# 2           2019                  Tier 2     635765
# 3           2019                  Tier 3    1996226
# 4           2023            Not eligible    7372440
# 5           2023                  Tier 1      93555
# 6           2023                  Tier 2     501044
# 7           2023                  Tier 3    1770087

# %% [markdown]
# ### Linear Regression

# %%
# import numpy as np
# from sklearn import datasets, linear_model
# import matplotlib.pyplot as plt

# %%
# headers_and_first_row(df_lounge_elig_flight_info_country_acft_typ)

# %% [markdown]
# Separate the large tables to different tiers

# %%
# df_merged_T1 = df_lounge_elig_flight_info_country_acft_typ[df_lounge_elig_flight_info_country_acft_typ['Lounge_eligibility_tier'] == 'Tier 1'].reset_index()
# df_merged_T2 = df_lounge_elig_flight_info_country_acft_typ[df_lounge_elig_flight_info_country_acft_typ['Lounge_eligibility_tier'] == 'Tier 2'].reset_index()
# df_merged_T3 = df_lounge_elig_flight_info_country_acft_typ[df_lounge_elig_flight_info_country_acft_typ['Lounge_eligibility_tier'] == 'Tier 3'].reset_index()

# df_merged_T1 = df_merged_T1.rename(columns={'pax':'Tier_1_pax'})
# df_merged_T2 = df_merged_T2.rename(columns={'pax':'Tier_2_pax'})
# df_merged_T3 = df_merged_T3.rename(columns={'pax':'Tier_3_pax'})

# %%
# df_merged_T3.columns
# headers_and_first_row(df_merged_T1)

# %%
# y = np.array([1,2,3])
# x = np.array([-1,0,1])

# # y = y.to_numpy()
# # x = x.to_numpy().reshape(-1, 1)
# x = x.reshape(-1,1)

# # print(x.shape, y.shape)

# regr = linear_model.LinearRegression()
# regr.fit(x,y)

# regr.coef_, regr.intercept_, regr.rank_

# %% [markdown]
# ### Compare by Year

# %%
# columns that you want to group by
list_groupby = ['GMT_UPLIFT_YR']

# grouping by OPERATING_FLT_NO, DISCHARGE_STN_CD and Lounge_eligibility_tier
df_groupby_year_ttl = df_lounge_elig_flight_info_country_acft_typ.groupby(list_groupby).agg(
                pax_count_ttl = ('pax','sum')
).reset_index()

# a look at the data
df_groupby_year_ttl
# Out:
#    GMT_UPLIFT_YR  pax_count_ttl
# 0           2019       10975714
# 1           2023        9737126

# %%
df_groupby_year = pd.merge(df_groupby_year,
                            df_groupby_year_ttl,
                            on = ['GMT_UPLIFT_YR'],
                            how = 'left'
                           )

df_groupby_year
# Out:
#    GMT_UPLIFT_YR Lounge_eligibility_tier  pax_count  pax_count_ttl
# 0           2019            Not eligible    8147159       10975714
# 1           2019                  Tier 1     196564       10975714
# 2           2019                  Tier 2     635765       10975714
# 3           2019                  Tier 3    1996226       10975714
# 4           2023            Not eligible    7372440        9737126
# 5           2023                  Tier 1      93555        9737126
# 6           2023                  Tier 2     501044        9737126
# 7           2023                  Tier 3    1770087        9737126

# %%
# getting the percentage of pax elegible for each of the Tiers

df_groupby_year['pax_eligible%'] = (df_groupby_year['pax_count'] / df_groupby_year['pax_count_ttl'] )*100 

# getting the pax_elegible% column in the right format
df_groupby_year['pax_eligible%'] = df_groupby_year['pax_eligible%'].map('{:,.1f}%'.format)

# dropping pax_count, pax_count_ttl columns - not needed anymore
df_groupby_year.drop(columns=['pax_count','pax_count_ttl'],inplace = True)

# %%
df_groupby_year = df_groupby_year[df_groupby_year['Lounge_eligibility_tier'] != "Not eligible"]

df_groupby_year
# Out:
#    GMT_UPLIFT_YR Lounge_eligibility_tier pax_eligible%
# 1           2019                  Tier 1          1.8%
# 2           2019                  Tier 2          5.8%
# 3           2019                  Tier 3         18.2%
# 5           2023                  Tier 1          1.0%
# 6           2023                  Tier 2          5.1%
# 7           2023                  Tier 3         18.2%

# %% [markdown]
# Not much difference

# %% [markdown]
# ### Compare by location and year

# %%
# columns that you want to group by
list_groupby = ['CORP_GEOG_CONTINENT_NM','CORP_GEOG_CTRY_GRP_NM','GMT_UPLIFT_YR','Lounge_eligibility_tier']

# grouping by OPERATING_FLT_NO, DISCHARGE_STN_CD and Lounge_eligibility_tier
df_groupby_country_group_year = df_lounge_elig_flight_info_country_acft_typ.groupby(list_groupby).agg(
                pax_count = ('pax','sum')
).reset_index()

list_groupby = ['CORP_GEOG_CONTINENT_NM','CORP_GEOG_CTRY_GRP_NM','GMT_UPLIFT_YR']

df_groupby_country_group_year_ttl = df_lounge_elig_flight_info_country_acft_typ.groupby(list_groupby).agg(
                pax_count_ttl = ('pax','sum')
).reset_index()

df_groupby_country_group_year = pd.merge(df_groupby_country_group_year,
                                         df_groupby_country_group_year_ttl,
                                         on = list_groupby,
                                         how = "left")

df_groupby_country_group_year = df_groupby_country_group_year[df_groupby_country_group_year['Lounge_eligibility_tier'] != 'Not eligible']

df_groupby_country_group_year['pax_eligible%'] = (df_groupby_country_group_year['pax_count'] / df_groupby_country_group_year['pax_count_ttl'] )*100 

# getting the pax_elegible% column in the right format
df_groupby_country_group_year['pax_eligible%'] = df_groupby_country_group_year['pax_eligible%'].map('{:,.1f}%'.format)

# dropping pax_count, pax_count_ttl columns - not needed anymore
df_groupby_country_group_year.drop(columns=['pax_count','pax_count_ttl'],inplace = True)

df_groupby_country_group_year.head(6)
# Out:
#   CORP_GEOG_CONTINENT_NM    CORP_GEOG_CTRY_GRP_NM  GMT_UPLIFT_YR Lounge_eligibility_tier pax_eligible%
# 1                 AFRICA  EAST AND CENTRAL AFRICA           2019                  Tier 1          3.7%
# 2                 AFRICA  EAST AND CENTRAL AFRICA           2019                  Tier 2          4.0%
# 3                 AFRICA  EAST AND CENTRAL AFRICA           2019                  Tier 3         17.6%
# 5                 AFRICA  EAST AND CENTRAL AFRICA           2023                  Tier 1          0.2%
# 6                 AFRICA  EAST AND CENTRAL AFRICA           2023                  Tier 2          4.3%
# 7                 AFRICA  EAST AND CENTRAL AFRICA           2023                  Tier 3         16.0%

# %%
df_groupby_country_group_year = df_groupby_country_group_year.set_index(['CORP_GEOG_CONTINENT_NM','CORP_GEOG_CTRY_GRP_NM','GMT_UPLIFT_YR','Lounge_eligibility_tier'],drop = True).unstack('Lounge_eligibility_tier')

df_groupby_country_group_year
# Out:
#                                                                   pax_eligible%
# Lounge_eligibility_tier                                                  Tier 1 Tier 2 Tier 3
# CORP_GEOG_CONTINENT_NM      CORP_GEOG_CTRY_GRP_NM   GMT_UPLIFT_YR
# AFRICA                      EAST AND CENTRAL AFRICA 2019                   3.7%   4.0%  17.6%
#                                                     2023                   0.2%   4.3%  16.0%
#                             NORTH AFRICA            2019                   0.5%   4.9%  20.9%
#                                                     2023                   0.3%   3.6%  19.4%
#                             SOUTHERN AFRICA         2019                   3.8%   5.3%  20.2%
#                                                     2023                   2.4%   4.4%  18.7%
#                             WEST AFRICA             2019                   3.7%   4.5%  16.0%
#                                                     2023                   2.3%   4.5%  17.2%
# ASIA FAR EAST               CHINA                   2019                   4.6%   4.2%  18.8%
#                                                     2023                   0.2%   2.6%  19.4%
#                             FAR EAST HUBS           2019                   3.8%   5.4%  18.5%
#                                                     2023                   1.4%   3.4%  16.2%
#                             FAR EAST OTHER          2019                   0.4%   3.8%  15.5%
#                             JAPAN                   2019                   3.5%   4.8%  18.6%
#                                                     2023                   1.0%   4.4%  20.8%
# ASIA SOUTH EAST AND CENTRAL SOUTH ASIA              2019                   2.8%   4.0%  19.1%
#                                                     2023                   0.4%   3.0%  17.0%
# AUSTRALASIA PACIFIC         FAR EAST JSA HUBS       2019                   2.3%   5.6%  18.3%
#                                                     2023                   3.4%   7.4%  26.3%
# EUROPE EXC UK               BENELUX                 2019                   0.7%   8.3%  18.3%
#                                                     2023                   0.5%   6.3%  15.5%
#                             EASTERN EUROPE          2019                   0.5%   4.8%  14.4%
#                                                     2023                   0.2%   4.2%  15.3%
#                             IRELAND RO              2019                   0.6%   6.6%  17.2%
#                                                     2023                   0.6%   6.3%  17.2%
#                             MEDITERRANEAN           2019                   0.7%   5.6%  17.9%
#                                                     2023                   0.3%   5.3%  20.7%
#                             SCANDINAVIA             2019                   0.6%   6.7%  16.0%
#                                                     2023                   0.4%   6.0%  16.5%
#                             WEST EUROPE             2019                   0.5%   6.8%  17.3%
#                                                     2023                   0.4%   5.7%  17.6%
# MIDDLE EAST                 MIDDLE EAST OTHER       2019                   0.3%   4.7%  14.8%
#                                                     2023                   0.1%   3.6%  17.9%
#                             NORTHERN GULF           2019                   5.0%   4.8%  23.4%
#                                                     2023                   3.0%   3.0%  17.8%
#                             SAUDI ARABIA            2019                   4.0%   6.6%  23.6%
#                                                     2023                   3.5%   7.8%  21.5%
#                             SOUTHERN GULF           2019                   4.8%   6.6%  19.2%
#                                                     2023                   3.6%   5.5%  18.7%
# NORTH AMERICA               CANADA                  2019                   2.3%   3.5%  17.5%
#                                                     2023                   0.2%   3.4%  17.3%
#                             NORTH AMERICA OTHER     2023                   3.6%  10.6%  20.1%
#                             USA                     2019                   4.3%   5.4%  20.8%
#                                                     2023                   2.4%   5.2%  19.4%
# SOUTH AMERICA INC CARIBBEAN CARIBBEAN               2019                    NaN   7.3%  20.2%
#                                                     2023                   2.7%   3.7%  20.2%
#                             CENTRAL AMERICA         2019                   3.9%   4.2%  17.9%
#                                                     2023                   3.6%   2.5%  17.2%
#                             SOUTH AMERICA           2019                   2.1%   3.5%  17.3%
#                                                     2023                   0.6%   3.0%  16.4%
# UK                          UK                      2019                   0.4%   5.7%  18.1%
#                                                     2023                   0.4%   5.0%  16.8%

# %% [markdown]
# ### By continent

# %%
# columns that you want to group by
list_groupby = ['CORP_GEOG_CONTINENT_NM','GMT_UPLIFT_YR','Lounge_eligibility_tier']

# grouping by OPERATING_FLT_NO, DISCHARGE_STN_CD and Lounge_eligibility_tier
df_groupby_cont_year = df_lounge_elig_flight_info_country_acft_typ.groupby(list_groupby).agg(
                pax_count = ('pax','sum')
).reset_index()

list_groupby = ['CORP_GEOG_CONTINENT_NM','GMT_UPLIFT_YR']

df_groupby_cont_year_ttl = df_lounge_elig_flight_info_country_acft_typ.groupby(list_groupby).agg(
                pax_count_ttl = ('pax','sum')
).reset_index()

df_groupby_cont_year = pd.merge(df_groupby_cont_year,
                                df_groupby_cont_year_ttl,
                                on = list_groupby,
                                how = "left")

df_groupby_cont_year = df_groupby_cont_year[df_groupby_cont_year['Lounge_eligibility_tier'] != 'Not eligible']

df_groupby_cont_year['pax_eligible%'] = (df_groupby_cont_year['pax_count'] / df_groupby_cont_year['pax_count_ttl'] )*100 

# getting the pax_elegible% column in the right format
df_groupby_cont_year['pax_eligible%'] = df_groupby_cont_year['pax_eligible%'].map('{:,.1f}%'.format)

# dropping pax_count, pax_count_ttl columns - not needed anymore
df_groupby_cont_year.drop(columns=['pax_count','pax_count_ttl'],inplace = True)

df_groupby_cont_year.head(6)
# Out:
#   CORP_GEOG_CONTINENT_NM  GMT_UPLIFT_YR Lounge_eligibility_tier pax_eligible%
# 1                 AFRICA           2019                  Tier 1          3.5%
# 2                 AFRICA           2019                  Tier 2          4.8%
# 3                 AFRICA           2019                  Tier 3         18.5%
# 5                 AFRICA           2023                  Tier 1          1.7%
# 6                 AFRICA           2023                  Tier 2          4.3%
# 7                 AFRICA           2023                  Tier 3         18.2%

# %%
df_groupby_cont_year = df_groupby_cont_year.set_index(['CORP_GEOG_CONTINENT_NM','GMT_UPLIFT_YR','Lounge_eligibility_tier'],drop = True).unstack('Lounge_eligibility_tier')

df_groupby_cont_year
# Out:
#                                           pax_eligible%
# Lounge_eligibility_tier                          Tier 1 Tier 2 Tier 3
# CORP_GEOG_CONTINENT_NM      GMT_UPLIFT_YR
# AFRICA                      2019                   3.5%   4.8%  18.5%
#                             2023                   1.7%   4.3%  18.2%
# ASIA FAR EAST               2019                   3.6%   4.8%  18.3%
#                             2023                   1.0%   3.5%  18.3%
# ASIA SOUTH EAST AND CENTRAL 2019                   2.8%   4.0%  19.1%
#                             2023                   0.4%   3.0%  17.0%
# AUSTRALASIA PACIFIC         2019                   2.3%   5.6%  18.3%
#                             2023                   3.4%   7.4%  26.3%
# EUROPE EXC UK               2019                   0.6%   6.4%  17.1%
#                             2023                   0.4%   5.5%  18.1%
# MIDDLE EAST                 2019                   4.0%   6.0%  20.2%
#                             2023                   3.1%   5.0%  18.8%
# NORTH AMERICA               2019                   4.1%   5.2%  20.5%
#                             2023                   2.3%   5.1%  19.2%
# SOUTH AMERICA INC CARIBBEAN 2019                   2.4%   3.6%  17.4%
#                             2023                   1.5%   3.1%  17.3%
# UK                          2019                   0.4%   5.7%  18.1%
#                             2023                   0.4%   5.0%  16.8%

# %% [markdown]
# ### By aircraft

# %%
list_groupby = ['IATA_AC_TYP_CD','ACT_AC_TYP_CD','FIRST_SEATS_QTY','CLUB_SEATS_QTY','PREM_ECONOMY_SEATS_QTY','ECONOMY_SEATS_QTY','Lounge_eligibility_tier']

# grouping by OPERATING_FLT_NO, DISCHARGE_STN_CD and Lounge_eligibility_tier
df_groupby_acft = df_lounge_elig_flight_info_country_acft_typ.groupby(list_groupby).agg(
                mean_pax_count = ('pax','mean')).reset_index()

df_groupby_acft['mean_pax_count'] = df_groupby_acft['mean_pax_count'].map('{:,.1f}'.format)

df_groupby_acft = df_groupby_acft[df_groupby_acft['Lounge_eligibility_tier'] != 'Not eligible']

df_groupby_acft = df_groupby_acft.set_index(list_groupby,drop = True).unstack('Lounge_eligibility_tier')

df_groupby_acft.fillna(0, inplace=True)

df_groupby_acft
# Out:
#                                                                                                      mean_pax_count
# Lounge_eligibility_tier                                                                                      Tier 1 Tier 2 Tier 3
# IATA_AC_TYP_CD ACT_AC_TYP_CD FIRST_SEATS_QTY CLUB_SEATS_QTY PREM_ECONOMY_SEATS_QTY ECONOMY_SEATS_QTY
# 319            A4            0.0             16.0           0.0                    119.0                        1.2    2.1    4.6
#                M4            0.0             21.0           0.0                    113.0                        1.1    1.8    4.3
# 320            A3            0.0             24.0           0.0                    132.0                        1.2    2.2    5.0
#                E9            0.0             29.0           0.0                    130.0                        1.2    2.0    5.7
#                M2            0.0             24.0           0.0                    144.0                        1.1    1.9    4.9
#                R3            0.0             28.0           0.0                    139.0                        1.2    2.1    5.4
#                T3            0.0             26.0           0.0                    142.0                        1.2    1.9    5.3
# 321            M6            0.0             23.0           0.0                    131.0                        1.3    2.0    3.9
#                V6            0.0             38.0           0.0                    160.0                        1.2    2.5    5.9
#                W6            0.0             42.0           0.0                    154.0                        1.3    2.4    5.8
# 32A            H3            0.0             20.0           0.0                    150.0                        1.2    2.2    5.4
# 32N            N3            0.0             20.0           0.0                    150.0                        1.2    2.2    5.5
# 32Q            N6            0.0             32.0           0.0                    172.0                        1.2    2.3    6.4
# 332            W9            0.0             30.0           21.0                   235.0                        1.0    1.7    3.9
# 339            W9            0.0             30.0           21.0                   234.0                        1.1    1.9    3.9
# 343            W9            0.0             45.0           0.0                    212.0                        1.3    2.2    6.2
# 351            K5            0.0             56.0           56.0                   219.0                        1.3    2.3    6.6
# 388            A8            14.0            97.0           55.0                   303.0                        2.2    3.0    8.9
# 744            S4            14.0            86.0           30.0                   145.0                        2.1    2.7    7.7
#                V4            14.0            52.0           36.0                   235.0                        2.1    2.1    5.9
# 777            D7            0.0             48.0           40.0                   184.0                        1.3    2.1    6.3
#                J7            0.0             32.0           48.0                   252.0                          0    2.0    4.8
#                K7            0.0             48.0           24.0                   203.0                          0    2.0    7.0
#                L7            0.0             48.0           24.0                   203.0                        1.3    2.2    6.1
#                M7            7.0             50.0           40.0                   138.0                        1.6    2.3    5.4
#                P7            17.0            48.0           24.0                   127.0                        2.1    2.1    5.3
#                R7            10.0            52.0           40.0                   134.0                        1.7    2.3    4.8
#                V7            14.0            48.0           40.0                   124.0                        2.1    2.2    5.5
#                W7            12.0            48.0           32.0                   127.0                        2.0    2.2    5.8
# 77W            F7            8.0             76.0           40.0                   130.0                        1.7    2.6    7.4
#                G7            14.0            56.0           44.0                   183.0                        2.1    2.3    6.3
# 781            X8            7.0             49.0           35.0                   165.0                        1.7    2.0    5.8
# 788            B8            0.0             35.0           25.0                   154.0                        1.2    1.7    5.0
# 789            L8            8.0             42.0           39.0                   127.0                        1.7    2.0    5.2

# %% [markdown]
# <br><br><br>

# %%
#--------------------------------
#
# Your turn!!!
#
#--------------------------------

# %% [markdown]
# <u>What level of granularity do you use?</u>
# - ... (your answer here)
#
# <u>What metric do you use to come up with Lounge eligibility profiles?</u>
# - ... (your answer here)

# %%
# your code here

# %% [markdown]
# <br>
#
# Please save your final lookup table below in the form of a pandas dataframe. It must contain the categories you have come up with as rows, and the Tier 1, Tier 2, and Tier 3 percentage of costumers as columns.
