# %% [markdown]
# # Ian's Data Discovery

# %% [markdown]
# ## All the tables
# Just to get all the tables first

# %%
import cadspy
import numpy as np
import pandas as pd
import datetime as dt

# %%
icw = cadspy.DatabaseConnection(system='ICW',user='u243696')

# %%
# diplay all rows and cols when using 'dataframe'.head() or 'dataframe'.tail()
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Lounge Eligibility Data

# %%
query = """

sel * from LDB_SBOX_OR.HACKATHON_OPS_LOUNGE_ELIGIBILITY

"""

df_lounge_eligibility = icw.queryToDataframe(query)

# %%
df_lounge_eligibility.head(5)
# Out:
#           Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 0  2019-08-101414               BA                  1414    2019-08-10
# 1   2023-05-17920               BA                   920    2023-05-17
# 2   2019-04-15770               BA                   770    2019-04-15
# 3   2019-09-23348               BA                   348    2019-09-23
# 4   2019-09-16155               BA                   155    2019-09-16
#
#   UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD BA_PAX_TIER  \
# 0        LHR              BHD                 M               M         Gold
# 1        LHR              STR                 C               C
# 2        LHR              OSL                 M               M
# 3        LHR              NCE                 M               M
# 4        LHR              CAI                 J               J
#
#   ONEWORLD_TIER Lounge_eligibility_tier  pax
# 0          EMER                  Tier 2    3
# 1                                Tier 3   13
# 2                          Not eligible   75
# 3          EMER                  Tier 2    6
# 4                                Tier 3   23

# %% [markdown]
# ### Flight Info

# %%
query = """

select * from LDB_SBOX_OR.HACKATHON_OPS_FLIGHT_INFO

"""

df_flight_info = icw.queryToDataframe(query)

# %%
df_flight_info.head(5)
# Out:
#   OPG_ALN_CD  OPG_FLT_NO     GMT_PLND_DEP_TS      GMT_ACT_DEP_TS  \
# 0     BA             548 2019-06-03 07:30:00 2019-06-03 07:27:00
# 1     BA             490 2019-06-12 10:35:00 2019-06-12 10:31:00
# 2     BA             386 2019-07-19 17:35:00 2019-07-19 18:14:00
# 3     BA             582 2019-05-22 19:35:00 2019-05-22 19:32:00
# 4     BA             275 2019-05-18 15:40:00 2019-05-18 15:38:00
#
#   ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD IATA_AC_TYP_CD  \
# 0         LHR                5           FCO            FCO            321
# 1         LHR                3           GIB            GIB            320
# 2         LHR                5           NTE            NTE            321
# 3         LHR                5           MXP            VRN            32A
# 4         LHR                3           LAS            LAS            744
#
#   ACT_AC_TYP_CD         ROUTE COUNTRY_CD     COUNTRY_NM CORP_GEOG_CTRY_GRP_NM  \
# 0          V6    LHRFCO           IT              Italy         MEDITERRANEAN
# 1          A3    LHRGIB           GI          Gibraltar         MEDITERRANEAN
# 2          V6    LHRNTE           FR             France           WEST EUROPE
# 3          H3    LHRMXP           IT              Italy         MEDITERRANEAN
# 4          V4    LHRLAS           US      United States                   USA
#
#   CORP_GEOG_CONTINENT_NM
# 0          EUROPE EXC UK
# 1          EUROPE EXC UK
# 2          EUROPE EXC UK
# 3          EUROPE EXC UK
# 4          NORTH AMERICA

# %% [markdown]
# ### Station Code Decode

# %%
query = """

select * from LDB_SBOX_OR.HACKATHON_OPS_COUNTRY_DECODE

"""

df_country = icw.queryToDataframe(query)

# %%
df_country.head(5)
# Out:
#     ROUTE COUNTRY_CD                           COUNTRY_NM  \
# 0  LHRINV        GB   United Kingdom and Northern Ireland
# 1  LHRSVO        RU                      Russia in Europe
# 2  LHREZE        AR                             Argentina
# 3  LHRLUX        LU                            Luxembourg
# 4  LHRCAI        EG                                 Egypt
#
#   CORP_GEOG_CTRY_GRP_NM       CORP_GEOG_CONTINENT_NM
# 0                    UK                           UK
# 1        EASTERN EUROPE                EUROPE EXC UK
# 2         SOUTH AMERICA  SOUTH AMERICA INC CARIBBEAN
# 3               BENELUX                EUROPE EXC UK
# 4          NORTH AFRICA                       AFRICA

# %% [markdown]
# ### Aircraft Type

# %%
query = """

select * from LDB_SBOX_OR.HACKATHON_OPS_AC_TYPE

"""

df_acft_typ = icw.queryToDataframe(query)

# %%
df_acft_typ
# Out:
#    IATA_AC_TYP_CD ACT_AC_TYP_CD WB_NB_CAT  FIRST_SEATS_QTY  CLUB_SEATS_QTY  \
# 0             320            A3        NB                0              24
# 1             777            K7        WB                0              48
# 2             32N            N3        NB                0              20
# 3             321            M6        NB                0              23
# 4             32Q            N6        NB                0              32
# 5             789            L8        WB                8              42
# 6             32A            H3        NB                0              20
# 7             319            A4        NB                0              16
# 8             788            B8        WB                0              35
# 9             77W            G7        WB               14              56
# 10            744            S4        WB               14              86
# 11            343            W9        WB                0              45
# 12            388            A8        WB               14              97
# 13            777            L7        WB                0              48
# 14            321            V6        NB                0              38
# 15            744            V4        WB               14              52
# 16            777            P7        WB               17              48
# 17            321            W6        NB                0              42
# 18            777            V7        WB               14              48
# 19            777            W7        WB               12              48
#
#     PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY
# 0                        0                132
# 1                       24                203
# 2                        0                150
# 3                        0                131
# 4                        0                172
# 5                       39                127
# 6                        0                150
# 7                        0                119
# 8                       25                154
# 9                       44                183
# 10                      30                145
# 11                       0                212
# 12                      55                303
# 13                      24                203
# 14                       0                160
# 15                      36                235
# 16                      24                127
# 17                       0                154
# 18                      40                124
# 19                      32                127

# %% [markdown]
# # Checkings
# Basically just to check duplicated data

# %% [markdown]
# ## 1. Loungue Eligibility
# Norally each Skew ID should only have one destination

# %% [markdown]
# - We first group the lpungue eligibility by Skew ID and flight number, showing the discharge station code and total passenegr

# %%
df_lounge_by_skew = df_lounge_eligibility.groupby(['Skew_Id','OPERATING_FLT_NO','DISCHARGE_STN_CD'], as_index = False).agg(pax_count = ('pax','sum'))

df_lounge_by_skew.head(5)
# Out:
#          Skew_Id  OPERATING_FLT_NO DISCHARGE_STN_CD  pax_count
# 0  2019-03-31103               103           YYC           197
# 1  2019-03-31105               105           DXB           209
# 2  2019-03-31107               107           DXB           201
# 3  2019-03-31109               109           DXB           217
# 4   2019-03-3111                11           SIN           443

# %% [markdown]
# - We then find all duplicated Skew ID's, and sorted by Skew ID for readability

# %%
duplicated_flag = df_lounge_by_skew.duplicated('Skew_Id',keep = False)

df_lounge_by_skew_duplicated = df_lounge_by_skew[duplicated_flag].sort_values(['Skew_Id','OPERATING_FLT_NO'])

df_lounge_by_skew_duplicated.head(20)
# Out:
#             Skew_Id  OPERATING_FLT_NO DISCHARGE_STN_CD  pax_count
# 38   2019-03-311448              1448           ABZ             1
# 39   2019-03-311448              1448           EDI           139
# 55     2019-03-3115                15           SIN           165
# 56     2019-03-3115                15           SYD           114
# 165   2019-03-31462               462           MAD           173
# 166   2019-03-31462               462           PHX            15
# 348  2019-04-011314              1314           ABZ           119
# 349  2019-04-011314              1314           BHD             1
# 395    2019-04-0115                15           SIN            97
# 396    2019-04-0115                15           SYD           114
# 436   2019-04-01253               253           GCM            87
# 437   2019-04-01253               253           NAS           181
# 697  2019-04-021318              1318           ABZ            98
# 698  2019-04-021318              1318           EDI             1
# 726  2019-04-021448              1448           ABZ             1
# 727  2019-04-021448              1448           EDI           109
# 745    2019-04-0215                15           SIN           114
# 746    2019-04-0215                15           SYD           145
# 853   2019-04-02462               462           MAD            86
# 854   2019-04-02462               462           PHX             3

# %%
df_lounge_by_skew_duplicated.tail(10)
# Out:
#               Skew_Id  OPERATING_FLT_NO DISCHARGE_STN_CD  pax_count
# 133890  2023-10-12253               253           NAS            87
# 133891  2023-10-12253               253           PLS            72
# 133928  2023-10-12362               362           GLA            13
# 133929  2023-10-12362               362           LYS            88
# 133940  2023-10-12404               404           BRU            10
# 133941  2023-10-12404               404           WAW             5
# 133989  2023-10-12554               554           EDI             1
# 133990  2023-10-12554               554           FCO            61
# 134009  2023-10-12606               606           GLA             2
# 134010  2023-10-12606               606           PSA            83

# %% [markdown]
# - Check Flight 1448 on 2019-3-31

# %%
df_flight_info[(df_flight_info['OPG_FLT_NO'] == 1448) & (pd.to_datetime(df_flight_info['GMT_PLND_DEP_TS']).dt.date == dt.date(2019,3,31))]
# Out:
#        OPG_ALN_CD  OPG_FLT_NO     GMT_PLND_DEP_TS      GMT_ACT_DEP_TS  \
# 101260     BA            1448 2019-03-31 14:20:00 2019-03-31 14:24:00
#
#        ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD  \
# 101260         LHR                5           EDI            EDI
#
#        IATA_AC_TYP_CD ACT_AC_TYP_CD         ROUTE COUNTRY_CD  \
# 101260         320             A3    LHREDI           GB
#
#                                  COUNTRY_NM CORP_GEOG_CTRY_GRP_NM  \
# 101260  United Kingdom and Northern Ireland                    UK
#
#        CORP_GEOG_CONTINENT_NM
# 101260                     UK

# %% [markdown]
# Has the flight ever flew to Aberdeen?

# %% [markdown]
# - Check Flight 15 on 2019-3-31

# %%
df_flight_info[(df_flight_info['OPG_FLT_NO'] == 15) & (pd.to_datetime(df_flight_info['GMT_PLND_DEP_TS']).dt.date == dt.date(2019,3,31))]
# Out:
#       OPG_ALN_CD  OPG_FLT_NO     GMT_PLND_DEP_TS      GMT_ACT_DEP_TS  \
# 80189     BA              15 2019-03-31 20:30:00 2019-03-31 20:36:00
#
#       ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD  \
# 80189         LHR                5           SIN            SIN
#
#       IATA_AC_TYP_CD ACT_AC_TYP_CD         ROUTE COUNTRY_CD COUNTRY_NM  \
# 80189         77W             G7    LHRSIN           SG      Singapore
#
#       CORP_GEOG_CTRY_GRP_NM CORP_GEOG_CONTINENT_NM
# 80189     FAR EAST JSA HUBS    AUSTRALASIA PACIFIC

# %% [markdown]
# No record to Sydney? Let's check for any flight to Sydney

# %%
df_flight_info[(df_flight_info['PLND_ARR_STN_CD']=="SYD") | (df_flight_info['ACT_ARR_STN_CD']=="SYD")]
# Out:
# Empty DataFrame
# Columns: [OPG_ALN_CD, OPG_FLT_NO, GMT_PLND_DEP_TS, GMT_ACT_DEP_TS, ACT_DEP_STN_CD, ACT_DEP_TML_CD, PLND_ARR_STN_CD, ACT_ARR_STN_CD, IATA_AC_TYP_CD, ACT_AC_TYP_CD, ROUTE, COUNTRY_CD, COUNTRY_NM, CORP_GEOG_CTRY_GRP_NM, CORP_GEOG_CONTINENT_NM]
# Index: []

# %% [markdown]
# No record to sydney, is it because already included into the LHR-SIN route?

# %% [markdown]
# ## 2. Flight Info
#
# Check if there is any duplicated flights

# %%
duplicated_flag = df_flight_info.duplicated(subset=['OPG_FLT_NO','GMT_PLND_DEP_TS'],keep=False)
df_flight_info_duplicated = df_flight_info[duplicated_flag].sort_values(['OPG_FLT_NO','GMT_PLND_DEP_TS','GMT_ACT_DEP_TS'])
df_flight_info_duplicated = df_flight_info_duplicated[['OPG_FLT_NO','GMT_PLND_DEP_TS','GMT_ACT_DEP_TS','ROUTE','PLND_ARR_STN_CD','ACT_ARR_STN_CD']]

df_flight_info_duplicated.head(10)
# Out:
#        OPG_FLT_NO     GMT_PLND_DEP_TS      GMT_ACT_DEP_TS         ROUTE  \
# 6366           31 2023-09-06 17:00:00 2023-09-06 17:29:00  LHRLHR
# 63963          31 2023-09-06 17:00:00 2023-09-07 16:59:00  LHRHKG
# 5050           55 2023-08-06 18:05:00 2023-08-06 18:21:00  LHRLHR
# 70885          55 2023-08-06 18:05:00 2023-08-07 22:17:00  LHRJNB
# 4604           65 2023-04-15 09:10:00 2023-04-15 09:13:00  LHRLHR
# 41149          65 2023-04-15 09:10:00 2023-04-15 20:55:00  LHRNBO
# 1285          119 2019-07-03 13:15:00 2019-07-03 14:01:00  LHRBLR
# 3349          119 2019-07-03 13:15:00 2019-07-03 20:28:00  LHRBLR
# 3705          207 2023-06-22 09:25:00 2023-06-22 11:11:00  LHRLHR
# 65148         207 2023-06-22 09:25:00 2023-06-23 14:15:00  LHRMIA
#
#       PLND_ARR_STN_CD ACT_ARR_STN_CD
# 6366           HKG            LHR
# 63963          HKG            HKG
# 5050           JNB            LHR
# 70885          JNB            JNB
# 4604           NBO            LHR
# 41149          NBO            NBO
# 1285           BLR            LHR
# 3349           BLR            BLR
# 3705           MIA            LHR
# 65148          MIA            MIA

# %% [markdown]
# It seesm like the flightd are just being rescheduled.
#
# Let's also check if the LHRLHR route actually exists

# %%
df_country[df_country['ROUTE'] == 'LHRLHR']
# Out:
# Empty DataFrame
# Columns: [ROUTE, COUNTRY_CD, COUNTRY_NM, CORP_GEOG_CTRY_GRP_NM, CORP_GEOG_CONTINENT_NM]
# Index: []

# %% [markdown]
# Of course why would it exist. BA 31 is due to Typhoon Hanna (Haikui 海葵).

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# # Flight info
# - First we sort out all flights by planned departure time and flight number

# %%
df_flight_info = df_flight_info.sort_values(['GMT_PLND_DEP_TS','OPG_FLT_NO','GMT_ACT_DEP_TS'])

df_flight_info.head(10)
# Out:
#        OPG_ALN_CD  OPG_FLT_NO     GMT_PLND_DEP_TS      GMT_ACT_DEP_TS  \
# 50194      BA             472 2019-03-31 05:15:00 2019-03-31 05:08:00
# 74947      BA             456 2019-03-31 05:20:00 2019-03-31 05:16:00
# 22731      BA             360 2019-03-31 05:35:00 2019-03-31 05:36:00
# 105274     BA             428 2019-03-31 05:40:00 2019-03-31 05:40:00
# 49888      BA             638 2019-03-31 05:45:00 2019-03-31 06:41:00
# 100028     BA             724 2019-03-31 05:45:00 2019-03-31 05:44:00
# 9711       BA             948 2019-03-31 05:45:00 2019-03-31 05:48:00
# 48578      BA             538 2019-03-31 05:50:00 2019-03-31 05:47:00
# 121504     BA             812 2019-03-31 05:55:00 2019-03-31 05:51:00
# 82165      BA             552 2019-03-31 06:00:00 2019-03-31 05:56:00
#
#        ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD  \
# 50194          LHR                3           BCN            BCN
# 74947          LHR                5           MAD            MAD
# 22731          LHR                3           LYS            LYS
# 105274         LHR                5           AMS            AMS
# 49888          LHR                5           ATH            ATH
# 100028         LHR                5           GVA            GVA
# 9711           LHR                5           MUC            MUC
# 48578          LHR                5           BLQ            BLQ
# 121504         LHR                5           CPH            CPH
# 82165          LHR                5           FCO            FCO
#
#        IATA_AC_TYP_CD ACT_AC_TYP_CD         ROUTE COUNTRY_CD   COUNTRY_NM  \
# 50194          320             A3    LHRBCN           ES            Spain
# 74947          32Q             N6    LHRMAD           ES            Spain
# 22731          320             A3    LHRLYS           FR           France
# 105274         32A             H3    LHRAMS           NL      Netherlands
# 49888          321             V6    LHRATH           GR           Greece
# 100028         319             A4    LHRGVA           CH      Switzerland
# 9711           321             V6    LHRMUC           DE          Germany
# 48578          321             V6    LHRBLQ           IT            Italy
# 121504         32N             N3    LHRCPH           DK          Denmark
# 82165          320             A3    LHRFCO           IT            Italy
#
#        CORP_GEOG_CTRY_GRP_NM CORP_GEOG_CONTINENT_NM
# 50194            WEST EUROPE          EUROPE EXC UK
# 74947            WEST EUROPE          EUROPE EXC UK
# 22731            WEST EUROPE          EUROPE EXC UK
# 105274               BENELUX          EUROPE EXC UK
# 49888          MEDITERRANEAN          EUROPE EXC UK
# 100028           WEST EUROPE          EUROPE EXC UK
# 9711             WEST EUROPE          EUROPE EXC UK
# 48578          MEDITERRANEAN          EUROPE EXC UK
# 121504           SCANDINAVIA          EUROPE EXC UK
# 82165          MEDITERRANEAN          EUROPE EXC UK

# %% [markdown]
# We would like to keep the first occourance of the duplicates

# %%
df_flight_info_unique = df_flight_info.drop_duplicates(subset = ['OPG_FLT_NO','GMT_PLND_DEP_TS'],keep = "first")
df_flight_info_unique.head(10)
# df_flight_info_unique.shape,df_flight_info.shape
# Out:
#        OPG_ALN_CD  OPG_FLT_NO     GMT_PLND_DEP_TS      GMT_ACT_DEP_TS  \
# 50194      BA             472 2019-03-31 05:15:00 2019-03-31 05:08:00
# 74947      BA             456 2019-03-31 05:20:00 2019-03-31 05:16:00
# 22731      BA             360 2019-03-31 05:35:00 2019-03-31 05:36:00
# 105274     BA             428 2019-03-31 05:40:00 2019-03-31 05:40:00
# 49888      BA             638 2019-03-31 05:45:00 2019-03-31 06:41:00
# 100028     BA             724 2019-03-31 05:45:00 2019-03-31 05:44:00
# 9711       BA             948 2019-03-31 05:45:00 2019-03-31 05:48:00
# 48578      BA             538 2019-03-31 05:50:00 2019-03-31 05:47:00
# 121504     BA             812 2019-03-31 05:55:00 2019-03-31 05:51:00
# 82165      BA             552 2019-03-31 06:00:00 2019-03-31 05:56:00
#
#        ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD  \
# 50194          LHR                3           BCN            BCN
# 74947          LHR                5           MAD            MAD
# 22731          LHR                3           LYS            LYS
# 105274         LHR                5           AMS            AMS
# 49888          LHR                5           ATH            ATH
# 100028         LHR                5           GVA            GVA
# 9711           LHR                5           MUC            MUC
# 48578          LHR                5           BLQ            BLQ
# 121504         LHR                5           CPH            CPH
# 82165          LHR                5           FCO            FCO
#
#        IATA_AC_TYP_CD ACT_AC_TYP_CD         ROUTE COUNTRY_CD   COUNTRY_NM  \
# 50194          320             A3    LHRBCN           ES            Spain
# 74947          32Q             N6    LHRMAD           ES            Spain
# 22731          320             A3    LHRLYS           FR           France
# 105274         32A             H3    LHRAMS           NL      Netherlands
# 49888          321             V6    LHRATH           GR           Greece
# 100028         319             A4    LHRGVA           CH      Switzerland
# 9711           321             V6    LHRMUC           DE          Germany
# 48578          321             V6    LHRBLQ           IT            Italy
# 121504         32N             N3    LHRCPH           DK          Denmark
# 82165          320             A3    LHRFCO           IT            Italy
#
#        CORP_GEOG_CTRY_GRP_NM CORP_GEOG_CONTINENT_NM
# 50194            WEST EUROPE          EUROPE EXC UK
# 74947            WEST EUROPE          EUROPE EXC UK
# 22731            WEST EUROPE          EUROPE EXC UK
# 105274               BENELUX          EUROPE EXC UK
# 49888          MEDITERRANEAN          EUROPE EXC UK
# 100028           WEST EUROPE          EUROPE EXC UK
# 9711             WEST EUROPE          EUROPE EXC UK
# 48578          MEDITERRANEAN          EUROPE EXC UK
# 121504           SCANDINAVIA          EUROPE EXC UK
# 82165          MEDITERRANEAN          EUROPE EXC UK

# %% [markdown]
# Check if there's duplicated

# %%
duplicated_flag = df_flight_info_unique.duplicated(subset=['OPG_FLT_NO','GMT_PLND_DEP_TS'],keep=False)
df_flight_info_duplicated = df_flight_info_unique[duplicated_flag].sort_values(['OPG_FLT_NO','GMT_PLND_DEP_TS','GMT_ACT_DEP_TS'])
df_flight_info_duplicated = df_flight_info_duplicated[['OPG_FLT_NO','GMT_PLND_DEP_TS','GMT_ACT_DEP_TS','ROUTE','PLND_ARR_STN_CD','ACT_ARR_STN_CD']]

df_flight_info_duplicated.head(10)
# Out:
# Empty DataFrame
# Columns: [OPG_FLT_NO, GMT_PLND_DEP_TS, GMT_ACT_DEP_TS, ROUTE, PLND_ARR_STN_CD, ACT_ARR_STN_CD]
# Index: []

# %% [markdown]
# # Lounge Eligibility
