# %% [markdown]
# ## Connect to ICW:

# %%
import cadspy

# %%
username = str(input('User number'))
icw = cadspy.DatabaseConnection(system='ICW', user=username)
# Out:
# User number u243700
# Enter Password:  ··············

# %% [markdown]
# <br>
# <div class="alert alert-" style = "border-radius:10px;border-width:3px;border-color:salmon;font-family:Verdana,sans-serif;font-size:16px;">
#
# <font size="4">Can't connect to ICW? Instructions on how to get access to it in the links below:
#
# </font>
# </div>

# %% [markdown]
# - Step 1: [Requesting Access to GitHub](https://baplc.sharepoint.com/sites/ask/SitePages/Requesting-Access-to-GitHub.aspx)
#
# Once your access to GitHub has been aproved, you need to:
#
# - Step 2: [Request access to British-Ent GitHub organisation](https://github.com/BritishAirways-Ent/insight-processes/blob/main/onboarding/Corporate_Directory_git.md)
#
# And
#
# - Step 3: [Setup Sagemaker Studio to access GitHub](https://github.com/BritishAirways-Ent/insight-processes/blob/main/onboarding/sagemaker_to_github_setup.md)
#
# <br>

# %% [markdown]
# Below are some packages to get you started. You don't have to use them but you may find them useful!

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %%
# diplay all rows and cols when using 'dataframe'.head() or 'dataframe'.tail()
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# <br>
#
# ### Data
#
# #### S19 Lounge Eligibility data

# %%
query = """

sel * from LDB_SBOX_OR.HACKATHON_OPS_LOUNGE_ELIGIBILITY

"""

df_lounge_eligibility = icw.queryToDataframe(query)

# %%
df_lounge_eligibility.head(2)
# Out:
#          Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 0  2023-08-05618               BA                   618    2023-08-05
# 1  2023-05-17920               BA                   920    2023-05-17
#
#   UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD  \
# 0        LHR              OLB                 C               C
# 1        LHR              STR                 C               C
#
#      BA_PAX_TIER ONEWORLD_TIER Lounge_eligibility_tier  pax
# 0  Gold For Life          EMER                  Tier 2    2
# 1                                               Tier 3   13

# %%
df_lounge_eligibility.shape
# Out:
# (1534750, 12)

# %%
# a look to a particular flight number and date

#mask = (df_lounge_eligibility['DISCHARGE_STN_CD'] == 'GCM   ') & (df_lounge_eligibility['GMT_UPLIFT_DT'] == dt.date(2019,9,12) )

#df_lounge_eligibility[mask]

# %% [markdown]
# #### S19 Flight info

# %%
query = """

select * from LDB_SBOX_OR.HACKATHON_OPS_FLIGHT_INFO

"""

df_flight_info = icw.queryToDataframe(query)

# %%
df_flight_info.head(2)
# Out:
#       GMT_PLND_DEP_TS      GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO  \
# 0 2023-04-30 20:25:00 2023-04-30 20:34:00     BA              57
# 1 2019-05-18 12:15:00 2019-05-18 12:16:00     BA             632
#
#   ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD IATA_AC_TYP_CD  \
# 0         LHR                5           JNB            JNB            388
# 1         LHR                5           ATH            ATH            320
#
#   ACT_AC_TYP_CD         ROUTE
# 0          A8    LHRJNB
# 1          R3    LHRATH

# %% [markdown]
# #### Station Code Decode

# %%
query = """

select * from LDB_SBOX_OR.HACKATHON_OPS_COUNTRY_DECODE

"""

df_country = icw.queryToDataframe(query)

# %%
df_country.head(2)
# Out:
#     ROUTE COUNTRY_CD                           COUNTRY_NM  \
# 0  LHRINV        GB   United Kingdom and Northern Ireland
# 1  LHRSVO        RU                      Russia in Europe
#
#   CORP_GEOG_CTRY_GRP_NM CORP_GEOG_CONTINENT_NM
# 0                    UK                     UK
# 1        EASTERN EUROPE          EUROPE EXC UK

# %% [markdown]
# #### Aircraft Type

# %%
query = """

select * from LDB_SBOX_OR.HACKATHON_OPS_AC_TYPE

"""

df_acft_typ = icw.queryToDataframe(query)

# %%
df_acft_typ.head(2)
# Out:
#   IATA_AC_TYP_CD ACT_AC_TYP_CD WB_NB_CAT  FIRST_SEATS_QTY  CLUB_SEATS_QTY  \
# 0            320            A3        NB                0              24
# 1            777            K7        WB                0              48
#
#    PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY
# 0                       0                132
# 1                      24                203

# %%
df_acft_typ.shape
# Out:
# (20, 7)

# %%
df_acft_typ
# Out:
#    IATA_AC_TYP_CD ACT_AC_TYP_CD WB_NB_CAT  FIRST_SEATS_QTY  CLUB_SEATS_QTY  \
# 0             320            A3        NB                0              24
# 1             777            K7        WB                0              48
# 2             32N            N3        NB                0              20
# 3             321            M6        NB                0              23
# 4             32Q            N6        NB                0              32
# 5             789            L8        WB                8              42
# 6             32A            H3        NB                0              20
# 7             319            A4        NB                0              16
# 8             788            B8        WB                0              35
# 9             77W            G7        WB               14              56
# 10            744            S4        WB               14              86
# 11            343            W9        WB                0              45
# 12            388            A8        WB               14              97
# 13            777            L7        WB                0              48
# 14            321            V6        NB                0              38
# 15            744            V4        WB               14              52
# 16            777            P7        WB               17              48
# 17            321            W6        NB                0              42
# 18            777            V7        WB               14              48
# 19            777            W7        WB               12              48
#
#     PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY
# 0                        0                132
# 1                       24                203
# 2                        0                150
# 3                        0                131
# 4                        0                172
# 5                       39                127
# 6                        0                150
# 7                        0                119
# 8                       25                154
# 9                       44                183
# 10                      30                145
# 11                       0                212
# 12                      55                303
# 13                      24                203
# 14                       0                160
# 15                      36                235
# 16                      24                127
# 17                       0                154
# 18                      40                124
# 19                      32                127

# %% [markdown]
# Merging df_country with route haul and business/leisure data from reference tables in ICW.
#
# They will be merged into df_lounge_eligibility for further analysis.

# %%
# A corporate_reference table just for flight numbers
# and their descriptions.
# To be matched on flight number and date (inner join probably)
# Checked with TLV and AMM, both correct (LH, SH)
query = """

select FM_FLT_NO, TO_FLT_NO, EFF_DT, EXP_DT, LONGHAUL_IND, SHORTHAUL_IND,
DOMESTIC_IND, RANGE_DESC_TXT

from CRT_FLIGHT_NO_RANGES

WHERE CODESHARE_IND = 'N' AND FRANCHISE_IND = 'N' 

"""

df_flt_no_ranges = icw.queryToDataframe(query)

# %%
df_flt_no_ranges.head(10)
# Out:
#    FM_FLT_NO  TO_FLT_NO      EFF_DT      EXP_DT LONGHAUL_IND SHORTHAUL_IND  \
# 0       8000       8019  2019-03-31  2021-08-12           Y             N
# 1       2530       2899  2022-10-30  2022-10-31           N             Y
# 2       2530       2825  2023-10-18  2023-10-18           N             Y
# 3       2360       2369  2022-10-30  2022-10-31           N             Y
# 4       3000       3199  2005-01-01  2021-10-30           N             N
# 5       2826       2827  2023-10-18  2023-10-18           N             Y
# 6       2210       2217  2019-03-31  2021-10-30           N             Y
# 7       3300       3319  2005-01-01  2021-10-30           Y             N
# 8       9278       9279  2022-03-27  2022-10-29           N             N
# 9       2218       2229  2019-03-31  2021-10-30           N             Y
#
#   DOMESTIC_IND                                     RANGE_DESC_TXT
# 0           N                          Openskies for LEVEL France
# 1           N                       LGW Euroflyer Prime Shorthaul
# 2           N                   LGW Euroflyer Prime LGW Shorthaul
# 3           N                                  BA Cityflyer Prime
# 4           N   BA Cargo Interline Services (Robbie Newport x8...
# 5           N                   LGW Euroflyer Prime LGW Shorthaul
# 6           N   BA Cityflyer (CJ) (London City services Shorth...
# 7           N   BA wet lease and shared longhaul freighter ser...
# 8           N                               Euroflyer Engineering
# 9           N            BA Cityflyer (CJ) (London City Services)

# %%
# For more granular details of route type, we can also use RevMan definitions.

query = """

SELECT DEP_STN_CD, ARR_STN_CD, GCD_KM, REVMAN_HUB_TXT, 
REVMAN_AREA_TXT, ROUTE_CAT_TXT
FROM REF_ROUTE

WHERE DEP_STN_CD = 'LHR' AND REVMAN_HUB_TXT <> 'Unknown'

"""

df_route_categories = icw.queryToDataframe(query)

# %% [markdown]
# <br>
#
# ### Pre-processing

# %% [markdown]
# *Hint:* It is always worth checking the format of each of the columns in your dataframes before trying to do any work with them. To do so, you can make use of the `headers_and_first_row` function below.

# %%
def headers_and_first_row(df):
    '''
    print headers and first row of a df to deal with data types
    '''
    
    headers = df.columns
    first_row = []

    for col in headers:
        first_row.append(df[col][0])
    
    dictionary = dict( zip( headers, first_row) )

    return dictionary

# %%
# applying headers_and_first_row to df_lounge_eligibility
format_df = headers_and_first_row(df_lounge_eligibility)
format_2 = headers_and_first_row(df_flight_info)

# %%
# Note that some columns have blank spaces!
format_df
format_2
# Out:
# {'GMT_PLND_DEP_TS': Timestamp('2023-04-30 20:25:00'),
#  'GMT_ACT_DEP_TS': Timestamp('2023-04-30 20:34:00'),
#  'OPG_ALN_CD': 'BA    ',
#  'OPG_FLT_NO': 57,
#  'ACT_DEP_STN_CD': 'LHR   ',
#  'ACT_DEP_TML_CD': '5 ',
#  'PLND_ARR_STN_CD': 'JNB   ',
#  'ACT_ARR_STN_CD': 'JNB   ',
#  'IATA_AC_TYP_CD': '388   ',
#  'ACT_AC_TYP_CD': 'A8  ',
#  'ROUTE': 'LHRJNB      '}

# %% [markdown]
# <br>
# <div class="alert alert-" style = "border-radius:10px;border-width:3px;border-color:lightblue;font-family:Verdana,sans-serif;font-size:16px;">
#
# <font size="3">**Exercise 1:** Pre-process **all** the tables above (df_lounge_eligibility, df_flight_info, df_country, df_acft_typ).
#
# </font>
#
# </ol>
# </div>

# %% [markdown]
# We will first strip all frames of spaces. We will then go through each frame to properly prepare it.
#
# We will then load some additional datasets that will be useful for analysis.

# %%
# Stripping strings

tables = [df_lounge_eligibility,df_flight_info,df_country,df_acft_typ,df_flt_no_ranges,df_route_categories]

# Define a function that fine all string fields and remove all blak spaces
def data_cleaning_string(df):
    # Get names of all fields in a dataframe
    fields = df.columns
    # loop for all fields, if data type is string then remove blank spaces
    for f in fields:
        if type(df[f][0]) == str:
            df[f] = df[f].str.strip()
    return df

for i,t in enumerate(tables):
    tables[i] = data_cleaning_string(t)

# %%
df_flight_info[df_flight_info['ACT_ARR_STN_CD'] == 'BGI'].head(10)
# Out:
#            GMT_PLND_DEP_TS      GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO  \
# 28891  2023-03-31 10:30:00 2023-03-31 10:54:00         BA         255
# 61714  2023-04-01 10:30:00 2023-04-01 10:29:00         BA         255
# 103803 2023-04-02 10:30:00 2023-04-02 10:43:00         BA         255
# 115571 2023-04-03 10:30:00 2023-04-03 10:58:00         BA         255
# 127358 2023-04-04 10:30:00 2023-04-04 10:41:00         BA         255
# 135677 2023-04-05 10:30:00 2023-04-05 10:46:00         BA         255
# 29908  2023-04-06 10:30:00 2023-04-06 10:31:00         BA         255
# 9237   2023-04-07 10:30:00 2023-04-07 10:28:00         BA         255
# 47059  2023-04-08 10:30:00 2023-04-08 10:28:00         BA         255
# 59318  2023-04-09 10:30:00 2023-04-09 10:34:00         BA         255
#
#        ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD  \
# 28891             LHR              5             BGI            BGI
# 61714             LHR              5             BGI            BGI
# 103803            LHR              5             BGI            BGI
# 115571            LHR              5             BGI            BGI
# 127358            LHR              5             BGI            BGI
# 135677            LHR              5             BGI            BGI
# 29908             LHR              5             BGI            BGI
# 9237              LHR              5             BGI            BGI
# 47059             LHR              5             BGI            BGI
# 59318             LHR              5             BGI            BGI
#
#        IATA_AC_TYP_CD ACT_AC_TYP_CD   ROUTE
# 28891             777            M7  LHRBGI
# 61714             777            M7  LHRBGI
# 103803            777            M7  LHRBGI
# 115571            777            M7  LHRBGI
# 127358            777            M7  LHRBGI
# 135677            77W            F7  LHRBGI
# 29908             77W            G7  LHRBGI
# 9237              77W            G7  LHRBGI
# 47059             777            M7  LHRBGI
# 59318             77W            G7  LHRBGI

# %%
# count duplicates of flight_info
test_flight_dups = df_flight_info[df_flight_info.duplicated(subset=['GMT_PLND_DEP_TS','OPG_FLT_NO'],keep=False)]
test_flight_dups.sort_values(['PLND_ARR_STN_CD','GMT_ACT_DEP_TS','OPG_FLT_NO'])
# Out:
# Empty DataFrame
# Columns: [GMT_PLND_DEP_TS, GMT_ACT_DEP_TS, OPG_ALN_CD, OPG_FLT_NO, ACT_DEP_STN_CD, ACT_DEP_TML_CD, PLND_ARR_STN_CD, ACT_ARR_STN_CD, IATA_AC_TYP_CD, ACT_AC_TYP_CD, ROUTE]
# Index: []

# %%
# Removing duplucates of flight_info

# Sort the table
df_flight_info = df_flight_info.sort_values(['GMT_PLND_DEP_TS','OPG_FLT_NO','GMT_ACT_DEP_TS'])
# Remove all duplicates and keep the first rows of all duplicated
df_flight_info = df_flight_info.drop_duplicates(subset = ['OPG_FLT_NO','GMT_PLND_DEP_TS'],keep = "first")

# %%
df_flight_info.shape
# Out:
# (136180, 11)

# %%
# 2. Flight info
# Ian's code to clean dataset - identify latest departure date for
# duplicated flights and eliminate it.
df_flight_info['GMT_PLND_DEP_DT'] = df_flight_info['GMT_PLND_DEP_TS'].dt.date
df_flight_info['GMT_PLND_DEP_TIME'] = df_flight_info['GMT_PLND_DEP_TS'].dt.time

# %%
# 3. Country
df_country['DEP_STN_CD'] = df_country['ROUTE'].str.slice(0,3)
df_country['ARR_STN_CD'] = df_country['ROUTE'].str.slice(3,6)

# %%
df_flight_info.head(1)
# Out:
#           GMT_PLND_DEP_TS      GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO  \
# 10910 2019-03-31 05:15:00 2019-03-31 05:08:00         BA         472
#
#       ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD  \
# 10910            LHR              3             BCN            BCN
#
#       IATA_AC_TYP_CD ACT_AC_TYP_CD   ROUTE GMT_PLND_DEP_DT GMT_PLND_DEP_TIME
# 10910            320            A3  LHRBCN      2019-03-31          05:15:00

# %%
# 4. Aircraft type
df_acft_typ.sort_values('FIRST_SEATS_QTY').tail(10)
not_in_af_typ = df_flight_info[~df_flight_info['ACT_AC_TYP_CD'].isin(df_acft_typ['ACT_AC_TYP_CD'])]
ac_missing_counts = not_in_af_typ['ACT_AC_TYP_CD'].value_counts()
print(ac_missing_counts)
df_acft_typ
# Out:
# R3    18130
# M4     4151
# M7     2575
# K5     2197
# D7     1924
# F7     1799
# E9     1627
# T3     1322
# X8     1232
# M2      406
# R7      332
# T7       28
# Y3        2
# K3        1
# U7        1
# J7        1
# Name: ACT_AC_TYP_CD, dtype: int64
#    IATA_AC_TYP_CD ACT_AC_TYP_CD WB_NB_CAT  FIRST_SEATS_QTY  CLUB_SEATS_QTY  \
# 0             320            A3        NB                0              24
# 1             777            K7        WB                0              48
# 2             32N            N3        NB                0              20
# 3             321            M6        NB                0              23
# 4             32Q            N6        NB                0              32
# 5             789            L8        WB                8              42
# 6             32A            H3        NB                0              20
# 7             319            A4        NB                0              16
# 8             788            B8        WB                0              35
# 9             77W            G7        WB               14              56
# 10            744            S4        WB               14              86
# 11            343            W9        WB                0              45
# 12            388            A8        WB               14              97
# 13            777            L7        WB                0              48
# 14            321            V6        NB                0              38
# 15            744            V4        WB               14              52
# 16            777            P7        WB               17              48
# 17            321            W6        NB                0              42
# 18            777            V7        WB               14              48
# 19            777            W7        WB               12              48
#
#     PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY
# 0                        0                132
# 1                       24                203
# 2                        0                150
# 3                        0                131
# 4                        0                172
# 5                       39                127
# 6                        0                150
# 7                        0                119
# 8                       25                154
# 9                       44                183
# 10                      30                145
# 11                       0                212
# 12                      55                303
# 13                      24                203
# 14                       0                160
# 15                      36                235
# 16                      24                127
# 17                       0                154
# 18                      40                124
# 19                      32                127

# %%
df_lounge_eligibility.shape
# Out:
# (1534750, 12)

# %%
# Joining flight_no_ranges with lounge eligibility
# df_merged_a = pd.merge(df_lounge_eligibility,df_flt_no_ranges,how='left',
#                       left_on=['OPERATING_FLT_NO'],right_on=['FM_FLT_NO'])
# print(df_merged_a.shape)
# df_merged_a = df_merged_a[(df_merged_a['GMT_UPLIFT_DT'] >= df_merged_a['EFF_DT'])&
#                     (df_merged_a['GMT_UPLIFT_DT']<=df_merged_a['EXP_DT'])]
# df_merged_a.drop(['FM_FLT_NO','TO_FLT_NO','EFF_DT','EXP_DT'],axis=1,inplace=True)
# print(df_merged_a.shape)

# %%
# df_merged_a.sort_values(['Skew_Id']).head(2)
# # success

# df_merged_a.shape

# %%
# df_merged_b = pd.merge(df_merged_a,df_route_categories,
#                       left_on=['UPLIFT_STN_CD','DISCHARGE_STN_CD'],
#                       right_on=['DEP_STN_CD','ARR_STN_CD'],
#                       how='left')

# %%
# # check for success
# df_merged_b.head(2)

# df_merged_b.shape

# %%
# df_lounge_eligibility = df_merged_b.copy()

# df_lounge_eligibility.head(5)

# df_lounge_eligibility.shape

# %% [markdown]
# <br>
# <div class="alert alert-" style = "border-radius:10px;border-width:3px;border-color:lightblue;font-family:Verdana,sans-serif;font-size:16px;">
#
# <font size="3">**Exercise 2:** Join the tables below
#
#     - df_flight_info
#     - df_country
#     - df_acft_typ
#
# to the table df_lounge_eligibility to generate a final dataset.
#
# </font>
#
# </ol>
# </div>

# %% [markdown]
# PLUS for us, join df_flight_no_ranges and df_route_categories.

# %%
# df_lounge_eligibility.head(5)

# %%
df_lounge_elig_flight_info = pd.merge(df_lounge_eligibility,# left table
                                     df_flight_info, # right table
                                     left_on = ['OPERATING_AIRLINE_CD','OPERATING_FLT_NO','GMT_UPLIFT_DT'], # left on? e.g. which columns from the left table are you joining on to?
                                     right_on = ['OPG_ALN_CD','OPG_FLT_NO','GMT_PLND_DEP_DT'] , # right on? # left on? e.g. which columns from the right table are you joining on to?
                                     how = "left" # how? e.g. left, right, inner,etc
                                     )

df_lounge_elig_flight_info.head(5)
# Out:
#          Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 0  2023-08-05618                   BA               618    2023-08-05
# 1  2023-05-17920                   BA               920    2023-05-17
# 2  2019-04-15770                   BA               770    2019-04-15
# 3  2019-09-23348                   BA               348    2019-09-23
# 4  2019-09-16155                   BA               155    2019-09-16
#
#   UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD  \
# 0           LHR              OLB               C               C
# 1           LHR              STR               C               C
# 2           LHR              OSL               M               M
# 3           LHR              NCE               M               M
# 4           LHR              CAI               J               J
#
#      BA_PAX_TIER ONEWORLD_TIER Lounge_eligibility_tier  pax  \
# 0  Gold For Life          EMER                  Tier 2    2
# 1                                               Tier 3   13
# 2                                         Not eligible   75
# 3                         EMER                  Tier 2    6
# 4                                               Tier 3   23
#
#       GMT_PLND_DEP_TS      GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO  \
# 0 2023-08-05 14:25:00 2023-08-05 14:57:00         BA       618.0
# 1 2023-05-17 16:35:00 2023-05-17 16:43:00         BA       920.0
# 2 2019-04-15 18:25:00 2019-04-15 18:52:00         BA       770.0
# 3 2019-09-23 14:40:00 2019-09-23 14:45:00         BA       348.0
# 4 2019-09-16 16:15:00 2019-09-16 16:45:00         BA       155.0
#
#   ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD IATA_AC_TYP_CD  \
# 0            LHR              3             OLB            OLB            319
# 1            LHR              3             STR            STR            319
# 2            LHR              5             OSL            OSL            32A
# 3            LHR              5             NCE            NCE            319
# 4            LHR              5             CAI            CAI            343
#
#   ACT_AC_TYP_CD   ROUTE GMT_PLND_DEP_DT GMT_PLND_DEP_TIME
# 0            M4  LHROLB      2023-08-05          14:25:00
# 1            M4  LHRSTR      2023-05-17          16:35:00
# 2            H3  LHROSL      2019-04-15          18:25:00
# 3            A4  LHRNCE      2019-09-23          14:40:00
# 4            W9  LHRCAI      2019-09-16          16:15:00

# %%
# your code here!
df_lounge_elig_flight_info.shape
# Out:
# (1534750, 25)

# %% [markdown]
# Get rows with any null values

# %%
df_lounge_elig_flight_info[df_lounge_elig_flight_info.isna().any(axis=1)].shape
# Out:
# (1183, 25)

# %%
df_lounge_elig_flight_info.loc[df_lounge_elig_flight_info['Skew_Id'] == '2023-10-1483'
# Investigation following the previous cell.
# Out:
#               Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 625082  2023-10-14832                   BA               832    2023-10-14
#
#        UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD  \
# 625082           LHR              DUB               M               M
#
#        BA_PAX_TIER ONEWORLD_TIER Lounge_eligibility_tier  pax GMT_PLND_DEP_TS  \
# 625082                                      Not eligible    1             NaT
#
#        GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO ACT_DEP_STN_CD ACT_DEP_TML_CD  \
# 625082            NaT        NaN         NaN            NaN            NaN
#
#        PLND_ARR_STN_CD ACT_ARR_STN_CD IATA_AC_TYP_CD ACT_AC_TYP_CD ROUTE  \
# 625082             NaN            NaN            NaN           NaN   NaN
#
#        GMT_PLND_DEP_DT GMT_PLND_DEP_TIME
# 625082             NaN               NaN

# %%
df_lounge_elig_flight_info[df_lounge_elig_flight_info.isna().any(axis=1)].sort_values(by='GMT_UPLIFT_DT',ascending=False).head(50)
# Why do some flights not match up. Manual investigation with FlightRadar 24 shows many of the most recent ones were cancelled flights.
# But very odd that only some of rows were retained - appears to be only 1 or 2 pax though. So probs best to remove.
# I think this is reflected in real data too on e.g. Ops Dashboard. Cancelled flights will often show as 1 or 2 people, presumably where flight was cancelled ages ago and one person didn't rebook or get moved.
# Out:
#                 Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 625082    2023-10-14832                   BA               832    2023-10-14
# 133379    2023-10-13446                   BA               446    2023-10-13
# 1483884   2023-10-13304                   BA               304    2023-10-13
# 1483264   2023-10-13304                   BA               304    2023-10-13
# 208143    2023-10-13578                   BA               578    2023-10-13
# 208719    2023-10-13578                   BA               578    2023-10-13
# 209295    2023-10-13578                   BA               578    2023-10-13
# 222151    2023-10-13828                   BA               828    2023-10-13
# 760816   2023-10-131414                   BA              1414    2023-10-13
# 1099412   2023-10-13460                   BA               460    2023-10-13
# 760240   2023-10-131414                   BA              1414    2023-10-13
# 648058    2023-10-13860                   BA               860    2023-10-13
# 754578     2023-10-1353                   BA                53    2023-10-13
# 754002     2023-10-1353                   BA                53    2023-10-13
# 738755   2023-10-131420                   BA              1420    2023-10-13
# 738179   2023-10-131420                   BA              1420    2023-10-13
# 142258   2023-10-131370                   BA              1370    2023-10-13
# 1483575   2023-10-13304                   BA               304    2023-10-13
# 242785    2023-10-13428                   BA               428    2023-10-13
# 1484192   2023-10-13304                   BA               304    2023-10-13
# 496090    2023-10-13306                   BA               306    2023-10-13
# 495514    2023-10-13306                   BA               306    2023-10-13
# 494938    2023-10-13306                   BA               306    2023-10-13
# 932377   2023-10-121452                   BA              1452    2023-10-12
# 167451    2023-10-12287                   BA               287    2023-10-12
# 1298575   2023-10-12560                   BA               560    2023-10-12
# 1298005   2023-10-12560                   BA               560    2023-10-12
# 115022    2023-10-12712                   BA               712    2023-10-12
# 1295725   2023-10-12560                   BA               560    2023-10-12
# 1297435   2023-10-12560                   BA               560    2023-10-12
# 1296865   2023-10-12560                   BA               560    2023-10-12
# 1296295   2023-10-12560                   BA               560    2023-10-12
# 933529   2023-10-121452                   BA              1452    2023-10-12
# 934105   2023-10-121452                   BA              1452    2023-10-12
# 114446    2023-10-12712                   BA               712    2023-10-12
# 113870    2023-10-12712                   BA               712    2023-10-12
# 113294    2023-10-12712                   BA               712    2023-10-12
# 934681   2023-10-121452                   BA              1452    2023-10-12
# 115598    2023-10-12712                   BA               712    2023-10-12
# 1295155   2023-10-12560                   BA               560    2023-10-12
# 932953   2023-10-121452                   BA              1452    2023-10-12
# 116174    2023-10-12712                   BA               712    2023-10-12
# 116750    2023-10-12712                   BA               712    2023-10-12
# 166875    2023-10-12287                   BA               287    2023-10-12
# 168603    2023-10-12287                   BA               287    2023-10-12
# 169179    2023-10-12287                   BA               287    2023-10-12
# 169755    2023-10-12287                   BA               287    2023-10-12
# 170331    2023-10-12287                   BA               287    2023-10-12
# 170907    2023-10-12287                   BA               287    2023-10-12
# 171483    2023-10-12287                   BA               287    2023-10-12
#
#         UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD  \
# 625082            LHR              DUB               M               M
# 133379            LHR              AGP               M               M
# 1483884           LHR              CDG               C               C
# 1483264           LHR              CDG               C               C
# 208143            LHR              VCE               C               C
# 208719            LHR              VCE               M               M
# 209295            LHR              VCE               C               C
# 222151            LHR              DUB               M               M
# 760816            LHR              BHD               M               M
# 1099412           LHR              MAD               C               C
# 760240            LHR              BHD               C               C
# 648058            LHR              PRG               M               M
# 754578            LHR              SEA               M               M
# 754002            LHR              SEA               J               J
# 738755            LHR              BHD               M               M
# 738179            LHR              BHD               C               C
# 142258            LHR              MAN               M               M
# 1483575           LHR              CDG               M               M
# 242785            LHR              AMS               M               M
# 1484192           LHR              CDG               M               M
# 496090            LHR              CDG               M               M
# 495514            LHR              CDG               C               C
# 494938            LHR              CDG               M               M
# 932377            LHR              EDI               M               M
# 167451            LHR              SFO               W               W
# 1298575           LHR              FCO               C               C
# 1298005           LHR              FCO               M               M
# 115022            LHR              ZRH               M               M
# 1295725           LHR              FCO               M               M
# 1297435           LHR              FCO               C               C
# 1296865           LHR              FCO               M               M
# 1296295           LHR              FCO               M               M
# 933529            LHR              EDI               C               C
# 934105            LHR              EDI               C               C
# 114446            LHR              ZRH               M               M
# 113870            LHR              ZRH               M               M
# 113294            LHR              ZRH               C               C
# 934681            LHR              EDI               M               M
# 115598            LHR              ZRH               M               M
# 1295155           LHR              FCO               C               C
# 932953            LHR              EDI               M               M
# 116174            LHR              ZRH               C               C
# 116750            LHR              ZRH               M               M
# 166875            LHR              SFO               M               M
# 168603            LHR              SFO               J               J
# 169179            LHR              SFO               J               J
# 169755            LHR              SFO               W               W
# 170331            LHR              SFO               W               W
# 170907            LHR              SFO               M               M
# 171483            LHR              SFO               M               M
#
#              BA_PAX_TIER ONEWORLD_TIER Lounge_eligibility_tier  pax  \
# 625082                                            Not eligible    1
# 133379                                            Not eligible    1
# 1483884                                                 Tier 3    2
# 1483264           Silver          SAPP                  Tier 3    1
# 208143                                                  Tier 3    1
# 208719                            SAPP                  Tier 3    2
# 209295                            EMER                  Tier 2    1
# 222151                                            Not eligible    6
# 760816                                            Not eligible    2
# 1099412                           EMER                  Tier 2    1
# 760240   Gold Guest List          EMER                  Tier 1    1
# 648058                                            Not eligible    1
# 754578                                            Not eligible    2
# 754002                            EMER                  Tier 2    1
# 738755                                            Not eligible    5
# 738179                                                  Tier 3    1
# 142258                                            Not eligible    5
# 1483575                           SAPP                  Tier 3    1
# 242785                                            Not eligible    2
# 1484192                                           Not eligible    3
# 496090                            SAPP                  Tier 3    1
# 495514                                                  Tier 3    1
# 494938                            EMER                  Tier 2    1
# 932377            Silver          SAPP                  Tier 3    4
# 167451                            EMER                  Tier 2    2
# 1298575           Silver          SAPP                  Tier 3    1
# 1298005                           EMER                  Tier 2    1
# 115022                                            Not eligible   60
# 1295725                           SAPP                  Tier 3    2
# 1297435                           EMER                  Tier 2    3
# 1296865           Silver          SAPP                  Tier 3    1
# 1296295                                           Not eligible   44
# 933529            Silver          SAPP                  Tier 3    1
# 934105                                                  Tier 3    2
# 114446              Gold          EMER                  Tier 2    2
# 113870                            SAPP                  Tier 3    1
# 113294                                                  Tier 3    3
# 934681              Gold          EMER                  Tier 2    3
# 115598            Silver          SAPP                  Tier 3    3
# 1295155                                                 Tier 3   17
# 932953              Gold                                Tier 2    1
# 116174            Silver          SAPP                  Tier 3    3
# 116750                            EMER                  Tier 2    1
# 166875                                            Not eligible  123
# 168603                            SAPP                  Tier 3    1
# 169179              Gold          EMER                  Tier 2    2
# 169755                                            Not eligible   30
# 170331              Gold          EMER                  Tier 2    1
# 170907                            EMER                  Tier 2    1
# 171483            Silver                                Tier 3    1
#
#         GMT_PLND_DEP_TS GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO ACT_DEP_STN_CD  \
# 625082              NaT            NaT        NaN         NaN            NaN
# 133379              NaT            NaT        NaN         NaN            NaN
# 1483884             NaT            NaT        NaN         NaN            NaN
# 1483264             NaT            NaT        NaN         NaN            NaN
# 208143              NaT            NaT        NaN         NaN            NaN
# 208719              NaT            NaT        NaN         NaN            NaN
# 209295              NaT            NaT        NaN         NaN            NaN
# 222151              NaT            NaT        NaN         NaN            NaN
# 760816              NaT            NaT        NaN         NaN            NaN
# 1099412             NaT            NaT        NaN         NaN            NaN
# 760240              NaT            NaT        NaN         NaN            NaN
# 648058              NaT            NaT        NaN         NaN            NaN
# 754578              NaT            NaT        NaN         NaN            NaN
# 754002              NaT            NaT        NaN         NaN            NaN
# 738755              NaT            NaT        NaN         NaN            NaN
# 738179              NaT            NaT        NaN         NaN            NaN
# 142258              NaT            NaT        NaN         NaN            NaN
# 1483575             NaT            NaT        NaN         NaN            NaN
# 242785              NaT            NaT        NaN         NaN            NaN
# 1484192             NaT            NaT        NaN         NaN            NaN
# 496090              NaT            NaT        NaN         NaN            NaN
# 495514              NaT            NaT        NaN         NaN            NaN
# 494938              NaT            NaT        NaN         NaN            NaN
# 932377              NaT            NaT        NaN         NaN            NaN
# 167451              NaT            NaT        NaN         NaN            NaN
# 1298575             NaT            NaT        NaN         NaN            NaN
# 1298005             NaT            NaT        NaN         NaN            NaN
# 115022              NaT            NaT        NaN         NaN            NaN
# 1295725             NaT            NaT        NaN         NaN            NaN
# 1297435             NaT            NaT        NaN         NaN            NaN
# 1296865             NaT            NaT        NaN         NaN            NaN
# 1296295             NaT            NaT        NaN         NaN            NaN
# 933529              NaT            NaT        NaN         NaN            NaN
# 934105              NaT            NaT        NaN         NaN            NaN
# 114446              NaT            NaT        NaN         NaN            NaN
# 113870              NaT            NaT        NaN         NaN            NaN
# 113294              NaT            NaT        NaN         NaN            NaN
# 934681              NaT            NaT        NaN         NaN            NaN
# 115598              NaT            NaT        NaN         NaN            NaN
# 1295155             NaT            NaT        NaN         NaN            NaN
# 932953              NaT            NaT        NaN         NaN            NaN
# 116174              NaT            NaT        NaN         NaN            NaN
# 116750              NaT            NaT        NaN         NaN            NaN
# 166875              NaT            NaT        NaN         NaN            NaN
# 168603              NaT            NaT        NaN         NaN            NaN
# 169179              NaT            NaT        NaN         NaN            NaN
# 169755              NaT            NaT        NaN         NaN            NaN
# 170331              NaT            NaT        NaN         NaN            NaN
# 170907              NaT            NaT        NaN         NaN            NaN
# 171483              NaT            NaT        NaN         NaN            NaN
#
#         ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD IATA_AC_TYP_CD  \
# 625082             NaN             NaN            NaN            NaN
# 133379             NaN             NaN            NaN            NaN
# 1483884            NaN             NaN            NaN            NaN
# 1483264            NaN             NaN            NaN            NaN
# 208143             NaN             NaN            NaN            NaN
# 208719             NaN             NaN            NaN            NaN
# 209295             NaN             NaN            NaN            NaN
# 222151             NaN             NaN            NaN            NaN
# 760816             NaN             NaN            NaN            NaN
# 1099412            NaN             NaN            NaN            NaN
# 760240             NaN             NaN            NaN            NaN
# 648058             NaN             NaN            NaN            NaN
# 754578             NaN             NaN            NaN            NaN
# 754002             NaN             NaN            NaN            NaN
# 738755             NaN             NaN            NaN            NaN
# 738179             NaN             NaN            NaN            NaN
# 142258             NaN             NaN            NaN            NaN
# 1483575            NaN             NaN            NaN            NaN
# 242785             NaN             NaN            NaN            NaN
# 1484192            NaN             NaN            NaN            NaN
# 496090             NaN             NaN            NaN            NaN
# 495514             NaN             NaN            NaN            NaN
# 494938             NaN             NaN            NaN            NaN
# 932377             NaN             NaN            NaN            NaN
# 167451             NaN             NaN            NaN            NaN
# 1298575            NaN             NaN            NaN            NaN
# 1298005            NaN             NaN            NaN            NaN
# 115022             NaN             NaN            NaN            NaN
# 1295725            NaN             NaN            NaN            NaN
# 1297435            NaN             NaN            NaN            NaN
# 1296865            NaN             NaN            NaN            NaN
# 1296295            NaN             NaN            NaN            NaN
# 933529             NaN             NaN            NaN            NaN
# 934105             NaN             NaN            NaN            NaN
# 114446             NaN             NaN            NaN            NaN
# 113870             NaN             NaN            NaN            NaN
# 113294             NaN             NaN            NaN            NaN
# 934681             NaN             NaN            NaN            NaN
# 115598             NaN             NaN            NaN            NaN
# 1295155            NaN             NaN            NaN            NaN
# 932953             NaN             NaN            NaN            NaN
# 116174             NaN             NaN            NaN            NaN
# 116750             NaN             NaN            NaN            NaN
# 166875             NaN             NaN            NaN            NaN
# 168603             NaN             NaN            NaN            NaN
# 169179             NaN             NaN            NaN            NaN
# 169755             NaN             NaN            NaN            NaN
# 170331             NaN             NaN            NaN            NaN
# 170907             NaN             NaN            NaN            NaN
# 171483             NaN             NaN            NaN            NaN
#
#         ACT_AC_TYP_CD ROUTE GMT_PLND_DEP_DT GMT_PLND_DEP_TIME
# 625082            NaN   NaN             NaN               NaN
# 133379            NaN   NaN             NaN               NaN
# 1483884           NaN   NaN             NaN               NaN
# 1483264           NaN   NaN             NaN               NaN
# 208143            NaN   NaN             NaN               NaN
# 208719            NaN   NaN             NaN               NaN
# 209295            NaN   NaN             NaN               NaN
# 222151            NaN   NaN             NaN               NaN
# 760816            NaN   NaN             NaN               NaN
# 1099412           NaN   NaN             NaN               NaN
# 760240            NaN   NaN             NaN               NaN
# 648058            NaN   NaN             NaN               NaN
# 754578            NaN   NaN             NaN               NaN
# 754002            NaN   NaN             NaN               NaN
# 738755            NaN   NaN             NaN               NaN
# 738179            NaN   NaN             NaN               NaN
# 142258            NaN   NaN             NaN               NaN
# 1483575           NaN   NaN             NaN               NaN
# 242785            NaN   NaN             NaN               NaN
# 1484192           NaN   NaN             NaN               NaN
# 496090            NaN   NaN             NaN               NaN
# 495514            NaN   NaN             NaN               NaN
# 494938            NaN   NaN             NaN               NaN
# 932377            NaN   NaN             NaN               NaN
# 167451            NaN   NaN             NaN               NaN
# 1298575           NaN   NaN             NaN               NaN
# 1298005           NaN   NaN             NaN               NaN
# 115022            NaN   NaN             NaN               NaN
# 1295725           NaN   NaN             NaN               NaN
# 1297435           NaN   NaN             NaN               NaN
# 1296865           NaN   NaN             NaN               NaN
# 1296295           NaN   NaN             NaN               NaN
# 933529            NaN   NaN             NaN               NaN
# 934105            NaN   NaN             NaN               NaN
# 114446            NaN   NaN             NaN               NaN
# 113870            NaN   NaN             NaN               NaN
# 113294            NaN   NaN             NaN               NaN
# 934681            NaN   NaN             NaN               NaN
# 115598            NaN   NaN             NaN               NaN
# 1295155           NaN   NaN             NaN               NaN
# 932953            NaN   NaN             NaN               NaN
# 116174            NaN   NaN             NaN               NaN
# 116750            NaN   NaN             NaN               NaN
# 166875            NaN   NaN             NaN               NaN
# 168603            NaN   NaN             NaN               NaN
# 169179            NaN   NaN             NaN               NaN
# 169755            NaN   NaN             NaN               NaN
# 170331            NaN   NaN             NaN               NaN
# 170907            NaN   NaN             NaN               NaN
# 171483            NaN   NaN             NaN               NaN

# %%
df_flight_info[df_flight_info['OPG_FLT_NO'] == 8642].head(10)
# Out:
# Empty DataFrame
# Columns: [GMT_PLND_DEP_TS, GMT_ACT_DEP_TS, OPG_ALN_CD, OPG_FLT_NO, ACT_DEP_STN_CD, ACT_DEP_TML_CD, PLND_ARR_STN_CD, ACT_ARR_STN_CD, IATA_AC_TYP_CD, ACT_AC_TYP_CD, ROUTE, GMT_PLND_DEP_DT, GMT_PLND_DEP_TIME]
# Index: []

# %% [markdown]
# ### Merge `df_country` to table

# %%
[headers_and_first_row(d) for d in [df_lounge_elig_flight_info,df_country]]
# Out:
# [{'Skew_Id': '2023-08-05618',
#   'OPERATING_AIRLINE_CD': 'BA',
#   'OPERATING_FLT_NO': 618,
#   'GMT_UPLIFT_DT': datetime.date(2023, 8, 5),
#   'UPLIFT_STN_CD': 'LHR',
#   'DISCHARGE_STN_CD': 'OLB',
#   'BOOKED_CABIN_CD': 'C',
#   'TRAVEL_CABIN_CD': 'C',
#   'BA_PAX_TIER': 'Gold For Life',
#   'ONEWORLD_TIER': 'EMER',
#   'Lounge_eligibility_tier': 'Tier 2',
#   'pax': 2,
#   'GMT_PLND_DEP_TS': Timestamp('2023-08-05 14:25:00'),
#   'GMT_ACT_DEP_TS': Timestamp('2023-08-05 14:57:00'),
#   'OPG_ALN_CD': 'BA',
#   'OPG_FLT_NO': 618.0,
#   'ACT_DEP_STN_CD': 'LHR',
#   'ACT_DEP_TML_CD': '3',
#   'PLND_ARR_STN_CD': 'OLB',
#   'ACT_ARR_STN_CD': 'OLB',
#   'IATA_AC_TYP_CD': '319',
#   'ACT_AC_TYP_CD': 'M4',
#   'ROUTE': 'LHROLB',
#   'GMT_PLND_DEP_DT': datetime.date(2023, 8, 5),
#   'GMT_PLND_DEP_TIME': datetime.time(14, 25)},
#  {'ROUTE': 'LHRINV',
#   'COUNTRY_CD': 'GB',
#   'COUNTRY_NM': 'United Kingdom and Northern Ireland',
#   'CORP_GEOG_CTRY_GRP_NM': 'UK',
#   'CORP_GEOG_CONTINENT_NM': 'UK',
#   'DEP_STN_CD': 'LHR',
#   'ARR_STN_CD': 'INV'}]

# %%
df_lounge_elig_flight_info_country = pd.merge(df_lounge_elig_flight_info,# left table
                                     df_country, # right table
                                     left_on = ['PLND_ARR_STN_CD'], # left on? e.g. which columns from the left table are you joining on to?
                                     right_on = ['ARR_STN_CD'] , # right on? # left on? e.g. which columns from the right table are you joining on to?
                                     how = "left" # how? e.g. left, right, inner,etc
                                     )

# df_lounge_elig_flight_info = df_lounge_elig_flight_info.drop_duplicates()

df_lounge_elig_flight_info_country.head(5)
# Out:
#          Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 0  2023-08-05618                   BA               618    2023-08-05
# 1  2023-05-17920                   BA               920    2023-05-17
# 2  2019-04-15770                   BA               770    2019-04-15
# 3  2019-09-23348                   BA               348    2019-09-23
# 4  2019-09-16155                   BA               155    2019-09-16
#
#   UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD  \
# 0           LHR              OLB               C               C
# 1           LHR              STR               C               C
# 2           LHR              OSL               M               M
# 3           LHR              NCE               M               M
# 4           LHR              CAI               J               J
#
#      BA_PAX_TIER ONEWORLD_TIER Lounge_eligibility_tier  pax  \
# 0  Gold For Life          EMER                  Tier 2    2
# 1                                               Tier 3   13
# 2                                         Not eligible   75
# 3                         EMER                  Tier 2    6
# 4                                               Tier 3   23
#
#       GMT_PLND_DEP_TS      GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO  \
# 0 2023-08-05 14:25:00 2023-08-05 14:57:00         BA       618.0
# 1 2023-05-17 16:35:00 2023-05-17 16:43:00         BA       920.0
# 2 2019-04-15 18:25:00 2019-04-15 18:52:00         BA       770.0
# 3 2019-09-23 14:40:00 2019-09-23 14:45:00         BA       348.0
# 4 2019-09-16 16:15:00 2019-09-16 16:45:00         BA       155.0
#
#   ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD IATA_AC_TYP_CD  \
# 0            LHR              3             OLB            OLB            319
# 1            LHR              3             STR            STR            319
# 2            LHR              5             OSL            OSL            32A
# 3            LHR              5             NCE            NCE            319
# 4            LHR              5             CAI            CAI            343
#
#   ACT_AC_TYP_CD ROUTE_x GMT_PLND_DEP_DT GMT_PLND_DEP_TIME ROUTE_y COUNTRY_CD  \
# 0            M4  LHROLB      2023-08-05          14:25:00  LHROLB         IT
# 1            M4  LHRSTR      2023-05-17          16:35:00  LHRSTR         DE
# 2            H3  LHROSL      2019-04-15          18:25:00  LHROSL         NO
# 3            A4  LHRNCE      2019-09-23          14:40:00  LHRNCE         FR
# 4            W9  LHRCAI      2019-09-16          16:15:00  LHRCAI         EG
#
#   COUNTRY_NM CORP_GEOG_CTRY_GRP_NM CORP_GEOG_CONTINENT_NM DEP_STN_CD  \
# 0      Italy         MEDITERRANEAN          EUROPE EXC UK        LHR
# 1    Germany           WEST EUROPE          EUROPE EXC UK        LHR
# 2     Norway           SCANDINAVIA          EUROPE EXC UK        LHR
# 3     France           WEST EUROPE          EUROPE EXC UK        LHR
# 4      Egypt          NORTH AFRICA                 AFRICA        LHR
#
#   ARR_STN_CD
# 0        OLB
# 1        STR
# 2        OSL
# 3        NCE
# 4        CAI

# %%
df_lounge_elig_flight_info_country.shape
# Out:
# (1534750, 32)

# %% [markdown]
# Check for null values

# %%
df_lounge_elig_flight_info_country[df_lounge_elig_flight_info_country['COUNTRY_CD'].isna()].head(5)
# Out:
#           Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 28  2023-06-25516                   BA               516    2023-06-25
# 44  2023-10-06804                   BA               804    2023-10-06
# 67  2023-07-04310                   BA               310    2023-07-04
# 87  2023-06-03744                   BA               744    2023-06-03
# 89  2023-04-27424                   BA               424    2023-04-27
#
#    UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD BA_PAX_TIER  \
# 28           LHR              OPO               C               C      Silver
# 44           LHR              DLM               C               C
# 67           LHR              ALG               C               C
# 87           LHR              HER               M               M        Gold
# 89           LHR              NAP               M               C        Gold
#
#    ONEWORLD_TIER Lounge_eligibility_tier  pax     GMT_PLND_DEP_TS  \
# 28          SAPP                  Tier 3    4 2023-06-25 06:40:00
# 44          SAPP                  Tier 3    1 2023-10-06 10:20:00
# 67                                Tier 3    9 2023-07-04 07:05:00
# 87          EMER                  Tier 2    1 2023-06-03 08:50:00
# 89          EMER                  Tier 2    1 2023-04-27 14:20:00
#
#         GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO ACT_DEP_STN_CD ACT_DEP_TML_CD  \
# 28 2023-06-25 06:34:00         BA       516.0            LHR              5
# 44 2023-10-06 10:35:00         BA       804.0            LHR              5
# 67 2023-07-04 08:06:00         BA       310.0            LHR              3
# 87 2023-06-03 09:32:00         BA       744.0            LHR              5
# 89 2023-04-27 15:00:00         BA       424.0            LHR              5
#
#    PLND_ARR_STN_CD ACT_ARR_STN_CD IATA_AC_TYP_CD ACT_AC_TYP_CD ROUTE_x  \
# 28             OPO            OPO            32N            N3  LHROPO
# 44             DLM            DLM            32N            N3  LHRDLM
# 67             ALG            ALG            320            T3  LHRALG
# 87             HER            HER            32N            N3  LHRHER
# 89             NAP            NAP            320            R3  LHRNAP
#
#    GMT_PLND_DEP_DT GMT_PLND_DEP_TIME ROUTE_y COUNTRY_CD COUNTRY_NM  \
# 28      2023-06-25          06:40:00     NaN        NaN        NaN
# 44      2023-10-06          10:20:00     NaN        NaN        NaN
# 67      2023-07-04          07:05:00     NaN        NaN        NaN
# 87      2023-06-03          08:50:00     NaN        NaN        NaN
# 89      2023-04-27          14:20:00     NaN        NaN        NaN
#
#    CORP_GEOG_CTRY_GRP_NM CORP_GEOG_CONTINENT_NM DEP_STN_CD ARR_STN_CD
# 28                   NaN                    NaN        NaN        NaN
# 44                   NaN                    NaN        NaN        NaN
# 67                   NaN                    NaN        NaN        NaN
# 87                   NaN                    NaN        NaN        NaN
# 89                   NaN                    NaN        NaN        NaN

# %%
# make a list of all the airports which are not in the country_df
# if doing with inner join, this should be empty.
unique_destinations_df_lounge_elig = df_lounge_elig_flight_info_country['PLND_ARR_STN_CD'].value_counts().reset_index()
unique_destinations_df_lounge_elig.columns = ['Value','Count']

dests_df_country = df_country['ARR_STN_CD'].unique()
missing_dests = unique_destinations_df_lounge_elig[~unique_destinations_df_lounge_elig['Value'].isin(dests_df_country)]
print(missing_dests)
# This list shows all the missing destinations in the dataset. We could easily do this manually.
# But probs worth asking stakeholder.
# Note still 9 LHR arrivals with left joins all the way through.
# Out:
#     Value  Count
# 59    BER   8790
# 68    JER   7642
# 100   NAP   5154
# 106   BDA   4176
# 119   BGI   3082
# 129   OPO   2379
# 131   PDX   2269
# 140   TIA   1507
# 142   FLR   1439
# 144   FNC   1407
# 145   MLE   1353
# 154   SKG   1022
# 155   NUE    940
# 157   CVG    873
# 158   DLM    850
# 161   HER    799
# 163   DBV    770
# 164   ALG    763
# 167   SAW    634
# 168   PEG    566
# 170   BJV    413
# 175   PFO    242
# 177   RHO    200
# 178   PDL     83
# 179   SZG     80
# 180   GNB     51
# 183   LHR      9

# %% [markdown]
# ### `df_acft_typ`

# %%
df_lounge_elig_flight_info_country_acft_typ = pd.merge(
    df_lounge_elig_flight_info_country,
    df_acft_typ,
    left_on = ['IATA_AC_TYP_CD','ACT_AC_TYP_CD'],
    right_on = ['IATA_AC_TYP_CD','ACT_AC_TYP_CD'],
    how = 'left'
)

df_lounge_elig_flight_info_country_acft_typ.head(5)
# Out:
#          Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 0  2023-08-05618                   BA               618    2023-08-05
# 1  2023-05-17920                   BA               920    2023-05-17
# 2  2019-04-15770                   BA               770    2019-04-15
# 3  2019-09-23348                   BA               348    2019-09-23
# 4  2019-09-16155                   BA               155    2019-09-16
#
#   UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD  \
# 0           LHR              OLB               C               C
# 1           LHR              STR               C               C
# 2           LHR              OSL               M               M
# 3           LHR              NCE               M               M
# 4           LHR              CAI               J               J
#
#      BA_PAX_TIER ONEWORLD_TIER Lounge_eligibility_tier  pax  \
# 0  Gold For Life          EMER                  Tier 2    2
# 1                                               Tier 3   13
# 2                                         Not eligible   75
# 3                         EMER                  Tier 2    6
# 4                                               Tier 3   23
#
#       GMT_PLND_DEP_TS      GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO  \
# 0 2023-08-05 14:25:00 2023-08-05 14:57:00         BA       618.0
# 1 2023-05-17 16:35:00 2023-05-17 16:43:00         BA       920.0
# 2 2019-04-15 18:25:00 2019-04-15 18:52:00         BA       770.0
# 3 2019-09-23 14:40:00 2019-09-23 14:45:00         BA       348.0
# 4 2019-09-16 16:15:00 2019-09-16 16:45:00         BA       155.0
#
#   ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD IATA_AC_TYP_CD  \
# 0            LHR              3             OLB            OLB            319
# 1            LHR              3             STR            STR            319
# 2            LHR              5             OSL            OSL            32A
# 3            LHR              5             NCE            NCE            319
# 4            LHR              5             CAI            CAI            343
#
#   ACT_AC_TYP_CD ROUTE_x GMT_PLND_DEP_DT GMT_PLND_DEP_TIME ROUTE_y COUNTRY_CD  \
# 0            M4  LHROLB      2023-08-05          14:25:00  LHROLB         IT
# 1            M4  LHRSTR      2023-05-17          16:35:00  LHRSTR         DE
# 2            H3  LHROSL      2019-04-15          18:25:00  LHROSL         NO
# 3            A4  LHRNCE      2019-09-23          14:40:00  LHRNCE         FR
# 4            W9  LHRCAI      2019-09-16          16:15:00  LHRCAI         EG
#
#   COUNTRY_NM CORP_GEOG_CTRY_GRP_NM CORP_GEOG_CONTINENT_NM DEP_STN_CD  \
# 0      Italy         MEDITERRANEAN          EUROPE EXC UK        LHR
# 1    Germany           WEST EUROPE          EUROPE EXC UK        LHR
# 2     Norway           SCANDINAVIA          EUROPE EXC UK        LHR
# 3     France           WEST EUROPE          EUROPE EXC UK        LHR
# 4      Egypt          NORTH AFRICA                 AFRICA        LHR
#
#   ARR_STN_CD WB_NB_CAT  FIRST_SEATS_QTY  CLUB_SEATS_QTY  \
# 0        OLB       NaN              NaN             NaN
# 1        STR       NaN              NaN             NaN
# 2        OSL        NB              0.0            20.0
# 3        NCE        NB              0.0            16.0
# 4        CAI        WB              0.0            45.0
#
#    PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY
# 0                     NaN                NaN
# 1                     NaN                NaN
# 2                     0.0              150.0
# 3                     0.0              119.0
# 4                     0.0              212.0

# %%
df_lounge_elig_flight_info_country_acft_typ.shape
# Out:
# (1534750, 37)

# %% [markdown]
# Check for null

# %%
df_lounge_elig_flight_info_country_acft_typ[df_lounge_elig_flight_info_country_acft_typ.isna().any(axis=1)].head(5)
# Out:
#          Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 0  2023-08-05618                   BA               618    2023-08-05
# 1  2023-08-05618                   BA               618    2023-08-05
# 2  2023-08-05618                   BA               618    2023-08-05
# 3  2023-08-05618                   BA               618    2023-08-05
# 4  2023-08-05618                   BA               618    2023-08-05
#
#   UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD  \
# 0           LHR              OLB               C               C
# 1           LHR              OLB               C               C
# 2           LHR              OLB               M               M
# 3           LHR              OLB               M               M
# 4           LHR              OLB               M               M
#
#        BA_PAX_TIER ONEWORLD_TIER Lounge_eligibility_tier  pax  \
# 0    Gold For Life          EMER                  Tier 2    2
# 1  Gold Guest List                                Tier 1    1
# 2                                           Not eligible   68
# 3  Gold Guest List          EMER                  Tier 1    4
# 4           Silver          SAPP                  Tier 3    6
#
#       GMT_PLND_DEP_TS      GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO  \
# 0 2023-08-05 14:25:00 2023-08-05 14:57:00         BA         618
# 1 2023-08-05 14:25:00 2023-08-05 14:57:00         BA         618
# 2 2023-08-05 14:25:00 2023-08-05 14:57:00         BA         618
# 3 2023-08-05 14:25:00 2023-08-05 14:57:00         BA         618
# 4 2023-08-05 14:25:00 2023-08-05 14:57:00         BA         618
#
#   ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD IATA_AC_TYP_CD  \
# 0            LHR              3             OLB            OLB            319
# 1            LHR              3             OLB            OLB            319
# 2            LHR              3             OLB            OLB            319
# 3            LHR              3             OLB            OLB            319
# 4            LHR              3             OLB            OLB            319
#
#   ACT_AC_TYP_CD ROUTE_x GMT_PLND_DEP_DT GMT_PLND_DEP_TIME ROUTE_y COUNTRY_CD  \
# 0            M4  LHROLB      2023-08-05          14:25:00  LHROLB         IT
# 1            M4  LHROLB      2023-08-05          14:25:00  LHROLB         IT
# 2            M4  LHROLB      2023-08-05          14:25:00  LHROLB         IT
# 3            M4  LHROLB      2023-08-05          14:25:00  LHROLB         IT
# 4            M4  LHROLB      2023-08-05          14:25:00  LHROLB         IT
#
#   COUNTRY_NM CORP_GEOG_CTRY_GRP_NM CORP_GEOG_CONTINENT_NM DEP_STN_CD  \
# 0      Italy         MEDITERRANEAN          EUROPE EXC UK        LHR
# 1      Italy         MEDITERRANEAN          EUROPE EXC UK        LHR
# 2      Italy         MEDITERRANEAN          EUROPE EXC UK        LHR
# 3      Italy         MEDITERRANEAN          EUROPE EXC UK        LHR
# 4      Italy         MEDITERRANEAN          EUROPE EXC UK        LHR
#
#   ARR_STN_CD WB_NB_CAT  FIRST_SEATS_QTY  CLUB_SEATS_QTY  \
# 0        OLB       NaN              NaN             NaN
# 1        OLB       NaN              NaN             NaN
# 2        OLB       NaN              NaN             NaN
# 3        OLB       NaN              NaN             NaN
# 4        OLB       NaN              NaN             NaN
#
#    PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY
# 0                     NaN                NaN
# 1                     NaN                NaN
# 2                     NaN                NaN
# 3                     NaN                NaN
# 4                     NaN                NaN

# %%
df_acft_typ[df_acft_typ['ACT_AC_TYP_CD'] == 'M4']
# Out:
# Empty DataFrame
# Columns: [IATA_AC_TYP_CD, ACT_AC_TYP_CD, WB_NB_CAT, FIRST_SEATS_QTY, CLUB_SEATS_QTY, PREM_ECONOMY_SEATS_QTY, ECONOMY_SEATS_QTY]
# Index: []

# %%
# Same code as previous join to identify missing values and list them and their frequency.
# Can discuss with stakeholder as to their preferred strategy. Have retained for now, can easily drop columns with NaN later.
missing_final_left_joins = df_lounge_elig_flight_info_country_acft_typ['ACT_AC_TYP_CD'].value_counts().reset_index()
missing_final_left_joins.columns = ['Value','Count']

ac_types_original = df_acft_typ['ACT_AC_TYP_CD'].unique()
missing_ac = missing_final_left_joins[~missing_final_left_joins['Value'].isin(ac_types_original)]
print(missing_ac)
# Out:
#    Value   Count
# 1     R3  164508
# 13    M7   43245
# 15    F7   34710
# 16    M4   32483
# 17    K5   30892
# 19    D7   23866
# 20    X8   19592
# 21    E9   13795
# 25    T3   10626
# 27    R7    4894
# 29    M2    3210
# 30    T7     412
# 31    J7      13
# 32    U7      11

# %% [markdown]
# ### More cleaning for columns redundancy

# %%
headers_and_first_row(df_lounge_elig_flight_info_country_acft_typ)
# Out:
# {'Skew_Id': '2023-08-05618',
#  'OPERATING_AIRLINE_CD': 'BA',
#  'OPERATING_FLT_NO': 618,
#  'GMT_UPLIFT_DT': datetime.date(2023, 8, 5),
#  'UPLIFT_STN_CD': 'LHR',
#  'DISCHARGE_STN_CD': 'OLB',
#  'BOOKED_CABIN_CD': 'C',
#  'TRAVEL_CABIN_CD': 'C',
#  'BA_PAX_TIER': 'Gold For Life',
#  'ONEWORLD_TIER': 'EMER',
#  'Lounge_eligibility_tier': 'Tier 2',
#  'pax': 2,
#  'GMT_PLND_DEP_TS': Timestamp('2023-08-05 14:25:00'),
#  'GMT_ACT_DEP_TS': Timestamp('2023-08-05 14:57:00'),
#  'OPG_ALN_CD': 'BA',
#  'OPG_FLT_NO': 618.0,
#  'ACT_DEP_STN_CD': 'LHR',
#  'ACT_DEP_TML_CD': '3',
#  'PLND_ARR_STN_CD': 'OLB',
#  'ACT_ARR_STN_CD': 'OLB',
#  'IATA_AC_TYP_CD': '319',
#  'ACT_AC_TYP_CD': 'M4',
#  'ROUTE_x': 'LHROLB',
#  'GMT_PLND_DEP_DT': datetime.date(2023, 8, 5),
#  'GMT_PLND_DEP_TIME': datetime.time(14, 25),
#  'ROUTE_y': 'LHROLB',
#  'COUNTRY_CD': 'IT',
#  'COUNTRY_NM': 'Italy',
#  'CORP_GEOG_CTRY_GRP_NM': 'MEDITERRANEAN',
#  'CORP_GEOG_CONTINENT_NM': 'EUROPE EXC UK',
#  'DEP_STN_CD': 'LHR',
#  'ARR_STN_CD': 'OLB',
#  'WB_NB_CAT': nan,
#  'FIRST_SEATS_QTY': nan,
#  'CLUB_SEATS_QTY': nan,
#  'PREM_ECONOMY_SEATS_QTY': nan,
#  'ECONOMY_SEATS_QTY': nan}

# %%
to_drop = ['GMT_PLND_DEP_TS','GMT_ACT_DEP_TS','OPG_ALN_CD','OPG_FLT_NO','ACT_DEP_STN_CD','PLND_ARR_STN_CD','ACT_ARR_STN_CD','ROUTE_y',
'DEP_STN_CD','ARR_STN_CD','GMT_PLND_DEP_DT']

df_lounge_elig_flight_info_country_acft_typ = df_lounge_elig_flight_info_country_acft_typ.drop(columns = to_drop,)

df_lounge_elig_flight_info_country_acft_typ.head(5)
# Out:
#          Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 0  2023-08-05618                   BA               618    2023-08-05
# 1  2023-05-17920                   BA               920    2023-05-17
# 2  2019-04-15770                   BA               770    2019-04-15
# 3  2019-09-23348                   BA               348    2019-09-23
# 4  2019-09-16155                   BA               155    2019-09-16
#
#   UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD  \
# 0           LHR              OLB               C               C
# 1           LHR              STR               C               C
# 2           LHR              OSL               M               M
# 3           LHR              NCE               M               M
# 4           LHR              CAI               J               J
#
#      BA_PAX_TIER ONEWORLD_TIER Lounge_eligibility_tier  pax ACT_DEP_TML_CD  \
# 0  Gold For Life          EMER                  Tier 2    2              3
# 1                                               Tier 3   13              3
# 2                                         Not eligible   75              5
# 3                         EMER                  Tier 2    6              5
# 4                                               Tier 3   23              5
#
#   IATA_AC_TYP_CD ACT_AC_TYP_CD ROUTE_x GMT_PLND_DEP_TIME COUNTRY_CD  \
# 0            319            M4  LHROLB          14:25:00         IT
# 1            319            M4  LHRSTR          16:35:00         DE
# 2            32A            H3  LHROSL          18:25:00         NO
# 3            319            A4  LHRNCE          14:40:00         FR
# 4            343            W9  LHRCAI          16:15:00         EG
#
#   COUNTRY_NM CORP_GEOG_CTRY_GRP_NM CORP_GEOG_CONTINENT_NM WB_NB_CAT  \
# 0      Italy         MEDITERRANEAN          EUROPE EXC UK       NaN
# 1    Germany           WEST EUROPE          EUROPE EXC UK       NaN
# 2     Norway           SCANDINAVIA          EUROPE EXC UK        NB
# 3     France           WEST EUROPE          EUROPE EXC UK        NB
# 4      Egypt          NORTH AFRICA                 AFRICA        WB
#
#    FIRST_SEATS_QTY  CLUB_SEATS_QTY  PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY
# 0              NaN             NaN                     NaN                NaN
# 1              NaN             NaN                     NaN                NaN
# 2              0.0            20.0                     0.0              150.0
# 3              0.0            16.0                     0.0              119.0
# 4              0.0            45.0                     0.0              212.0

# %%
df_lounge_elig_flight_info_country_acft_typ['ACT_DEP_TML_CD'].unique()
# Out:
# array(['3', '5', nan], dtype=object)

# %%
df_lounge_elig_flight_info_country_acft_typ.isnull().values.any()
# THERE ARE NA VALUES FOR AIRCRAFT TYPE.
# Out:
# True

# %%
# TEMPORARY, REMOVE BEFORE SUBMISSION!
df_lounge_elig_flight_info_country_acft_typ.to_csv('df_final.csv')

# %% [markdown]
# <br><br>
# <div class="alert alert-" style = "border-radius:10px;border-width:3px;border-color:lightblue;font-family:Verdana,sans-serif;font-size:16px;">
#
# <font size="3">Exercise 3: Based on S2019/S2023 data, provide a lookup table of Lounge eligibility assumptions that can be applied to a future schedule. To do so, answer each of the following questions in the Markdown cell provided below.
#
# - What level of granularity do you use?
# - What metric do you use to come up with Lounge eligibility profiles?
#
#
# Note 1: **Provide evidence for your assumptions.** This can be in the form of tables, graphs, correlation matrix, etc.
#
# Note 2: Make use of the examples below to give structure to your answer. Feel free to attend the Hackathon Clinics if you have any questions.
# </font>
#
#
#
# </ol>
# </div>

# %% [markdown]
# **Reasoning (Example 1)**:

# %% [markdown]
# Assume:
# - Data has been preprocessed.
# - Data has been joined, and a final dataset has been created. This dataset is the result of joining the 4 tables.
#
# The final dataset has been called `df_lounge_elig_flight_info_country_acft_typ`.

# %% [markdown]
# <u>What level of granularity do you use?</u>
# - I have decided to split all flights in the network based on their aircraft type. I will therefore have a lookup table with two categories: Narrowbody and Widebody.
#
# <u>What metric do you use to come up with Lounge eligibility profiles?</u>
# - I have sumed up all the passengers by Aircraft Type, by Tier. Then I have divided them by the total number of passengers by Aircraft Type. For example:
#     - For NB aircrafts, and for Tier 1 passengers: In S19 we had 41,728 pax eligible for Tier 1 out of 7,222,830 pax flying on Narrowbody aircraft. This represents 0.6% of the costumers and I assume that this will be the number of costumers elegible for this specific Lounge in a future schedule.

# %%
# your code here!

# %%
# columns that you want to group by
list_groupby = ['WB_NB_CAT','Lounge_eligibility_tier']

# grouping by WB_NB_CAT and Lounge_eligibility_tier
df_groupby_wb_nb = df_lounge_elig_flight_info_country_acft_typ.groupby(list_groupby).agg(
                pax_count = ('pax','sum')
).reset_index()

# %%
# a look at the data
df_groupby_wb_nb
# Out:
#   WB_NB_CAT Lounge_eligibility_tier  pax_count
# 0        NB            Not eligible    7274457
# 1        NB                  Tier 1      42096
# 2        NB                  Tier 2     572764
# 3        NB                  Tier 3    1678702
# 4        WB            Not eligible    4157801
# 5        WB                  Tier 1     198032
# 6        WB                  Tier 2     284599
# 7        WB                  Tier 3    1119094

# %%
# getting the number of pax by aircraft type

# columns that you want to group by
list_groupby = ['WB_NB_CAT']

# grouping by WB_NB_CAT
df_groupby_wb_nb_ttl = df_lounge_elig_flight_info_country_acft_typ.groupby(list_groupby).agg(
                pax_count_ttl = ('pax','sum')
).reset_index()

# %%
# a look at the data
df_groupby_wb_nb_ttl
# Out:
#   WB_NB_CAT  pax_count_ttl
# 0        NB        9568019
# 1        WB        5759526

# %%
# now, let's left join df_groupby_wb_nb_ttl onto df_groupby_wb_nb
# this adds a new column to the df_groupby_wb_nb table (pax_count_ttl) that will be used to get the percentage of passenger eligible by Tier

df_groupby_wb_nb = pd.merge(df_groupby_wb_nb,
                            df_groupby_wb_nb_ttl,
                            on = ['WB_NB_CAT'],
                            how = 'left'
                           )

# %%
# a look at the data
df_groupby_wb_nb
# Out:
#   WB_NB_CAT Lounge_eligibility_tier  pax_count  pax_count_ttl
# 0        NB            Not eligible    7274457        9568019
# 1        NB                  Tier 1      42096        9568019
# 2        NB                  Tier 2     572764        9568019
# 3        NB                  Tier 3    1678702        9568019
# 4        WB            Not eligible    4157801        5759526
# 5        WB                  Tier 1     198032        5759526
# 6        WB                  Tier 2     284599        5759526
# 7        WB                  Tier 3    1119094        5759526

# %%
# getting the percentage of pax elegible for each of the Tiers

df_groupby_wb_nb['pax_eligible%'] = (df_groupby_wb_nb['pax_count'] / df_groupby_wb_nb['pax_count_ttl'] )*100 

# getting the pax_elegible% column in the right format
df_groupby_wb_nb['pax_eligible%'] = df_groupby_wb_nb['pax_eligible%'].map('{:,.1f}%'.format)

# %%
# dropping pax_count, pax_count_ttl columns - not needed anymore
df_groupby_wb_nb.drop(columns=['pax_count','pax_count_ttl'],inplace = True)

# %%
# a look at the data
df_groupby_wb_nb
# Out:
#   WB_NB_CAT Lounge_eligibility_tier pax_eligible%
# 0        NB            Not eligible         76.0%
# 1        NB                  Tier 1          0.4%
# 2        NB                  Tier 2          6.0%
# 3        NB                  Tier 3         17.5%
# 4        WB            Not eligible         72.2%
# 5        WB                  Tier 1          3.4%
# 6        WB                  Tier 2          4.9%
# 7        WB                  Tier 3         19.4%

# %%
# dropping 'not eligible' rows - not needed anymore
mask = df_groupby_wb_nb['Lounge_eligibility_tier'] == 'Not eligible'

df_groupby_wb_nb = df_groupby_wb_nb[~mask].copy()

# %% [markdown]
# <br>
#
# Please save your final lookup table below in the form of a pandas dataframe. It must contain the categories you have come up with as rows, and the Tier 1, Tier 2, and Tier 3 percentage of costumers as columns.

# %%
# using set_index to come up with the final lookup table
df_groupby_wb_nb = df_groupby_wb_nb.set_index(['WB_NB_CAT','Lounge_eligibility_tier'],drop = True).unstack('Lounge_eligibility_tier')

# %%
# final table
df_groupby_wb_nb
# Out:
#                         pax_eligible%
# Lounge_eligibility_tier        Tier 1 Tier 2 Tier 3
# WB_NB_CAT
# NB                               0.4%   6.0%  17.5%
# WB                               3.4%   4.9%  19.4%

# %% [markdown]
# <br>
#
# **Feedback:** This analysis provides a lookup table in the format needed to be input into a future schedule. Nevertheless, this analysis is too high level and you haven't provided any evidence for your assumptions. To further enhance your answer use insights from the data and provide evidence for your assumptions. Please find some ideas below:
#
# - Using the same categories (WB,NB), plot data overtime to better understand the peaks for the different lounges.
# - Is there a way to split Widebody into more categories? Do the Haul, Region, Time of Day, or Country play a role in the number of passengers that are eligible in Tier 1, Tier 2 and Tier 3? Etc...

# %% [markdown]
# <br><br>
#
# **Reasoning (Example 2)**:

# %% [markdown]
# <u>What level of granularity do you use?</u>
# - I have decided to split all flights in the network based on their flight number. I will therefore have a lookup table with a lot of categories as each flight number is a category.
#
# <u>What metric do you use to come up with Lounge eligibility profiles?</u>
# - I have sumed up all the passengers by flight number, by Tier. Then I have divided them by the total number of passengers flight number.

# %%
# your code here!

# %%
# columns that you want to group by
list_groupby = ['OPERATING_FLT_NO','DISCHARGE_STN_CD','Lounge_eligibility_tier']

# grouping by OPERATING_FLT_NO, DISCHARGE_STN_CD and Lounge_eligibility_tier
df_groupby_flt_no = df_lounge_elig_flight_info_country_acft_typ.groupby(list_groupby).agg(
                pax_count = ('pax','sum')
).reset_index()

# a look at the data
df_groupby_flt_no.head(4)
# Out:
#    OPERATING_FLT_NO DISCHARGE_STN_CD Lounge_eligibility_tier  pax_count
# 0                 5              HND            Not eligible      15825
# 1                 5              HND                  Tier 1        220
# 2                 5              HND                  Tier 2        888
# 3                 5              HND                  Tier 3       4469

# %%
# getting the number of pax by OPERATING_FLT_NO and DISCHARGE_STN_CD

# columns that you want to group by
list_groupby = ['OPERATING_FLT_NO','DISCHARGE_STN_CD']

# grouping by WB_NB_CAT
df_groupby_flt_no_ttl = df_lounge_elig_flight_info_country_acft_typ.groupby(list_groupby).agg(
                pax_count_ttl = ('pax','sum')
).reset_index()

# %%
# a look at the data
df_groupby_flt_no_ttl.head(2)
# Out:
#    OPERATING_FLT_NO DISCHARGE_STN_CD  pax_count_ttl
# 0                 5              HND          21402
# 1                 5              NRT          38378

# %%
# now, let's left join df_groupby_flt_no_ttl onto df_groupby_flt_no
# this adds a new column to the df_groupby_flt_no table (pax_count_ttl) that will be used to get the percentage of passenger eligible by Tier

df_groupby_flt_no = pd.merge(df_groupby_flt_no,
                            df_groupby_flt_no_ttl,
                            on = ['OPERATING_FLT_NO','DISCHARGE_STN_CD'],
                            how = 'left'
                           )

# %%
# a look at the data
df_groupby_flt_no.head(4)
# Out:
#    OPERATING_FLT_NO DISCHARGE_STN_CD Lounge_eligibility_tier  pax_count  \
# 0                 5              HND            Not eligible      15825
# 1                 5              HND                  Tier 1        220
# 2                 5              HND                  Tier 2        888
# 3                 5              HND                  Tier 3       4469
#
#    pax_count_ttl
# 0          21402
# 1          21402
# 2          21402
# 3          21402

# %%
# getting the percentage of pax elegible for each of the Tiers

df_groupby_flt_no['pax_eligible%'] = (df_groupby_flt_no['pax_count'] / df_groupby_flt_no['pax_count_ttl'] )*100 

# getting the pax_elegible% column in the right format
df_groupby_flt_no['pax_eligible%'] = df_groupby_flt_no['pax_eligible%'].map('{:,.1f}%'.format)

# dropping pax_count, pax_count_ttl columns - not needed anymore
df_groupby_flt_no.drop(columns=['pax_count','pax_count_ttl'],inplace = True)

# %%
# a look at the data
df_groupby_flt_no.head(4)
# Out:
#    OPERATING_FLT_NO DISCHARGE_STN_CD Lounge_eligibility_tier pax_eligible%
# 0                 5              HND            Not eligible         73.9%
# 1                 5              HND                  Tier 1          1.0%
# 2                 5              HND                  Tier 2          4.1%
# 3                 5              HND                  Tier 3         20.9%

# %%
# dropping 'not eligible' rows - not needed anymore
mask = df_groupby_flt_no['Lounge_eligibility_tier'] == 'Not eligible'

df_groupby_flt_no = df_groupby_flt_no[~mask].copy()

# %% [markdown]
# <br>
#
# Please save your final lookup table below in the form of a pandas dataframe. It must contain the categories you have come up with as rows, and the Tier 1, Tier 2, and Tier 3 percentage of costumers as columns.

# %%
# using set_index to come up with the final lookup table
df_groupby_flt_no = df_groupby_flt_no.set_index(['OPERATING_FLT_NO','DISCHARGE_STN_CD','Lounge_eligibility_tier'],drop = True).unstack('Lounge_eligibility_tier')

# %%
# final table
df_groupby_flt_no.head(4)
# Out:
#                                   pax_eligible%
# Lounge_eligibility_tier                  Tier 1 Tier 2 Tier 3
# OPERATING_FLT_NO DISCHARGE_STN_CD
# 5                HND                       1.0%   4.1%  20.9%
#                  NRT                       3.6%   4.8%  19.1%
# 7                HND                       3.3%   5.2%  19.8%
# 9                BKK                       0.3%   4.2%  15.9%

# %% [markdown]
# <br>
#
# **Feedback:** This analysis goes at a very granular level, we might come up with missing values if we apply this lounge eligibility profiles to a future schedule. Here are some ideas to further enhance your answer:
#
# - What would happen if we fly to a new destination in the future? How do we ensure we have a lounge eligibility profile for this new route?
# - As you can see in the example above: Pax eligible for Tier 1 for the BKK flight is significantly different from the rest. What's the most used aircraft type for this route? And why it differs that much from the rest? Is it because of the route characteristics instead?
# - For SH routes, we might change the time of departure for a specific flight number from one year to the next. Explore the possibility of using a clasification that takes that into account, like using Time of Day instead of flight number.

# %% [markdown]
# <br><br><br>

# %%
#--------------------------------
#
# Your turn!!!
#
#--------------------------------

# %% [markdown]
# <u>What level of granularity do you use?</u>
# - ... (your answer here)
#
# <u>What metric do you use to come up with Lounge eligibility profiles?</u>
# - ... (your answer here)

# %%
# your code here

# %% [markdown]
# <br>
#
# Please save your final lookup table below in the form of a pandas dataframe. It must contain the categories you have come up with as rows, and the Tier 1, Tier 2, and Tier 3 percentage of costumers as columns.

# %%
# MORE TESTING PLEASE IGNORE AND DELETE BEFORE SUBMITTING

# %%
## more testing SCRAGG
df_final = df_lounge_elig_flight_info_country_acft_typ.copy()

# %%
df_final.shape
# Out:
# (1534750, 26)

# %%
df_lounge_eligibility.shape
# Out:
# (1534750, 12)

# %%
df_final.loc[df_final['DISCHARGE_STN_CD'] == 'BGI'].head(10)
# Out:
#             Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 392   2023-08-20255                   BA               255    2023-08-20
# 407   2023-04-20255                   BA               255    2023-04-20
# 968   2023-08-20255                   BA               255    2023-08-20
# 983   2023-04-20255                   BA               255    2023-04-20
# 1544  2023-08-20255                   BA               255    2023-08-20
# 1559  2023-04-20255                   BA               255    2023-04-20
# 2120  2023-08-20255                   BA               255    2023-08-20
# 2135  2023-04-20255                   BA               255    2023-04-20
# 2696  2023-08-20255                   BA               255    2023-08-20
# 2711  2023-04-20255                   BA               255    2023-04-20
#
#      UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD  \
# 392            LHR              BGI               F               F
# 407            LHR              BGI               J               F
# 968            LHR              BGI               M               M
# 983            LHR              BGI               W               W
# 1544           LHR              BGI               F               F
# 1559           LHR              BGI               W               W
# 2120           LHR              BGI               M               M
# 2135           LHR              BGI               M               M
# 2696           LHR              BGI               M               M
# 2711           LHR              BGI               J               J
#
#      BA_PAX_TIER ONEWORLD_TIER Lounge_eligibility_tier  pax ACT_DEP_TML_CD  \
# 392       Silver          SAPP                  Tier 1    1              5
# 407                                             Tier 1    1              5
# 968                       SAPP                  Tier 3    3              5
# 983                       EMER                  Tier 2    1              5
# 1544        Gold          EMER                  Tier 1    5              5
# 1559      Silver                                Tier 3    1              5
# 2120        Gold          EMER                  Tier 2    1              5
# 2135      Silver          SAPP                  Tier 3    4              5
# 2696                                      Not eligible  129              5
# 2711      Silver                                Tier 3    2              5
#
#      IATA_AC_TYP_CD ACT_AC_TYP_CD ROUTE_x GMT_PLND_DEP_TIME COUNTRY_CD  \
# 392             777            M7  LHRBGI          10:30:00        NaN
# 407             777            M7  LHRBGI          10:30:00        NaN
# 968             777            M7  LHRBGI          10:30:00        NaN
# 983             777            M7  LHRBGI          10:30:00        NaN
# 1544            777            M7  LHRBGI          10:30:00        NaN
# 1559            777            M7  LHRBGI          10:30:00        NaN
# 2120            777            M7  LHRBGI          10:30:00        NaN
# 2135            777            M7  LHRBGI          10:30:00        NaN
# 2696            777            M7  LHRBGI          10:30:00        NaN
# 2711            777            M7  LHRBGI          10:30:00        NaN
#
#      COUNTRY_NM CORP_GEOG_CTRY_GRP_NM CORP_GEOG_CONTINENT_NM WB_NB_CAT  \
# 392         NaN                   NaN                    NaN       NaN
# 407         NaN                   NaN                    NaN       NaN
# 968         NaN                   NaN                    NaN       NaN
# 983         NaN                   NaN                    NaN       NaN
# 1544        NaN                   NaN                    NaN       NaN
# 1559        NaN                   NaN                    NaN       NaN
# 2120        NaN                   NaN                    NaN       NaN
# 2135        NaN                   NaN                    NaN       NaN
# 2696        NaN                   NaN                    NaN       NaN
# 2711        NaN                   NaN                    NaN       NaN
#
#       FIRST_SEATS_QTY  CLUB_SEATS_QTY  PREM_ECONOMY_SEATS_QTY  \
# 392               NaN             NaN                     NaN
# 407               NaN             NaN                     NaN
# 968               NaN             NaN                     NaN
# 983               NaN             NaN                     NaN
# 1544              NaN             NaN                     NaN
# 1559              NaN             NaN                     NaN
# 2120              NaN             NaN                     NaN
# 2135              NaN             NaN                     NaN
# 2696              NaN             NaN                     NaN
# 2711              NaN             NaN                     NaN
#
#       ECONOMY_SEATS_QTY
# 392                 NaN
# 407                 NaN
# 968                 NaN
# 983                 NaN
# 1544                NaN
# 1559                NaN
# 2120                NaN
# 2135                NaN
# 2696                NaN
# 2711                NaN
