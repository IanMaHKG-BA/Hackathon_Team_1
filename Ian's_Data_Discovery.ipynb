# %% [markdown]
# # Ian's Data Discovery

# %% [markdown]
# ## All the tables
# Just to get all the tables first

# %%
import cadspy
import numpy as np
import pandas as pd
import datetime as dt

# %%
icw = cadspy.DatabaseConnection(system='ICW',user='u243696')

# %%
# diplay all rows and cols when using 'dataframe'.head() or 'dataframe'.tail()
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Lounge Eligibility Data

# %%
query = """

sel * from LDB_SBOX_OR.HACKATHON_OPS_LOUNGE_ELIGIBILITY

"""

df_lounge_eligibility = icw.queryToDataframe(query)

# %%
df_lounge_eligibility.head(5)
# Out:
#           Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 0  2019-08-101414               BA                  1414    2019-08-10
# 1   2023-05-17920               BA                   920    2023-05-17
# 2   2019-04-15770               BA                   770    2019-04-15
# 3   2019-09-23348               BA                   348    2019-09-23
# 4   2019-09-16155               BA                   155    2019-09-16
#
#   UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD BA_PAX_TIER  \
# 0        LHR              BHD                 M               M         Gold
# 1        LHR              STR                 C               C
# 2        LHR              OSL                 M               M
# 3        LHR              NCE                 M               M
# 4        LHR              CAI                 J               J
#
#   ONEWORLD_TIER Lounge_eligibility_tier  pax
# 0          EMER                  Tier 2    3
# 1                                Tier 3   13
# 2                          Not eligible   75
# 3          EMER                  Tier 2    6
# 4                                Tier 3   23

# %% [markdown]
# ### Flight Info

# %%
query = """

select * from LDB_SBOX_OR.HACKATHON_OPS_FLIGHT_INFO

"""

df_flight_info = icw.queryToDataframe(query)

# %%
df_flight_info.head(5)
# Out:
#       GMT_PLND_DEP_TS      GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO  \
# 0 2019-09-04 06:45:00 2019-09-04 06:43:00     BA            1434
# 1 2019-05-18 12:15:00 2019-05-18 12:16:00     BA             632
# 2 2019-07-19 15:10:00 2019-07-19 15:11:00     BA             718
# 3 2019-04-18 18:25:00 2019-04-18 18:40:00     BA             257
# 4 2019-08-11 12:20:00 2019-08-11 12:16:00     BA             460
#
#   ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD IATA_AC_TYP_CD  \
# 0         LHR                5           EDI            EDI            32Q
# 1         LHR                5           ATH            ATH            320
# 2         LHR                5           ZRH            ZRH            319
# 3         LHR                5           DEL            DEL            777
# 4         LHR                5           MAD            MAD            777
#
#   ACT_AC_TYP_CD         ROUTE
# 0          N6    LHREDI
# 1          R3    LHRATH
# 2          A4    LHRZRH
# 3          W7    LHRDEL
# 4          V7    LHRMAD

# %% [markdown]
# ### Station Code Decode

# %%
query = """

select * from LDB_SBOX_OR.HACKATHON_OPS_COUNTRY_DECODE

"""

df_country = icw.queryToDataframe(query)

# %%
df_country.head(5)
# Out:
#     ROUTE COUNTRY_CD                           COUNTRY_NM  \
# 0  LHRINV        GB   United Kingdom and Northern Ireland
# 1  LHRSVO        RU                      Russia in Europe
# 2  LHREZE        AR                             Argentina
# 3  LHRLUX        LU                            Luxembourg
# 4  LHRCAI        EG                                 Egypt
#
#   CORP_GEOG_CTRY_GRP_NM       CORP_GEOG_CONTINENT_NM
# 0                    UK                           UK
# 1        EASTERN EUROPE                EUROPE EXC UK
# 2         SOUTH AMERICA  SOUTH AMERICA INC CARIBBEAN
# 3               BENELUX                EUROPE EXC UK
# 4          NORTH AFRICA                       AFRICA

# %% [markdown]
# ### Aircraft Type

# %%
query = """

select * from LDB_SBOX_OR.HACKATHON_OPS_AC_TYPE

"""

df_acft_typ = icw.queryToDataframe(query)

# %%
df_acft_typ
# Out:
#    IATA_AC_TYP_CD ACT_AC_TYP_CD WB_NB_CAT  FIRST_SEATS_QTY  CLUB_SEATS_QTY  \
# 0             320            A3        NB                0              24
# 1             777            K7        WB                0              48
# 2             32N            N3        NB                0              20
# 3             321            M6        NB                0              23
# 4             32Q            N6        NB                0              32
# 5             789            L8        WB                8              42
# 6             32A            H3        NB                0              20
# 7             319            A4        NB                0              16
# 8             788            B8        WB                0              35
# 9             77W            G7        WB               14              56
# 10            744            S4        WB               14              86
# 11            343            W9        WB                0              45
# 12            388            A8        WB               14              97
# 13            777            L7        WB                0              48
# 14            321            V6        NB                0              38
# 15            744            V4        WB               14              52
# 16            777            P7        WB               17              48
# 17            321            W6        NB                0              42
# 18            777            V7        WB               14              48
# 19            777            W7        WB               12              48
#
#     PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY
# 0                        0                132
# 1                       24                203
# 2                        0                150
# 3                        0                131
# 4                        0                172
# 5                       39                127
# 6                        0                150
# 7                        0                119
# 8                       25                154
# 9                       44                183
# 10                      30                145
# 11                       0                212
# 12                      55                303
# 13                      24                203
# 14                       0                160
# 15                      36                235
# 16                      24                127
# 17                       0                154
# 18                      40                124
# 19                      32                127

# %% [markdown]
# ## Basic Pre-processing

# %%
def headers_and_first_row(df):
    '''
    print headers and first row of a df to deal with data types
    '''
    
    headers = df.columns
    first_row = []

    for col in headers:
        first_row.append(df[col][0])
    
    dictionary = dict( zip( headers, first_row) )

    return dictionary

# Define a function that fine all string fields and remove all blank spaces
def data_cleaning_string(df):
    # Get names of all fields in a dataframe
    fields = df.columns
    # loop for all fields, if data type is string then remove blank spaces
    for f in fields:
        if type(df[f][0]) == str:
            df[f] = df[f].str.strip()
    return df

# %%
tables = [df_lounge_eligibility,df_flight_info,df_country,df_acft_typ]

for i,t in enumerate(tables):
    tables[i] = data_cleaning_string(t)

tables = [df_lounge_eligibility,df_flight_info,df_country,df_acft_typ]

[headers_and_first_row(t) for t in tables]
# Out:
# [{'Skew_Id': '2019-08-101414',
#   'OPERATING_AIRLINE_CD': 'BA',
#   'OPERATING_FLT_NO': 1414,
#   'GMT_UPLIFT_DT': datetime.date(2019, 8, 10),
#   'UPLIFT_STN_CD': 'LHR',
#   'DISCHARGE_STN_CD': 'BHD',
#   'BOOKED_CABIN_CD': 'M',
#   'TRAVEL_CABIN_CD': 'M',
#   'BA_PAX_TIER': 'Gold',
#   'ONEWORLD_TIER': 'EMER',
#   'Lounge_eligibility_tier': 'Tier 2',
#   'pax': 3},
#  {'GMT_PLND_DEP_TS': Timestamp('2019-09-04 06:45:00'),
#   'GMT_ACT_DEP_TS': Timestamp('2019-09-04 06:43:00'),
#   'OPG_ALN_CD': 'BA',
#   'OPG_FLT_NO': 1434,
#   'ACT_DEP_STN_CD': 'LHR',
#   'ACT_DEP_TML_CD': '5',
#   'PLND_ARR_STN_CD': 'EDI',
#   'ACT_ARR_STN_CD': 'EDI',
#   'IATA_AC_TYP_CD': '32Q',
#   'ACT_AC_TYP_CD': 'N6',
#   'ROUTE': 'LHREDI'},
#  {'ROUTE': 'LHRINV',
#   'COUNTRY_CD': 'GB',
#   'COUNTRY_NM': 'United Kingdom and Northern Ireland',
#   'CORP_GEOG_CTRY_GRP_NM': 'UK',
#   'CORP_GEOG_CONTINENT_NM': 'UK'},
#  {'IATA_AC_TYP_CD': '320',
#   'ACT_AC_TYP_CD': 'A3',
#   'WB_NB_CAT': 'NB',
#   'FIRST_SEATS_QTY': 0,
#   'CLUB_SEATS_QTY': 24,
#   'PREM_ECONOMY_SEATS_QTY': 0,
#   'ECONOMY_SEATS_QTY': 132}]

# %%
# Create date and time fields for the time stamp fields
df_flight_info['GMT_PLND_DEP_DATE'] = pd.to_datetime(df_flight_info['GMT_PLND_DEP_TS']).dt.date
df_flight_info['GMT_PLND_DEP_TIME'] = pd.to_datetime(df_flight_info['GMT_PLND_DEP_TS']).dt.time
df_flight_info['GMT_ACT_DEP_DATE'] = pd.to_datetime(df_flight_info['GMT_ACT_DEP_TS']).dt.date
df_flight_info['GMT_ACT_DEP_TIME'] = pd.to_datetime(df_flight_info['GMT_ACT_DEP_TS']).dt.time

# Remove timestaps due to redundancy
# df_flight_info = df_flight_info.drop(columns= ['GMT_PLND_DEP_TS','GMT_ACT_DEP_TS'])

# Check
headers_and_first_row(df_flight_info)
# Out:
# {'GMT_PLND_DEP_TS': Timestamp('2019-09-04 06:45:00'),
#  'GMT_ACT_DEP_TS': Timestamp('2019-09-04 06:43:00'),
#  'OPG_ALN_CD': 'BA',
#  'OPG_FLT_NO': 1434,
#  'ACT_DEP_STN_CD': 'LHR',
#  'ACT_DEP_TML_CD': '5',
#  'PLND_ARR_STN_CD': 'EDI',
#  'ACT_ARR_STN_CD': 'EDI',
#  'IATA_AC_TYP_CD': '32Q',
#  'ACT_AC_TYP_CD': 'N6',
#  'ROUTE': 'LHREDI',
#  'GMT_PLND_DEP_DATE': datetime.date(2019, 9, 4),
#  'GMT_PLND_DEP_TIME': datetime.time(6, 45),
#  'GMT_ACT_DEP_DATE': datetime.date(2019, 9, 4),
#  'GMT_ACT_DEP_TIME': datetime.time(6, 43)}

# %% [markdown]
# # Checkings
# Basically just to check duplicated data

# %% [markdown]
# ## 1. Loungue Eligibility
# Norally each Skew ID should only have one destination

# %% [markdown]
# - We first group the lpungue eligibility by Skew ID and flight number, showing the discharge station code and total passenegr

# %%
df_lounge_by_skew = df_lounge_eligibility.groupby(['Skew_Id','OPERATING_FLT_NO','DISCHARGE_STN_CD'], as_index = False).agg(pax_count = ('pax','sum'))

df_lounge_by_skew.head(5)
# Out:
#          Skew_Id  OPERATING_FLT_NO DISCHARGE_STN_CD  pax_count
# 0  2019-03-31103               103              YYC        197
# 1  2019-03-31105               105              DXB        209
# 2  2019-03-31107               107              DXB        201
# 3  2019-03-31109               109              DXB        217
# 4   2019-03-3111                11              SIN        443

# %% [markdown]
# - We then find all duplicated Skew ID's, and sorted by Skew ID for readability

# %%
duplicated_flag = df_lounge_by_skew.duplicated('Skew_Id',keep = False)

df_lounge_by_skew_duplicated = df_lounge_by_skew[duplicated_flag].sort_values(['Skew_Id','OPERATING_FLT_NO'])

df_lounge_by_skew_duplicated.head(20)
# Out:
#             Skew_Id  OPERATING_FLT_NO DISCHARGE_STN_CD  pax_count
# 38   2019-03-311448              1448              ABZ          1
# 39   2019-03-311448              1448              EDI        139
# 55     2019-03-3115                15              SIN        165
# 56     2019-03-3115                15              SYD        114
# 165   2019-03-31462               462              MAD        173
# 166   2019-03-31462               462              PHX         15
# 348  2019-04-011314              1314              ABZ        119
# 349  2019-04-011314              1314              BHD          1
# 395    2019-04-0115                15              SIN         97
# 396    2019-04-0115                15              SYD        114
# 436   2019-04-01253               253              GCM         87
# 437   2019-04-01253               253              NAS        181
# 697  2019-04-021318              1318              ABZ         98
# 698  2019-04-021318              1318              EDI          1
# 726  2019-04-021448              1448              ABZ          1
# 727  2019-04-021448              1448              EDI        109
# 745    2019-04-0215                15              SIN        114
# 746    2019-04-0215                15              SYD        145
# 853   2019-04-02462               462              MAD         86
# 854   2019-04-02462               462              PHX          3

# %% [markdown]
# - Check Flight 1448 on 2019-3-31

# %%
df_flight_info[(df_flight_info['OPG_FLT_NO'] == 1448) & (df_flight_info['GMT_PLND_DEP_DATE'] == dt.date(2019,3,31))]
# Out:
#           GMT_PLND_DEP_TS      GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO  \
# 62735 2019-03-31 14:20:00 2019-03-31 14:24:00         BA        1448
#
#       ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD  \
# 62735            LHR              5             EDI            EDI
#
#       IATA_AC_TYP_CD ACT_AC_TYP_CD   ROUTE GMT_PLND_DEP_DATE  \
# 62735            320            A3  LHREDI        2019-03-31
#
#       GMT_PLND_DEP_TIME GMT_ACT_DEP_DATE GMT_ACT_DEP_TIME
# 62735          14:20:00       2019-03-31         14:24:00

# %% [markdown]
# Has the flight ever flew to Aberdeen?

# %% [markdown]
# - Check Flight 15 on 2019-3-31

# %%
df_flight_info[(df_flight_info['OPG_FLT_NO'] == 15) & (df_flight_info['GMT_PLND_DEP_DATE'] == dt.date(2019,3,31))]
# Out:
#         GMT_PLND_DEP_TS      GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO  \
# 377 2019-03-31 20:30:00 2019-03-31 20:36:00         BA          15
#
#     ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD  \
# 377            LHR              5             SIN            SIN
#
#     IATA_AC_TYP_CD ACT_AC_TYP_CD   ROUTE GMT_PLND_DEP_DATE GMT_PLND_DEP_TIME  \
# 377            77W            G7  LHRSIN        2019-03-31          20:30:00
#
#     GMT_ACT_DEP_DATE GMT_ACT_DEP_TIME
# 377       2019-03-31         20:36:00

# %% [markdown]
# No record to Sydney? Let's check for any flight to Sydney

# %%
df_flight_info[(df_flight_info['PLND_ARR_STN_CD']=="SYD") | (df_flight_info['ACT_ARR_STN_CD']=="SYD")]
# Out:
# Empty DataFrame
# Columns: [GMT_PLND_DEP_TS, GMT_ACT_DEP_TS, OPG_ALN_CD, OPG_FLT_NO, ACT_DEP_STN_CD, ACT_DEP_TML_CD, PLND_ARR_STN_CD, ACT_ARR_STN_CD, IATA_AC_TYP_CD, ACT_AC_TYP_CD, ROUTE, GMT_PLND_DEP_DATE, GMT_PLND_DEP_TIME, GMT_ACT_DEP_DATE, GMT_ACT_DEP_TIME]
# Index: []

# %% [markdown]
# No record to sydney, is it because already included into the LHR-SIN route?

# %% [markdown]
# ## 2. Flight Info
#
# Check if there is any duplicated flights

# %%
duplicated_flag = df_flight_info.duplicated(subset=['OPG_FLT_NO','GMT_PLND_DEP_TS'],keep=False)
df_flight_info_duplicated = df_flight_info[duplicated_flag].sort_values(['OPG_FLT_NO','GMT_PLND_DEP_TS','GMT_ACT_DEP_TS'])
df_flight_info_duplicated = df_flight_info_duplicated[['OPG_FLT_NO','GMT_PLND_DEP_TS','GMT_ACT_DEP_TS','ROUTE','PLND_ARR_STN_CD','ACT_ARR_STN_CD']]

df_flight_info_duplicated.head(10)
# Out:
#        OPG_FLT_NO     GMT_PLND_DEP_TS      GMT_ACT_DEP_TS   ROUTE  \
# 37730         119 2019-07-03 13:15:00 2019-07-03 14:01:00  LHRBLR
# 38306         119 2019-07-03 13:15:00 2019-07-03 20:28:00  LHRBLR
# 543           223 2019-04-29 13:45:00 2019-04-29 13:44:00  LHRBNA
# 1119          223 2019-04-29 13:45:00 2019-04-29 16:37:00  LHRBNA
# 58380         249 2019-07-17 11:20:00 2019-07-17 11:18:00  LHRGIG
# 58879         249 2019-07-17 11:20:00 2019-07-17 18:13:00  LHRGIG
# 28002         251 2019-07-05 21:00:00 2019-07-05 21:01:00  LHRSCL
# 27426         251 2019-07-05 21:00:00 2019-07-06 16:28:00  LHRSCL
# 32766         289 2019-09-29 13:45:00 2019-09-29 14:09:00  LHRPHX
# 33342         289 2019-09-29 13:45:00 2019-09-29 19:09:00  LHRPHX
#
#       PLND_ARR_STN_CD ACT_ARR_STN_CD
# 37730             BLR            LHR
# 38306             BLR            BLR
# 543               BNA            LHR
# 1119              BNA            BNA
# 58380             GIG            LHR
# 58879             GIG            GIG
# 28002             SCL            LHR
# 27426             SCL            SCL
# 32766             PHX            LHR
# 33342             PHX            PHX

# %% [markdown]
# It seesm like the flightd are just being rescheduled.
#
# Let's also check if the LHRLHR route actually exists

# %%
df_country[df_country['ROUTE'] == 'LHRLHR']
# Out:
# Empty DataFrame
# Columns: [ROUTE, COUNTRY_CD, COUNTRY_NM, CORP_GEOG_CTRY_GRP_NM, CORP_GEOG_CONTINENT_NM]
# Index: []

# %% [markdown]
# Of course why would it exist. BA 31 is due to Typhoon Hanna (Haikui 海葵).

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Flight info
# - First we sort out all flights by planned departure time and flight number

# %%
df_flight_info = df_flight_info.sort_values(['GMT_PLND_DEP_TS','OPG_FLT_NO','GMT_ACT_DEP_TS'])

df_flight_info.head(10)
# Out:
#           GMT_PLND_DEP_TS      GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO  \
# 5726  2019-03-31 05:15:00 2019-03-31 05:08:00         BA         472
# 32201 2019-03-31 05:20:00 2019-03-31 05:16:00         BA         456
# 34780 2019-03-31 05:35:00 2019-03-31 05:36:00         BA         360
# 63777 2019-03-31 05:40:00 2019-03-31 05:40:00         BA         428
# 8668  2019-03-31 05:45:00 2019-03-31 06:41:00         BA         638
# 7516  2019-03-31 05:45:00 2019-03-31 05:44:00         BA         724
# 8092  2019-03-31 05:45:00 2019-03-31 05:48:00         BA         948
# 43242 2019-03-31 05:50:00 2019-03-31 05:47:00         BA         538
# 19536 2019-03-31 05:55:00 2019-03-31 05:51:00         BA         812
# 40906 2019-03-31 06:00:00 2019-03-31 05:56:00         BA         552
#
#       ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD  \
# 5726             LHR              3             BCN            BCN
# 32201            LHR              5             MAD            MAD
# 34780            LHR              3             LYS            LYS
# 63777            LHR              5             AMS            AMS
# 8668             LHR              5             ATH            ATH
# 7516             LHR              5             GVA            GVA
# 8092             LHR              5             MUC            MUC
# 43242            LHR              5             BLQ            BLQ
# 19536            LHR              5             CPH            CPH
# 40906            LHR              5             FCO            FCO
#
#       IATA_AC_TYP_CD ACT_AC_TYP_CD   ROUTE GMT_PLND_DEP_DATE  \
# 5726             320            A3  LHRBCN        2019-03-31
# 32201            32Q            N6  LHRMAD        2019-03-31
# 34780            320            A3  LHRLYS        2019-03-31
# 63777            32A            H3  LHRAMS        2019-03-31
# 8668             321            V6  LHRATH        2019-03-31
# 7516             319            A4  LHRGVA        2019-03-31
# 8092             321            V6  LHRMUC        2019-03-31
# 43242            321            V6  LHRBLQ        2019-03-31
# 19536            32N            N3  LHRCPH        2019-03-31
# 40906            320            A3  LHRFCO        2019-03-31
#
#       GMT_PLND_DEP_TIME GMT_ACT_DEP_DATE GMT_ACT_DEP_TIME
# 5726           05:15:00       2019-03-31         05:08:00
# 32201          05:20:00       2019-03-31         05:16:00
# 34780          05:35:00       2019-03-31         05:36:00
# 63777          05:40:00       2019-03-31         05:40:00
# 8668           05:45:00       2019-03-31         06:41:00
# 7516           05:45:00       2019-03-31         05:44:00
# 8092           05:45:00       2019-03-31         05:48:00
# 43242          05:50:00       2019-03-31         05:47:00
# 19536          05:55:00       2019-03-31         05:51:00
# 40906          06:00:00       2019-03-31         05:56:00

# %% [markdown]
# We would like to keep the first occourance of the duplicates

# %%
df_flight_info_unique = df_flight_info.drop_duplicates(subset = ['OPG_FLT_NO','GMT_PLND_DEP_TS'],keep = "first")
df_flight_info_unique.head(10)
# df_flight_info_unique.shape,df_flight_info.shape
# Out:
#           GMT_PLND_DEP_TS      GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO  \
# 5726  2019-03-31 05:15:00 2019-03-31 05:08:00         BA         472
# 32201 2019-03-31 05:20:00 2019-03-31 05:16:00         BA         456
# 34780 2019-03-31 05:35:00 2019-03-31 05:36:00         BA         360
# 63777 2019-03-31 05:40:00 2019-03-31 05:40:00         BA         428
# 8668  2019-03-31 05:45:00 2019-03-31 06:41:00         BA         638
# 7516  2019-03-31 05:45:00 2019-03-31 05:44:00         BA         724
# 8092  2019-03-31 05:45:00 2019-03-31 05:48:00         BA         948
# 43242 2019-03-31 05:50:00 2019-03-31 05:47:00         BA         538
# 19536 2019-03-31 05:55:00 2019-03-31 05:51:00         BA         812
# 40906 2019-03-31 06:00:00 2019-03-31 05:56:00         BA         552
#
#       ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD  \
# 5726             LHR              3             BCN            BCN
# 32201            LHR              5             MAD            MAD
# 34780            LHR              3             LYS            LYS
# 63777            LHR              5             AMS            AMS
# 8668             LHR              5             ATH            ATH
# 7516             LHR              5             GVA            GVA
# 8092             LHR              5             MUC            MUC
# 43242            LHR              5             BLQ            BLQ
# 19536            LHR              5             CPH            CPH
# 40906            LHR              5             FCO            FCO
#
#       IATA_AC_TYP_CD ACT_AC_TYP_CD   ROUTE GMT_PLND_DEP_DATE  \
# 5726             320            A3  LHRBCN        2019-03-31
# 32201            32Q            N6  LHRMAD        2019-03-31
# 34780            320            A3  LHRLYS        2019-03-31
# 63777            32A            H3  LHRAMS        2019-03-31
# 8668             321            V6  LHRATH        2019-03-31
# 7516             319            A4  LHRGVA        2019-03-31
# 8092             321            V6  LHRMUC        2019-03-31
# 43242            321            V6  LHRBLQ        2019-03-31
# 19536            32N            N3  LHRCPH        2019-03-31
# 40906            320            A3  LHRFCO        2019-03-31
#
#       GMT_PLND_DEP_TIME GMT_ACT_DEP_DATE GMT_ACT_DEP_TIME
# 5726           05:15:00       2019-03-31         05:08:00
# 32201          05:20:00       2019-03-31         05:16:00
# 34780          05:35:00       2019-03-31         05:36:00
# 63777          05:40:00       2019-03-31         05:40:00
# 8668           05:45:00       2019-03-31         06:41:00
# 7516           05:45:00       2019-03-31         05:44:00
# 8092           05:45:00       2019-03-31         05:48:00
# 43242          05:50:00       2019-03-31         05:47:00
# 19536          05:55:00       2019-03-31         05:51:00
# 40906          06:00:00       2019-03-31         05:56:00

# %% [markdown]
# Check if there's duplicated, here we keep the LHRLHR route, but we are changeing the route to the original planned one

# %%
# Removed all duplicates which are not the first one, which means the non 'LHRLHR' will be removed
duplicated_flag = df_flight_info_unique.duplicated(subset=['OPG_FLT_NO','GMT_PLND_DEP_TS'],keep=False)

# df_flight_info_duplicated = df_flight_info_unique[duplicated_flag].sort_values(['OPG_FLT_NO','GMT_PLND_DEP_TS','GMT_ACT_DEP_TS'])
# df_flight_info_duplicated = df_flight_info_duplicated[['OPG_FLT_NO','GMT_PLND_DEP_TS','GMT_ACT_DEP_TS','ROUTE','PLND_ARR_STN_CD','ACT_ARR_STN_CD']]

df_flight_info_unique[df_flight_info_unique['ROUTE'] == "LHRLHR"].head(5)
# Out:
# Empty DataFrame
# Columns: [GMT_PLND_DEP_TS, GMT_ACT_DEP_TS, OPG_ALN_CD, OPG_FLT_NO, ACT_DEP_STN_CD, ACT_DEP_TML_CD, PLND_ARR_STN_CD, ACT_ARR_STN_CD, IATA_AC_TYP_CD, ACT_AC_TYP_CD, ROUTE, GMT_PLND_DEP_DATE, GMT_PLND_DEP_TIME, GMT_ACT_DEP_DATE, GMT_ACT_DEP_TIME]
# Index: []

# %% [markdown]
# Merge set the new route to be 'LHR{'PLND_ARR_STN_CD'}'

# %%
df_flight_info_unique['ROUTE'] = df_flight_info_unique['ACT_DEP_STN_CD'] + df_flight_info_unique['PLND_ARR_STN_CD']

df_flight_info_unique.head(5)
# Out:
# c:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#           GMT_PLND_DEP_TS      GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO  \
# 5726  2019-03-31 05:15:00 2019-03-31 05:08:00         BA         472
# 32201 2019-03-31 05:20:00 2019-03-31 05:16:00         BA         456
# 34780 2019-03-31 05:35:00 2019-03-31 05:36:00         BA         360
# 63777 2019-03-31 05:40:00 2019-03-31 05:40:00         BA         428
# 8668  2019-03-31 05:45:00 2019-03-31 06:41:00         BA         638
#
#       ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD  \
# 5726             LHR              3             BCN            BCN
# 32201            LHR              5             MAD            MAD
# 34780            LHR              3             LYS            LYS
# 63777            LHR              5             AMS            AMS
# 8668             LHR              5             ATH            ATH
#
#       IATA_AC_TYP_CD ACT_AC_TYP_CD   ROUTE GMT_PLND_DEP_DATE  \
# 5726             320            A3  LHRBCN        2019-03-31
# 32201            32Q            N6  LHRMAD        2019-03-31
# 34780            320            A3  LHRLYS        2019-03-31
# 63777            32A            H3  LHRAMS        2019-03-31
# 8668             321            V6  LHRATH        2019-03-31
#
#       GMT_PLND_DEP_TIME GMT_ACT_DEP_DATE GMT_ACT_DEP_TIME
# 5726           05:15:00       2019-03-31         05:08:00
# 32201          05:20:00       2019-03-31         05:16:00
# 34780          05:35:00       2019-03-31         05:36:00
# 63777          05:40:00       2019-03-31         05:40:00
# 8668           05:45:00       2019-03-31         06:41:00

# %%
df_flight_info_unique[df_flight_info_unique['ROUTE'] == "LHRLHR"].head(5)
# Out:
# Empty DataFrame
# Columns: [GMT_PLND_DEP_TS, GMT_ACT_DEP_TS, OPG_ALN_CD, OPG_FLT_NO, ACT_DEP_STN_CD, ACT_DEP_TML_CD, PLND_ARR_STN_CD, ACT_ARR_STN_CD, IATA_AC_TYP_CD, ACT_AC_TYP_CD, ROUTE, GMT_PLND_DEP_DATE, GMT_PLND_DEP_TIME, GMT_ACT_DEP_DATE, GMT_ACT_DEP_TIME]
# Index: []

# %%
df_lounge_eligibility[df_lounge_eligibility['Skew_Id'] == "2023-06-01800"]
# Out:
#               Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 470261  2023-06-01800                   BA               800    2023-06-01
# 470837  2023-06-01800                   BA               800    2023-06-01
# 471413  2023-06-01800                   BA               800    2023-06-01
# 471989  2023-06-01800                   BA               800    2023-06-01
# 472565  2023-06-01800                   BA               800    2023-06-01
# 473141  2023-06-01800                   BA               800    2023-06-01
# 473717  2023-06-01800                   BA               800    2023-06-01
# 474293  2023-06-01800                   BA               800    2023-06-01
# 474869  2023-06-01800                   BA               800    2023-06-01
#
#        UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD  \
# 470261           LHR              KEF               C               C
# 470837           LHR              KEF               C               C
# 471413           LHR              KEF               C               C
# 471989           LHR              KEF               C               C
# 472565           LHR              KEF               M               M
# 473141           LHR              KEF               C               C
# 473717           LHR              KEF               M               M
# 474293           LHR              KEF               C               C
# 474869           LHR              KEF               M               M
#
#        BA_PAX_TIER ONEWORLD_TIER Lounge_eligibility_tier  pax
# 470261                      SAPP                  Tier 3    2
# 470837        Gold          EMER                  Tier 2    2
# 471413     Premier          EMER                  Tier 1    1
# 471989      Silver          SAPP                  Tier 3    3
# 472565                      EMER                  Tier 2    2
# 473141                                            Tier 3   19
# 473717        Gold          EMER                  Tier 2    2
# 474293                      EMER                  Tier 2    3
# 474869                                      Not eligible   74

# %% [markdown]
# Replace the table

# %%
df_flight_info = df_flight_info_unique

# %% [markdown]
# ## Joining Tables

# %% [markdown]
# ### `df_lounge_eligibility` and `df_flight_info`
# - Get the info of the columns

# %%
[headers_and_first_row(t) for t in [df_lounge_eligibility,df_flight_info]]
# Out:
# [{'Skew_Id': '2019-08-101414',
#   'OPERATING_AIRLINE_CD': 'BA',
#   'OPERATING_FLT_NO': 1414,
#   'GMT_UPLIFT_DT': datetime.date(2019, 8, 10),
#   'UPLIFT_STN_CD': 'LHR',
#   'DISCHARGE_STN_CD': 'BHD',
#   'BOOKED_CABIN_CD': 'M',
#   'TRAVEL_CABIN_CD': 'M',
#   'BA_PAX_TIER': 'Gold',
#   'ONEWORLD_TIER': 'EMER',
#   'Lounge_eligibility_tier': 'Tier 2',
#   'pax': 3},
#  {'GMT_PLND_DEP_TS': Timestamp('2019-09-04 06:45:00'),
#   'GMT_ACT_DEP_TS': Timestamp('2019-09-04 06:43:00'),
#   'OPG_ALN_CD': 'BA',
#   'OPG_FLT_NO': 1434,
#   'ACT_DEP_STN_CD': 'LHR',
#   'ACT_DEP_TML_CD': '5',
#   'PLND_ARR_STN_CD': 'EDI',
#   'ACT_ARR_STN_CD': 'EDI',
#   'IATA_AC_TYP_CD': '32Q',
#   'ACT_AC_TYP_CD': 'N6',
#   'ROUTE': 'LHREDI',
#   'GMT_PLND_DEP_DATE': datetime.date(2019, 9, 4),
#   'GMT_PLND_DEP_TIME': datetime.time(6, 45),
#   'GMT_ACT_DEP_DATE': datetime.date(2019, 9, 4),
#   'GMT_ACT_DEP_TIME': datetime.time(6, 43)}]

# %% [markdown]
# Joints:
# - `df_lounge_eligibility`: `'OPERATING_AIRLINE_CD','OPERATING_FLT_NO','GMT_UPLIFT_DT'`
# - `df_flight_info`: `'OPG_ALN_CD','OPG_FLT_NO','GMT_PLND_DEP_DATE'`
# -Inner join, as we want to make sure only valid flighs are joined

# %%
# joining df_lounge_eligibility and df_flight_info

df_lounge_elig_flight_info = pd.merge(df_lounge_eligibility,# left table
                                     df_flight_info, # right table
                                     left_on = ['OPERATING_AIRLINE_CD','OPERATING_FLT_NO','GMT_UPLIFT_DT'], # left on? e.g. which columns from the left table are you joining on to?
                                     right_on = ['OPG_ALN_CD','OPG_FLT_NO','GMT_PLND_DEP_DATE'] , # right on? # left on? e.g. which columns from the right table are you joining on to?
                                     how = "inner" # how? e.g. left, right, inner,etc
                                     )

# df_lounge_elig_flight_info = df_lounge_elig_flight_info.drop_duplicates()

df_lounge_elig_flight_info.head(5)
# Out:
#           Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 0  2019-08-101414                   BA              1414    2019-08-10
# 1  2019-08-101414                   BA              1414    2019-08-10
# 2  2019-08-101414                   BA              1414    2019-08-10
# 3  2019-08-101414                   BA              1414    2019-08-10
# 4  2019-08-101414                   BA              1414    2019-08-10
#
#   UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD BA_PAX_TIER  \
# 0           LHR              BHD               M               M        Gold
# 1           LHR              BHD               M               M
# 2           LHR              BHD               C               C
# 3           LHR              BHD               M               M      Silver
# 4           LHR              BHD               C               C
#
#   ONEWORLD_TIER Lounge_eligibility_tier  pax     GMT_PLND_DEP_TS  \
# 0          EMER                  Tier 2    3 2019-08-10 06:10:00
# 1                          Not eligible  114 2019-08-10 06:10:00
# 2          EMER                  Tier 2    3 2019-08-10 06:10:00
# 3          SAPP                  Tier 3    7 2019-08-10 06:10:00
# 4          SAPP                  Tier 3    1 2019-08-10 06:10:00
#
#        GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO ACT_DEP_STN_CD ACT_DEP_TML_CD  \
# 0 2019-08-10 06:11:00         BA        1414            LHR              5
# 1 2019-08-10 06:11:00         BA        1414            LHR              5
# 2 2019-08-10 06:11:00         BA        1414            LHR              5
# 3 2019-08-10 06:11:00         BA        1414            LHR              5
# 4 2019-08-10 06:11:00         BA        1414            LHR              5
#
#   PLND_ARR_STN_CD ACT_ARR_STN_CD IATA_AC_TYP_CD ACT_AC_TYP_CD   ROUTE  \
# 0             BHD            BHD            320            A3  LHRBHD
# 1             BHD            BHD            320            A3  LHRBHD
# 2             BHD            BHD            320            A3  LHRBHD
# 3             BHD            BHD            320            A3  LHRBHD
# 4             BHD            BHD            320            A3  LHRBHD
#
#   GMT_PLND_DEP_DATE GMT_PLND_DEP_TIME GMT_ACT_DEP_DATE GMT_ACT_DEP_TIME
# 0        2019-08-10          06:10:00       2019-08-10         06:11:00
# 1        2019-08-10          06:10:00       2019-08-10         06:11:00
# 2        2019-08-10          06:10:00       2019-08-10         06:11:00
# 3        2019-08-10          06:10:00       2019-08-10         06:11:00
# 4        2019-08-10          06:10:00       2019-08-10         06:11:00

# %%
df_lounge_elig_flight_info.shape
# Out:
# (860516, 27)

# %% [markdown]
# ### `df_country`

# %%
[headers_and_first_row(d) for d in [df_lounge_elig_flight_info,df_country]]
# Out:
# [{'Skew_Id': '2019-08-101414',
#   'OPERATING_AIRLINE_CD': 'BA',
#   'OPERATING_FLT_NO': 1414,
#   'GMT_UPLIFT_DT': datetime.date(2019, 8, 10),
#   'UPLIFT_STN_CD': 'LHR',
#   'DISCHARGE_STN_CD': 'BHD',
#   'BOOKED_CABIN_CD': 'M',
#   'TRAVEL_CABIN_CD': 'M',
#   'BA_PAX_TIER': 'Gold',
#   'ONEWORLD_TIER': 'EMER',
#   'Lounge_eligibility_tier': 'Tier 2',
#   'pax': 3,
#   'GMT_PLND_DEP_TS': Timestamp('2019-08-10 06:10:00'),
#   'GMT_ACT_DEP_TS': Timestamp('2019-08-10 06:11:00'),
#   'OPG_ALN_CD': 'BA',
#   'OPG_FLT_NO': 1414,
#   'ACT_DEP_STN_CD': 'LHR',
#   'ACT_DEP_TML_CD': '5',
#   'PLND_ARR_STN_CD': 'BHD',
#   'ACT_ARR_STN_CD': 'BHD',
#   'IATA_AC_TYP_CD': '320',
#   'ACT_AC_TYP_CD': 'A3',
#   'ROUTE': 'LHRBHD',
#   'GMT_PLND_DEP_DATE': datetime.date(2019, 8, 10),
#   'GMT_PLND_DEP_TIME': datetime.time(6, 10),
#   'GMT_ACT_DEP_DATE': datetime.date(2019, 8, 10),
#   'GMT_ACT_DEP_TIME': datetime.time(6, 11)},
#  {'ROUTE': 'LHRINV',
#   'COUNTRY_CD': 'GB',
#   'COUNTRY_NM': 'United Kingdom and Northern Ireland',
#   'CORP_GEOG_CTRY_GRP_NM': 'UK',
#   'CORP_GEOG_CONTINENT_NM': 'UK'}]

# %% [markdown]
# Joints:
# `df_lounge_elig_flight_info_country`:`'ROUTE'`
# `df_df_country`:`ROUTE`

# %%
df_lounge_elig_flight_info_country = pd.merge(df_lounge_elig_flight_info,# left table
                                     df_country, # right table
                                     left_on = ['ROUTE'], # left on? e.g. which columns from the left table are you joining on to?
                                     right_on = ['ROUTE'] , # right on? # left on? e.g. which columns from the right table are you joining on to?
                                     how = "inner" # how? e.g. left, right, inner,etc
                                     )

# df_lounge_elig_flight_info = df_lounge_elig_flight_info.drop_duplicates()

df_lounge_elig_flight_info_country.head(5)
# Out:
#           Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 0  2019-08-101414                   BA              1414    2019-08-10
# 1  2019-08-101414                   BA              1414    2019-08-10
# 2  2019-08-101414                   BA              1414    2019-08-10
# 3  2019-08-101414                   BA              1414    2019-08-10
# 4  2019-08-101414                   BA              1414    2019-08-10
#
#   UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD BA_PAX_TIER  \
# 0           LHR              BHD               M               M        Gold
# 1           LHR              BHD               M               M
# 2           LHR              BHD               C               C
# 3           LHR              BHD               M               M      Silver
# 4           LHR              BHD               C               C
#
#   ONEWORLD_TIER Lounge_eligibility_tier  pax     GMT_PLND_DEP_TS  \
# 0          EMER                  Tier 2    3 2019-08-10 06:10:00
# 1                          Not eligible  114 2019-08-10 06:10:00
# 2          EMER                  Tier 2    3 2019-08-10 06:10:00
# 3          SAPP                  Tier 3    7 2019-08-10 06:10:00
# 4          SAPP                  Tier 3    1 2019-08-10 06:10:00
#
#        GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO ACT_DEP_STN_CD ACT_DEP_TML_CD  \
# 0 2019-08-10 06:11:00         BA        1414            LHR              5
# 1 2019-08-10 06:11:00         BA        1414            LHR              5
# 2 2019-08-10 06:11:00         BA        1414            LHR              5
# 3 2019-08-10 06:11:00         BA        1414            LHR              5
# 4 2019-08-10 06:11:00         BA        1414            LHR              5
#
#   PLND_ARR_STN_CD ACT_ARR_STN_CD IATA_AC_TYP_CD ACT_AC_TYP_CD   ROUTE  \
# 0             BHD            BHD            320            A3  LHRBHD
# 1             BHD            BHD            320            A3  LHRBHD
# 2             BHD            BHD            320            A3  LHRBHD
# 3             BHD            BHD            320            A3  LHRBHD
# 4             BHD            BHD            320            A3  LHRBHD
#
#   GMT_PLND_DEP_DATE GMT_PLND_DEP_TIME GMT_ACT_DEP_DATE GMT_ACT_DEP_TIME  \
# 0        2019-08-10          06:10:00       2019-08-10         06:11:00
# 1        2019-08-10          06:10:00       2019-08-10         06:11:00
# 2        2019-08-10          06:10:00       2019-08-10         06:11:00
# 3        2019-08-10          06:10:00       2019-08-10         06:11:00
# 4        2019-08-10          06:10:00       2019-08-10         06:11:00
#
#   COUNTRY_CD                           COUNTRY_NM CORP_GEOG_CTRY_GRP_NM  \
# 0         GB  United Kingdom and Northern Ireland                    UK
# 1         GB  United Kingdom and Northern Ireland                    UK
# 2         GB  United Kingdom and Northern Ireland                    UK
# 3         GB  United Kingdom and Northern Ireland                    UK
# 4         GB  United Kingdom and Northern Ireland                    UK
#
#   CORP_GEOG_CONTINENT_NM
# 0                     UK
# 1                     UK
# 2                     UK
# 3                     UK
# 4                     UK

# %%
df_lounge_elig_flight_info_country.shape
# Out:
# (860516, 31)

# %% [markdown]
# ### `df_acft_typ`

# %%
[headers_and_first_row(d) for d in [df_lounge_elig_flight_info_country,df_acft_typ]]
# Out:
# [{'Skew_Id': '2019-08-101414',
#   'OPERATING_AIRLINE_CD': 'BA',
#   'OPERATING_FLT_NO': 1414,
#   'GMT_UPLIFT_DT': datetime.date(2019, 8, 10),
#   'UPLIFT_STN_CD': 'LHR',
#   'DISCHARGE_STN_CD': 'BHD',
#   'BOOKED_CABIN_CD': 'M',
#   'TRAVEL_CABIN_CD': 'M',
#   'BA_PAX_TIER': 'Gold',
#   'ONEWORLD_TIER': 'EMER',
#   'Lounge_eligibility_tier': 'Tier 2',
#   'pax': 3,
#   'GMT_PLND_DEP_TS': Timestamp('2019-08-10 06:10:00'),
#   'GMT_ACT_DEP_TS': Timestamp('2019-08-10 06:11:00'),
#   'OPG_ALN_CD': 'BA',
#   'OPG_FLT_NO': 1414,
#   'ACT_DEP_STN_CD': 'LHR',
#   'ACT_DEP_TML_CD': '5',
#   'PLND_ARR_STN_CD': 'BHD',
#   'ACT_ARR_STN_CD': 'BHD',
#   'IATA_AC_TYP_CD': '320',
#   'ACT_AC_TYP_CD': 'A3',
#   'ROUTE': 'LHRBHD',
#   'GMT_PLND_DEP_DATE': datetime.date(2019, 8, 10),
#   'GMT_PLND_DEP_TIME': datetime.time(6, 10),
#   'GMT_ACT_DEP_DATE': datetime.date(2019, 8, 10),
#   'GMT_ACT_DEP_TIME': datetime.time(6, 11),
#   'COUNTRY_CD': 'GB',
#   'COUNTRY_NM': 'United Kingdom and Northern Ireland',
#   'CORP_GEOG_CTRY_GRP_NM': 'UK',
#   'CORP_GEOG_CONTINENT_NM': 'UK'},
#  {'IATA_AC_TYP_CD': '320',
#   'ACT_AC_TYP_CD': 'A3',
#   'WB_NB_CAT': 'NB',
#   'FIRST_SEATS_QTY': 0,
#   'CLUB_SEATS_QTY': 24,
#   'PREM_ECONOMY_SEATS_QTY': 0,
#   'ECONOMY_SEATS_QTY': 132}]

# %% [markdown]
# Joints:
#
# `df_lounge_elig_flight_info_country`:`'IATA_AC_TYP_CD','ACT_AC_TYP_CD'`
#
# `df_acft_typ`:`'IATA_AC_TYP_CD','ACT_AC_TYP_CD'`

# %%
df_lounge_elig_flight_info_country_acft_typ = pd.merge(
    df_lounge_elig_flight_info_country,
    df_acft_typ,
    left_on = ['IATA_AC_TYP_CD','ACT_AC_TYP_CD'],
    right_on = ['IATA_AC_TYP_CD','ACT_AC_TYP_CD'],
    how = 'left'
)

df_lounge_elig_flight_info_country_acft_typ.head(10)
# Out:
#           Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 0  2019-08-101414                   BA              1414    2019-08-10
# 1  2019-08-101414                   BA              1414    2019-08-10
# 2  2019-08-101414                   BA              1414    2019-08-10
# 3  2019-08-101414                   BA              1414    2019-08-10
# 4  2019-08-101414                   BA              1414    2019-08-10
# 5  2019-08-101414                   BA              1414    2019-08-10
# 6  2019-08-101414                   BA              1414    2019-08-10
# 7  2019-08-101414                   BA              1414    2019-08-10
# 8  2019-08-101414                   BA              1414    2019-08-10
# 9  2019-08-101414                   BA              1414    2019-08-10
#
#   UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD BA_PAX_TIER  \
# 0           LHR              BHD               M               M        Gold
# 1           LHR              BHD               M               M
# 2           LHR              BHD               C               C
# 3           LHR              BHD               M               M      Silver
# 4           LHR              BHD               C               C
# 5           LHR              MXP               M               M
# 6           LHR              BHD               C               C        Gold
# 7           LHR              BHD               C               M        Gold
# 8           LHR              BHD               C               C      Silver
# 9           LHR              BHD               C               C
#
#   ONEWORLD_TIER Lounge_eligibility_tier  pax     GMT_PLND_DEP_TS  \
# 0          EMER                  Tier 2    3 2019-08-10 06:10:00
# 1                          Not eligible  114 2019-08-10 06:10:00
# 2          EMER                  Tier 2    3 2019-08-10 06:10:00
# 3          SAPP                  Tier 3    7 2019-08-10 06:10:00
# 4          SAPP                  Tier 3    1 2019-08-10 06:10:00
# 5                          Not eligible    7 2019-08-10 06:10:00
# 6          EMER                  Tier 2    4 2019-08-10 06:10:00
# 7          EMER                  Tier 2    1 2019-08-10 06:10:00
# 8          SAPP                  Tier 3    4 2019-08-10 06:10:00
# 9                                Tier 3   10 2019-08-10 06:10:00
#
#        GMT_ACT_DEP_TS OPG_ALN_CD  OPG_FLT_NO ACT_DEP_STN_CD ACT_DEP_TML_CD  \
# 0 2019-08-10 06:11:00         BA        1414            LHR              5
# 1 2019-08-10 06:11:00         BA        1414            LHR              5
# 2 2019-08-10 06:11:00         BA        1414            LHR              5
# 3 2019-08-10 06:11:00         BA        1414            LHR              5
# 4 2019-08-10 06:11:00         BA        1414            LHR              5
# 5 2019-08-10 06:11:00         BA        1414            LHR              5
# 6 2019-08-10 06:11:00         BA        1414            LHR              5
# 7 2019-08-10 06:11:00         BA        1414            LHR              5
# 8 2019-08-10 06:11:00         BA        1414            LHR              5
# 9 2019-08-10 06:11:00         BA        1414            LHR              5
#
#   PLND_ARR_STN_CD ACT_ARR_STN_CD IATA_AC_TYP_CD ACT_AC_TYP_CD   ROUTE  \
# 0             BHD            BHD            320            A3  LHRBHD
# 1             BHD            BHD            320            A3  LHRBHD
# 2             BHD            BHD            320            A3  LHRBHD
# 3             BHD            BHD            320            A3  LHRBHD
# 4             BHD            BHD            320            A3  LHRBHD
# 5             BHD            BHD            320            A3  LHRBHD
# 6             BHD            BHD            320            A3  LHRBHD
# 7             BHD            BHD            320            A3  LHRBHD
# 8             BHD            BHD            320            A3  LHRBHD
# 9             BHD            BHD            320            A3  LHRBHD
#
#   GMT_PLND_DEP_DATE GMT_PLND_DEP_TIME GMT_ACT_DEP_DATE GMT_ACT_DEP_TIME  \
# 0        2019-08-10          06:10:00       2019-08-10         06:11:00
# 1        2019-08-10          06:10:00       2019-08-10         06:11:00
# 2        2019-08-10          06:10:00       2019-08-10         06:11:00
# 3        2019-08-10          06:10:00       2019-08-10         06:11:00
# 4        2019-08-10          06:10:00       2019-08-10         06:11:00
# 5        2019-08-10          06:10:00       2019-08-10         06:11:00
# 6        2019-08-10          06:10:00       2019-08-10         06:11:00
# 7        2019-08-10          06:10:00       2019-08-10         06:11:00
# 8        2019-08-10          06:10:00       2019-08-10         06:11:00
# 9        2019-08-10          06:10:00       2019-08-10         06:11:00
#
#   COUNTRY_CD                           COUNTRY_NM CORP_GEOG_CTRY_GRP_NM  \
# 0         GB  United Kingdom and Northern Ireland                    UK
# 1         GB  United Kingdom and Northern Ireland                    UK
# 2         GB  United Kingdom and Northern Ireland                    UK
# 3         GB  United Kingdom and Northern Ireland                    UK
# 4         GB  United Kingdom and Northern Ireland                    UK
# 5         GB  United Kingdom and Northern Ireland                    UK
# 6         GB  United Kingdom and Northern Ireland                    UK
# 7         GB  United Kingdom and Northern Ireland                    UK
# 8         GB  United Kingdom and Northern Ireland                    UK
# 9         GB  United Kingdom and Northern Ireland                    UK
#
#   CORP_GEOG_CONTINENT_NM WB_NB_CAT  FIRST_SEATS_QTY  CLUB_SEATS_QTY  \
# 0                     UK        NB              0.0            24.0
# 1                     UK        NB              0.0            24.0
# 2                     UK        NB              0.0            24.0
# 3                     UK        NB              0.0            24.0
# 4                     UK        NB              0.0            24.0
# 5                     UK        NB              0.0            24.0
# 6                     UK        NB              0.0            24.0
# 7                     UK        NB              0.0            24.0
# 8                     UK        NB              0.0            24.0
# 9                     UK        NB              0.0            24.0
#
#    PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY
# 0                     0.0              132.0
# 1                     0.0              132.0
# 2                     0.0              132.0
# 3                     0.0              132.0
# 4                     0.0              132.0
# 5                     0.0              132.0
# 6                     0.0              132.0
# 7                     0.0              132.0
# 8                     0.0              132.0
# 9                     0.0              132.0

# %%
df_lounge_elig_flight_info_country_acft_typ.shape
# Out:
# (860516, 36)

# %% [markdown]
# ## More Cleaning
# - Let's check the headers and first row as some of them are noise(?)

# %%
headers_and_first_row(df_lounge_elig_flight_info_country_acft_typ)
# Out:
# {'Skew_Id': '2019-08-101414',
#  'OPERATING_AIRLINE_CD': 'BA',
#  'OPERATING_FLT_NO': 1414,
#  'GMT_UPLIFT_DT': datetime.date(2019, 8, 10),
#  'UPLIFT_STN_CD': 'LHR',
#  'DISCHARGE_STN_CD': 'BHD',
#  'BOOKED_CABIN_CD': 'M',
#  'TRAVEL_CABIN_CD': 'M',
#  'BA_PAX_TIER': 'Gold',
#  'ONEWORLD_TIER': 'EMER',
#  'Lounge_eligibility_tier': 'Tier 2',
#  'pax': 3,
#  'GMT_PLND_DEP_TS': Timestamp('2019-08-10 06:10:00'),
#  'GMT_ACT_DEP_TS': Timestamp('2019-08-10 06:11:00'),
#  'OPG_ALN_CD': 'BA',
#  'OPG_FLT_NO': 1414,
#  'ACT_DEP_STN_CD': 'LHR',
#  'ACT_DEP_TML_CD': '5',
#  'PLND_ARR_STN_CD': 'BHD',
#  'ACT_ARR_STN_CD': 'BHD',
#  'IATA_AC_TYP_CD': '320',
#  'ACT_AC_TYP_CD': 'A3',
#  'ROUTE': 'LHRBHD',
#  'GMT_PLND_DEP_DATE': datetime.date(2019, 8, 10),
#  'GMT_PLND_DEP_TIME': datetime.time(6, 10),
#  'GMT_ACT_DEP_DATE': datetime.date(2019, 8, 10),
#  'GMT_ACT_DEP_TIME': datetime.time(6, 11),
#  'COUNTRY_CD': 'GB',
#  'COUNTRY_NM': 'United Kingdom and Northern Ireland',
#  'CORP_GEOG_CTRY_GRP_NM': 'UK',
#  'CORP_GEOG_CONTINENT_NM': 'UK',
#  'WB_NB_CAT': 'NB',
#  'FIRST_SEATS_QTY': 0.0,
#  'CLUB_SEATS_QTY': 24.0,
#  'PREM_ECONOMY_SEATS_QTY': 0.0,
#  'ECONOMY_SEATS_QTY': 132.0}

# %% [markdown]
# Cloumns to drop:
# `'GMT_PLND_DEP_TS','GMT_ACT_DEP_TS','OPG_ALN_CD','OPG_FLT_NO','ACT_DEP_STN_CD','PLND_ARR_STN_CD','ACT_ARR_STN_CD','GMT_ACT_DEP_DATE','GMT_ACT_DEP_TIME'`

# %%
to_drop = ['GMT_PLND_DEP_TS','GMT_ACT_DEP_TS','OPG_ALN_CD','OPG_FLT_NO','ACT_DEP_STN_CD','PLND_ARR_STN_CD','ACT_ARR_STN_CD','GMT_ACT_DEP_DATE','GMT_ACT_DEP_TIME']

df_lounge_elig_flight_info_country_acft_typ = df_lounge_elig_flight_info_country_acft_typ.drop(columns = to_drop,)

df_lounge_elig_flight_info_country_acft_typ.head(5)
# Out:
#           Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 0  2019-08-101414                   BA              1414    2019-08-10
# 1  2019-08-101414                   BA              1414    2019-08-10
# 2  2019-08-101414                   BA              1414    2019-08-10
# 3  2019-08-101414                   BA              1414    2019-08-10
# 4  2019-08-101414                   BA              1414    2019-08-10
#
#   UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD BA_PAX_TIER  \
# 0           LHR              BHD               M               M        Gold
# 1           LHR              BHD               M               M
# 2           LHR              BHD               C               C
# 3           LHR              BHD               M               M      Silver
# 4           LHR              BHD               C               C
#
#   ONEWORLD_TIER Lounge_eligibility_tier  pax ACT_DEP_TML_CD IATA_AC_TYP_CD  \
# 0          EMER                  Tier 2    3              5            320
# 1                          Not eligible  114              5            320
# 2          EMER                  Tier 2    3              5            320
# 3          SAPP                  Tier 3    7              5            320
# 4          SAPP                  Tier 3    1              5            320
#
#   ACT_AC_TYP_CD   ROUTE GMT_PLND_DEP_DATE GMT_PLND_DEP_TIME COUNTRY_CD  \
# 0            A3  LHRBHD        2019-08-10          06:10:00         GB
# 1            A3  LHRBHD        2019-08-10          06:10:00         GB
# 2            A3  LHRBHD        2019-08-10          06:10:00         GB
# 3            A3  LHRBHD        2019-08-10          06:10:00         GB
# 4            A3  LHRBHD        2019-08-10          06:10:00         GB
#
#                             COUNTRY_NM CORP_GEOG_CTRY_GRP_NM  \
# 0  United Kingdom and Northern Ireland                    UK
# 1  United Kingdom and Northern Ireland                    UK
# 2  United Kingdom and Northern Ireland                    UK
# 3  United Kingdom and Northern Ireland                    UK
# 4  United Kingdom and Northern Ireland                    UK
#
#   CORP_GEOG_CONTINENT_NM WB_NB_CAT  FIRST_SEATS_QTY  CLUB_SEATS_QTY  \
# 0                     UK        NB              0.0            24.0
# 1                     UK        NB              0.0            24.0
# 2                     UK        NB              0.0            24.0
# 3                     UK        NB              0.0            24.0
# 4                     UK        NB              0.0            24.0
#
#    PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY
# 0                     0.0              132.0
# 1                     0.0              132.0
# 2                     0.0              132.0
# 3                     0.0              132.0
# 4                     0.0              132.0
