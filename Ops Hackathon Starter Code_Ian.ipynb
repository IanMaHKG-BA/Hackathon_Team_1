# %% [markdown]
# ## Connect to ICW:

# %%
import cadspy

# %%
icw = cadspy.DatabaseConnection(system='ICW', user='u243696')

# %% [markdown]
# <br>
# <div class="alert alert-" style = "border-radius:10px;border-width:3px;border-color:salmon;font-family:Verdana,sans-serif;font-size:16px;">
#
# <font size="4">Can't connect to ICW? Instructions on how to get access to it in the links below:
#
# </font>
# </div>

# %% [markdown]
# - Step 1: [Requesting Access to GitHub](https://baplc.sharepoint.com/sites/ask/SitePages/Requesting-Access-to-GitHub.aspx)
#
# Once your access to GitHub has been aproved, you need to:
#
# - Step 2: [Request access to British-Ent GitHub organisation](https://github.com/BritishAirways-Ent/insight-processes/blob/main/onboarding/Corporate_Directory_git.md)
#
# And
#
# - Step 3: [Setup Sagemaker Studio to access GitHub](https://github.com/BritishAirways-Ent/insight-processes/blob/main/onboarding/sagemaker_to_github_setup.md)
#
# <br>

# %% [markdown]
# Below are some packages to get you started. You don't have to use them but you may find them useful!

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %%
# diplay all rows and cols when using 'dataframe'.head() or 'dataframe'.tail()
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# <br>
#
# ### Data
#
# #### S19 Lounge Eligibility data

# %%
query = """

sel * from LDB_SBOX_OR.HACKATHON_OPS_LOUNGE_ELIGIBILITY

"""

df_lounge_eligibility = icw.queryToDataframe(query)

# %%
df_lounge_eligibility.head(10)
# Out:
#           Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 0  2019-08-101414               BA                  1414    2019-08-10
# 1   2023-05-17920               BA                   920    2023-05-17
# 2   2019-04-15770               BA                   770    2019-04-15
# 3   2019-09-23348               BA                   348    2019-09-23
# 4   2019-09-16155               BA                   155    2019-09-16
# 5   2023-08-05666               BA                   666    2023-08-05
# 6   2019-07-03227               BA                   227    2019-07-03
# 7  2019-06-301448               BA                  1448    2019-06-30
# 8   2019-04-27886               BA                   886    2019-04-27
# 9   2023-10-01558               BA                   558    2023-10-01
#
#   UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD BA_PAX_TIER  \
# 0        LHR              BHD                 M               M         Gold
# 1        LHR              STR                 C               C
# 2        LHR              OSL                 M               M
# 3        LHR              NCE                 M               M
# 4        LHR              CAI                 J               J
# 5        LHR              CHQ                 C               C         Gold
# 6        LHR              ATL                 J               J         Gold
# 7        LHR              EDI                 C               C
# 8        LHR              OTP                 M               M
# 9        LHR              FCO                 M               M         Gold
#
#   ONEWORLD_TIER Lounge_eligibility_tier  pax
# 0          EMER                  Tier 2    3
# 1                                Tier 3   13
# 2                          Not eligible   75
# 3          EMER                  Tier 2    6
# 4                                Tier 3   23
# 5          EMER                  Tier 2    3
# 6          EMER                  Tier 2    4
# 7          SAPP                  Tier 3    4
# 8          EMER                  Tier 2    1
# 9          EMER                  Tier 2    3

# %%
df_lounge_eligibility.shape
# Out:
# (1561588, 12)

# %%
# a look to a particular flight number and date

mask = (df_lounge_eligibility['DISCHARGE_STN_CD'] == 'GCM   ') & (df_lounge_eligibility['GMT_UPLIFT_DT'] == dt.date(2019,9,12) )

df_lounge_eligibility[mask]
# Out:
#              Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 48673  2019-09-12253               BA                   253    2019-09-12
# 49825  2019-09-12253               BA                   253    2019-09-12
# 50401  2019-09-12253               BA                   253    2019-09-12
# 52129  2019-09-12253               BA                   253    2019-09-12
# 52705  2019-09-12253               BA                   253    2019-09-12
# 54433  2019-09-12253               BA                   253    2019-09-12
# 55009  2019-09-12253               BA                   253    2019-09-12
#
#       UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD  \
# 48673        LHR              GCM                 M               M
# 49825        LHR              GCM                 J               J
# 50401        LHR              GCM                 M               M
# 52129        LHR              GCM                 J               J
# 52705        LHR              GCM                 J               J
# 54433        LHR              GCM                 W               W
# 55009        LHR              GCM                 J               J
#
#       BA_PAX_TIER ONEWORLD_TIER Lounge_eligibility_tier  pax
# 48673                                      Not eligible  157
# 49825                      EMER                  Tier 2    1
# 50401      Silver          SAPP                  Tier 3    2
# 52129        Gold          EMER                  Tier 2    2
# 52705      Silver          SAPP                  Tier 3    3
# 54433                                      Not eligible   19
# 55009                                            Tier 3    8

# %% [markdown]
# Here to see if any flight ended up having two destination (As we found a fligh flying to Edinburgh and Belfast simultainously)

# %%
df_lounge_by_skew = df_lounge_eligibility.groupby(['Skew_Id','OPERATING_FLT_NO','DISCHARGE_STN_CD'], as_index = False).agg(pax_count = ('pax','sum'))

df_lounge_by_skew.head(20)
# Out:
#            Skew_Id  OPERATING_FLT_NO DISCHARGE_STN_CD  pax_count
# 0    2019-03-31103               103           YYC           197
# 1    2019-03-31105               105           DXB           209
# 2    2019-03-31107               107           DXB           201
# 3    2019-03-31109               109           DXB           217
# 4     2019-03-3111                11           SIN           443
# 5    2019-03-31113               113           JFK           212
# 6    2019-03-31115               115           JFK           212
# 7    2019-03-31117               117           JFK           234
# 8    2019-03-31119               119           BLR           261
# 9    2019-03-31123               123           DOH           177
# 10   2019-03-31125               125           BAH           195
# 11  2019-03-311306              1306           ABZ           104
# 12  2019-03-311308              1308           ABZ           125
# 13  2019-03-311314              1314           ABZ           163
# 14  2019-03-311316              1316           ABZ           201
# 15  2019-03-311318              1318           ABZ           105
# 16  2019-03-311324              1324           NCL            72
# 17  2019-03-311326              1326           NCL           118
# 18   2019-03-31133               133           JED           179
# 19  2019-03-311334              1334           NCL           157

# %%
duplicated_flag = df_lounge_by_skew.duplicated('Skew_Id',keep = False)

df_lounge_by_skew_duplicated = df_lounge_by_skew[duplicated_flag].sort_values(['Skew_Id','OPERATING_FLT_NO'])

df_lounge_by_skew_duplicated.head(10)
# Out:
#             Skew_Id  OPERATING_FLT_NO DISCHARGE_STN_CD  pax_count
# 38   2019-03-311448              1448           ABZ             1
# 39   2019-03-311448              1448           EDI           139
# 55     2019-03-3115                15           SIN           165
# 56     2019-03-3115                15           SYD           114
# 165   2019-03-31462               462           MAD           173
# 166   2019-03-31462               462           PHX            15
# 348  2019-04-011314              1314           ABZ           119
# 349  2019-04-011314              1314           BHD             1
# 395    2019-04-0115                15           SIN            97
# 396    2019-04-0115                15           SYD           114

# %% [markdown]
# #### S19 Flight info

# %%
query = """

select * from LDB_SBOX_OR.HACKATHON_OPS_FLIGHT_INFO

"""

df_flight_info = icw.queryToDataframe(query)

# %%
df_flight_info.head(10)
# Out:
#   OPG_ALN_CD  OPG_FLT_NO     GMT_PLND_DEP_TS      GMT_ACT_DEP_TS  \
# 0     BA             548 2019-06-03 07:30:00 2019-06-03 07:27:00
# 1     BA             490 2019-06-12 10:35:00 2019-06-12 10:31:00
# 2     BA             386 2019-07-19 17:35:00 2019-07-19 18:14:00
# 3     BA             582 2019-05-22 19:35:00 2019-05-22 19:32:00
# 4     BA             275 2019-05-18 15:40:00 2019-05-18 15:38:00
# 5     BA             263 2019-07-18 12:45:00 2019-07-18 12:55:00
# 6     BA             155 2019-04-04 16:15:00 2019-04-04 16:26:00
# 7     BA             586 2019-08-03 06:40:00 2019-08-03 06:59:00
# 8     BA             672 2019-07-23 19:15:00 2019-07-23 19:15:00
# 9     BA             243 2023-05-19 14:20:00 2023-05-19 14:44:00
#
#   ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD IATA_AC_TYP_CD  \
# 0         LHR                5           FCO            FCO            321
# 1         LHR                3           GIB            GIB            320
# 2         LHR                5           NTE            NTE            321
# 3         LHR                5           MXP            VRN            32A
# 4         LHR                3           LAS            LAS            744
# 5         LHR                5           RUH            RUH            744
# 6         LHR                5           CAI            CAI            789
# 7         LHR                5           BIA            BIA            32N
# 8         LHR                5           LCA            PFO            320
# 9         LHR                5           MEX            CUN            789
#
#   ACT_AC_TYP_CD         ROUTE COUNTRY_CD     COUNTRY_NM CORP_GEOG_CTRY_GRP_NM  \
# 0          V6    LHRFCO           IT              Italy         MEDITERRANEAN
# 1          A3    LHRGIB           GI          Gibraltar         MEDITERRANEAN
# 2          V6    LHRNTE           FR             France           WEST EUROPE
# 3          H3    LHRMXP           IT              Italy         MEDITERRANEAN
# 4          V4    LHRLAS           US      United States                   USA
# 5          S4    LHRRUH           SA       Saudi Arabia          SAUDI ARABIA
# 6          L8    LHRCAI           EG              Egypt          NORTH AFRICA
# 7          N3    LHRBIA           FR             France           WEST EUROPE
# 8          A3    LHRLCA           CY             Cyprus         MEDITERRANEAN
# 9          L8    LHRCUN           MX             Mexico       CENTRAL AMERICA
#
#         CORP_GEOG_CONTINENT_NM
# 0                EUROPE EXC UK
# 1                EUROPE EXC UK
# 2                EUROPE EXC UK
# 3                EUROPE EXC UK
# 4                NORTH AMERICA
# 5                  MIDDLE EAST
# 6                       AFRICA
# 7                EUROPE EXC UK
# 8                EUROPE EXC UK
# 9  SOUTH AMERICA INC CARIBBEAN

# %%
df_flight_info.shape
# Out:
# (123135, 15)

# %% [markdown]
# There let's use the ABZ/EDI duplicated to find something
# - BA 1448 @ 2019-03-31

# %%
df_flight_info[(df_flight_info['OPG_FLT_NO'] == 1448) & (pd.to_datetime(df_flight_info['GMT_PLND_DEP_TS']).dt.date == dt.date(2019,3,31))]
# Out:
#        OPG_ALN_CD  OPG_FLT_NO     GMT_PLND_DEP_TS      GMT_ACT_DEP_TS  \
# 101260     BA            1448 2019-03-31 14:20:00 2019-03-31 14:24:00
#
#        ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD  \
# 101260         LHR                5           EDI            EDI
#
#        IATA_AC_TYP_CD ACT_AC_TYP_CD         ROUTE COUNTRY_CD  \
# 101260         320             A3    LHREDI           GB
#
#                                  COUNTRY_NM CORP_GEOG_CTRY_GRP_NM  \
# 101260  United Kingdom and Northern Ireland                    UK
#
#        CORP_GEOG_CONTINENT_NM
# 101260                     UK

# %% [markdown]
# This Shows There there should not be any passenger taking the BA 1448 on 2019-3-31 to Aberdeen, as there is no record

# %% [markdown]
# Check for duplicates for flight info

# %%
# df_flight_info_by_flight = df_flight_info_by_flight.groupby(['OPG_ALN_','DISCHARGE_STN_CD'], as_index = False).agg(pax_count = ('pax','sum'))
duplicated_flag = df_flight_info.duplicated(subset=['OPG_FLT_NO','GMT_PLND_DEP_TS'],keep=False)
df_flight_info_duplicated = df_flight_info[duplicated_flag].sort_values(['OPG_FLT_NO','GMT_PLND_DEP_TS'])

# df_flight_info_duplicated.head(10)
df_flight_info_duplicated[['OPG_FLT_NO','GMT_PLND_DEP_TS','ROUTE','PLND_ARR_STN_CD','ACT_ARR_STN_CD']].head(20)
# Out:
#        OPG_FLT_NO     GMT_PLND_DEP_TS         ROUTE PLND_ARR_STN_CD  \
# 6366           31 2023-09-06 17:00:00  LHRLHR                HKG
# 63963          31 2023-09-06 17:00:00  LHRHKG                HKG
# 5050           55 2023-08-06 18:05:00  LHRLHR                JNB
# 70885          55 2023-08-06 18:05:00  LHRJNB                JNB
# 4604           65 2023-04-15 09:10:00  LHRLHR                NBO
# 41149          65 2023-04-15 09:10:00  LHRNBO                NBO
# 1285          119 2019-07-03 13:15:00  LHRBLR                BLR
# 3349          119 2019-07-03 13:15:00  LHRBLR                BLR
# 3705          207 2023-06-22 09:25:00  LHRLHR                MIA
# 65148         207 2023-06-22 09:25:00  LHRMIA                MIA
# 2799          217 2023-06-16 11:35:00  LHRLHR                IAD
# 69795         217 2023-06-16 11:35:00  LHRIAD                IAD
# 1133          223 2019-04-29 13:45:00  LHRBNA                BNA
# 18339         223 2019-04-29 13:45:00  LHRBNA                BNA
# 207           249 2019-07-17 11:20:00  LHRGIG                GIG
# 19535         249 2019-07-17 11:20:00  LHRGIG                GIG
# 4305          249 2023-08-02 11:25:00  LHRLHR                GIG
# 33604         249 2023-08-02 11:25:00  LHRGIG                GIG
# 33            251 2019-07-05 21:00:00  LHRSCL                SCL
# 14494         251 2019-07-05 21:00:00  LHRSCL                SCL
#
#       ACT_ARR_STN_CD
# 6366          LHR
# 63963         HKG
# 5050          LHR
# 70885         JNB
# 4604          LHR
# 41149         NBO
# 1285          LHR
# 3349          BLR
# 3705          LHR
# 65148         MIA
# 2799          LHR
# 69795         IAD
# 1133          LHR
# 18339         BNA
# 207           LHR
# 19535         GIG
# 4305          LHR
# 33604         GIG
# 33            LHR
# 14494         SCL

# %% [markdown]
# Here we can see some flights have an identical record for LHR-LHR? (Weird)

# %% [markdown]
# #### Station Code Decode

# %%
query = """

select * from LDB_SBOX_OR.HACKATHON_OPS_COUNTRY_DECODE

"""

df_country = icw.queryToDataframe(query)

# %%
df_country.head(10)
# Out:
#     ROUTE COUNTRY_CD                           COUNTRY_NM  \
# 0  LHRINV        GB   United Kingdom and Northern Ireland
# 1  LHRSVO        RU                      Russia in Europe
# 2  LHREZE        AR                             Argentina
# 3  LHRLUX        LU                            Luxembourg
# 4  LHRCAI        EG                                 Egypt
# 5  LHREFL        GR                                Greece
# 6  LHRLJU        SI                              Slovenia
# 7  LHRNCE        FR                                France
# 8  LHRHKG        HK              Hong Kong - SAR of China
# 9  LHRCFU        GR                                Greece
#
#   CORP_GEOG_CTRY_GRP_NM       CORP_GEOG_CONTINENT_NM
# 0                    UK                           UK
# 1        EASTERN EUROPE                EUROPE EXC UK
# 2         SOUTH AMERICA  SOUTH AMERICA INC CARIBBEAN
# 3               BENELUX                EUROPE EXC UK
# 4          NORTH AFRICA                       AFRICA
# 5         MEDITERRANEAN                EUROPE EXC UK
# 6        EASTERN EUROPE                EUROPE EXC UK
# 7           WEST EUROPE                EUROPE EXC UK
# 8         FAR EAST HUBS                ASIA FAR EAST
# 9         MEDITERRANEAN                EUROPE EXC UK

# %% [markdown]
# See if LHRLHR route actually exists

# %%
df_country[df_country['ROUTE'] == 'LHRLHR']
# Out:
# Empty DataFrame
# Columns: [ROUTE, COUNTRY_CD, COUNTRY_NM, CORP_GEOG_CTRY_GRP_NM, CORP_GEOG_CONTINENT_NM]
# Index: []

# %% [markdown]
# It shold not exists

# %% [markdown]
# #### Aircraft Type

# %%
query = """

select * from LDB_SBOX_OR.HACKATHON_OPS_AC_TYPE

"""

df_acft_typ = icw.queryToDataframe(query)

# %%
df_acft_typ.head(10)
# Out:
#   IATA_AC_TYP_CD ACT_AC_TYP_CD WB_NB_CAT  FIRST_SEATS_QTY  CLUB_SEATS_QTY  \
# 0            320            A3        NB                0              24
# 1            777            K7        WB                0              48
# 2            32N            N3        NB                0              20
# 3            321            M6        NB                0              23
# 4            32Q            N6        NB                0              32
# 5            789            L8        WB                8              42
# 6            32A            H3        NB                0              20
# 7            319            A4        NB                0              16
# 8            788            B8        WB                0              35
# 9            77W            G7        WB               14              56
#
#    PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY
# 0                       0                132
# 1                      24                203
# 2                       0                150
# 3                       0                131
# 4                       0                172
# 5                      39                127
# 6                       0                150
# 7                       0                119
# 8                      25                154
# 9                      44                183

# %%
df_acft_typ.shape
# Out:
# (20, 7)

# %%
df_acft_typ
# Out:
#    IATA_AC_TYP_CD ACT_AC_TYP_CD WB_NB_CAT  FIRST_SEATS_QTY  CLUB_SEATS_QTY  \
# 0             320            A3        NB                0              24
# 1             777            K7        WB                0              48
# 2             32N            N3        NB                0              20
# 3             321            M6        NB                0              23
# 4             32Q            N6        NB                0              32
# 5             789            L8        WB                8              42
# 6             32A            H3        NB                0              20
# 7             319            A4        NB                0              16
# 8             788            B8        WB                0              35
# 9             77W            G7        WB               14              56
# 10            744            S4        WB               14              86
# 11            343            W9        WB                0              45
# 12            388            A8        WB               14              97
# 13            777            L7        WB                0              48
# 14            321            V6        NB                0              38
# 15            744            V4        WB               14              52
# 16            777            P7        WB               17              48
# 17            321            W6        NB                0              42
# 18            777            V7        WB               14              48
# 19            777            W7        WB               12              48
#
#     PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY
# 0                        0                132
# 1                       24                203
# 2                        0                150
# 3                        0                131
# 4                        0                172
# 5                       39                127
# 6                        0                150
# 7                        0                119
# 8                       25                154
# 9                       44                183
# 10                      30                145
# 11                       0                212
# 12                      55                303
# 13                      24                203
# 14                       0                160
# 15                      36                235
# 16                      24                127
# 17                       0                154
# 18                      40                124
# 19                      32                127

# %% [markdown]
# <br>
#
# ### Pre-processing

# %% [markdown]
# *Hint:* It is always worth checking the format of each of the columns in your dataframes before trying to do any work with them. To do so, you can make use of the `headers_and_first_row` function below.

# %%
def headers_and_first_row(df):
    '''
    print headers and first row of a df to deal with data types
    '''
    
    headers = df.columns
    first_row = []

    for col in headers:
        first_row.append(df[col][0])
    
    dictionary = dict( zip( headers, first_row) )

    return dictionary

# %%
# applying headers_and_first_row to df_lounge_eligibility
format_df = headers_and_first_row(df_lounge_eligibility)

# %%
# Note that some columns have blank spaces!
format_df
# Out:
# {'Skew_Id': '2019-08-101414',
#  'OPERATING_AIRLINE_CD': 'BA    ',
#  'OPERATING_FLT_NO': 1414,
#  'GMT_UPLIFT_DT': datetime.date(2019, 8, 10),
#  'UPLIFT_STN_CD': 'LHR   ',
#  'DISCHARGE_STN_CD': 'BHD   ',
#  'BOOKED_CABIN_CD': 'M ',
#  'TRAVEL_CABIN_CD': 'M ',
#  'BA_PAX_TIER': 'Gold',
#  'ONEWORLD_TIER': 'EMER',
#  'Lounge_eligibility_tier': 'Tier 2',
#  'pax': 3}

# %% [markdown]
# <br>
# <div class="alert alert-" style = "border-radius:10px;border-width:3px;border-color:lightblue;font-family:Verdana,sans-serif;font-size:16px;">
#
# <font size="3">**Exercise 1:** Pre-process **all** the tables above (df_lounge_eligibility, df_flight_info, df_country, df_acft_typ).
#
# </font>
#
# </ol>
# </div>

# %% [markdown]
# Check all the tables' formats

# %%
tables = [df_lounge_eligibility,df_flight_info,df_country,df_acft_typ]

[headers_and_first_row(t) for t in tables]
# Out:
# [{'Skew_Id': '2019-08-101414',
#   'OPERATING_AIRLINE_CD': 'BA    ',
#   'OPERATING_FLT_NO': 1414,
#   'GMT_UPLIFT_DT': datetime.date(2019, 8, 10),
#   'UPLIFT_STN_CD': 'LHR   ',
#   'DISCHARGE_STN_CD': 'BHD   ',
#   'BOOKED_CABIN_CD': 'M ',
#   'TRAVEL_CABIN_CD': 'M ',
#   'BA_PAX_TIER': 'Gold',
#   'ONEWORLD_TIER': 'EMER',
#   'Lounge_eligibility_tier': 'Tier 2',
#   'pax': 3},
#  {'OPG_ALN_CD': 'BA    ',
#   'OPG_FLT_NO': 548,
#   'GMT_PLND_DEP_TS': Timestamp('2019-06-03 07:30:00'),
#   'GMT_ACT_DEP_TS': Timestamp('2019-06-03 07:27:00'),
#   'ACT_DEP_STN_CD': 'LHR   ',
#   'ACT_DEP_TML_CD': '5 ',
#   'PLND_ARR_STN_CD': 'FCO   ',
#   'ACT_ARR_STN_CD': 'FCO   ',
#   'IATA_AC_TYP_CD': '321   ',
#   'ACT_AC_TYP_CD': 'V6  ',
#   'ROUTE': 'LHRFCO      ',
#   'COUNTRY_CD': 'IT    ',
#   'COUNTRY_NM': 'Italy',
#   'CORP_GEOG_CTRY_GRP_NM': 'MEDITERRANEAN',
#   'CORP_GEOG_CONTINENT_NM': 'EUROPE EXC UK'},
#  {'ROUTE': 'LHRINV',
#   'COUNTRY_CD': 'GB ',
#   'COUNTRY_NM': 'United Kingdom and Northern Ireland',
#   'CORP_GEOG_CTRY_GRP_NM': 'UK',
#   'CORP_GEOG_CONTINENT_NM': 'UK'},
#  {'IATA_AC_TYP_CD': '320',
#   'ACT_AC_TYP_CD': 'A3',
#   'WB_NB_CAT': 'NB',
#   'FIRST_SEATS_QTY': 0,
#   'CLUB_SEATS_QTY': 24,
#   'PREM_ECONOMY_SEATS_QTY': 0,
#   'ECONOMY_SEATS_QTY': 132}]

# %% [markdown]
# Obviously all the texts needs to has the blank spaces removed

# %%
# Define a function that fine all string fields and remove all blak spaces
def data_cleaning_string(df):
    # Get names of all fields in a dataframe
    fields = df.columns
    # loop for all fields, if data type is string then remove blank spaces
    for f in fields:
        if type(df[f][0]) == str:
            df[f] = df[f].str.strip()
    return df

# %% [markdown]
# Remove all blank spaces and check

# %%
for i,t in enumerate(tables):
    tables[i] = data_cleaning_string(t)

[headers_and_first_row(t) for t in tables]
# Out:
# [{'Skew_Id': '2019-08-101414',
#   'OPERATING_AIRLINE_CD': 'BA',
#   'OPERATING_FLT_NO': 1414,
#   'GMT_UPLIFT_DT': datetime.date(2019, 8, 10),
#   'UPLIFT_STN_CD': 'LHR',
#   'DISCHARGE_STN_CD': 'BHD',
#   'BOOKED_CABIN_CD': 'M',
#   'TRAVEL_CABIN_CD': 'M',
#   'BA_PAX_TIER': 'Gold',
#   'ONEWORLD_TIER': 'EMER',
#   'Lounge_eligibility_tier': 'Tier 2',
#   'pax': 3},
#  {'OPG_ALN_CD': 'BA',
#   'OPG_FLT_NO': 548,
#   'GMT_PLND_DEP_TS': Timestamp('2019-06-03 07:30:00'),
#   'GMT_ACT_DEP_TS': Timestamp('2019-06-03 07:27:00'),
#   'ACT_DEP_STN_CD': 'LHR',
#   'ACT_DEP_TML_CD': '5',
#   'PLND_ARR_STN_CD': 'FCO',
#   'ACT_ARR_STN_CD': 'FCO',
#   'IATA_AC_TYP_CD': '321',
#   'ACT_AC_TYP_CD': 'V6',
#   'ROUTE': 'LHRFCO',
#   'COUNTRY_CD': 'IT',
#   'COUNTRY_NM': 'Italy',
#   'CORP_GEOG_CTRY_GRP_NM': 'MEDITERRANEAN',
#   'CORP_GEOG_CONTINENT_NM': 'EUROPE EXC UK'},
#  {'ROUTE': 'LHRINV',
#   'COUNTRY_CD': 'GB',
#   'COUNTRY_NM': 'United Kingdom and Northern Ireland',
#   'CORP_GEOG_CTRY_GRP_NM': 'UK',
#   'CORP_GEOG_CONTINENT_NM': 'UK'},
#  {'IATA_AC_TYP_CD': '320',
#   'ACT_AC_TYP_CD': 'A3',
#   'WB_NB_CAT': 'NB',
#   'FIRST_SEATS_QTY': 0,
#   'CLUB_SEATS_QTY': 24,
#   'PREM_ECONOMY_SEATS_QTY': 0,
#   'ECONOMY_SEATS_QTY': 132}]

# %% [markdown]
# Also note that for `df_flight_info`, we will need to split the Timestamp to date and time

# %%
# Create date and time fields for the time stamp fields
df_flight_info['GMT_PLND_DEP_DATE'] = pd.to_datetime(df_flight_info['GMT_PLND_DEP_TS']).dt.date
df_flight_info['GMT_PLND_DEP_TIME'] = pd.to_datetime(df_flight_info['GMT_PLND_DEP_TS']).dt.time
df_flight_info['GMT_ACT_DEP_DATE'] = pd.to_datetime(df_flight_info['GMT_ACT_DEP_TS']).dt.date
df_flight_info['GMT_ACT_DEP_TIME'] = pd.to_datetime(df_flight_info['GMT_ACT_DEP_TS']).dt.time

# Remove timestaps due to redundancy
df_flight_info = df_flight_info.drop(columns= ['GMT_PLND_DEP_TS','GMT_ACT_DEP_TS'])

# %%
# Check
headers_and_first_row(df_flight_info)
# Out:
# {'OPG_ALN_CD': 'BA',
#  'OPG_FLT_NO': 548,
#  'ACT_DEP_STN_CD': 'LHR',
#  'ACT_DEP_TML_CD': '5',
#  'PLND_ARR_STN_CD': 'FCO',
#  'ACT_ARR_STN_CD': 'FCO',
#  'IATA_AC_TYP_CD': '321',
#  'ACT_AC_TYP_CD': 'V6',
#  'ROUTE': 'LHRFCO',
#  'COUNTRY_CD': 'IT',
#  'COUNTRY_NM': 'Italy',
#  'CORP_GEOG_CTRY_GRP_NM': 'MEDITERRANEAN',
#  'CORP_GEOG_CONTINENT_NM': 'EUROPE EXC UK',
#  'GMT_PLND_DEP_DATE': datetime.date(2019, 6, 3),
#  'GMT_PLND_DEP_TIME': datetime.time(7, 30),
#  'GMT_ACT_DEP_DATE': datetime.date(2019, 6, 3),
#  'GMT_ACT_DEP_TIME': datetime.time(7, 27)}

# %%
# Update
tables = [df_lounge_eligibility,df_flight_info,df_country,df_acft_typ]

[headers_and_first_row(t) for t in tables]
# Out:
# [{'Skew_Id': '2019-08-101414',
#   'OPERATING_AIRLINE_CD': 'BA',
#   'OPERATING_FLT_NO': 1414,
#   'GMT_UPLIFT_DT': datetime.date(2019, 8, 10),
#   'UPLIFT_STN_CD': 'LHR',
#   'DISCHARGE_STN_CD': 'BHD',
#   'BOOKED_CABIN_CD': 'M',
#   'TRAVEL_CABIN_CD': 'M',
#   'BA_PAX_TIER': 'Gold',
#   'ONEWORLD_TIER': 'EMER',
#   'Lounge_eligibility_tier': 'Tier 2',
#   'pax': 3},
#  {'OPG_ALN_CD': 'BA',
#   'OPG_FLT_NO': 548,
#   'ACT_DEP_STN_CD': 'LHR',
#   'ACT_DEP_TML_CD': '5',
#   'PLND_ARR_STN_CD': 'FCO',
#   'ACT_ARR_STN_CD': 'FCO',
#   'IATA_AC_TYP_CD': '321',
#   'ACT_AC_TYP_CD': 'V6',
#   'ROUTE': 'LHRFCO',
#   'COUNTRY_CD': 'IT',
#   'COUNTRY_NM': 'Italy',
#   'CORP_GEOG_CTRY_GRP_NM': 'MEDITERRANEAN',
#   'CORP_GEOG_CONTINENT_NM': 'EUROPE EXC UK',
#   'GMT_PLND_DEP_DATE': datetime.date(2019, 6, 3),
#   'GMT_PLND_DEP_TIME': datetime.time(7, 30),
#   'GMT_ACT_DEP_DATE': datetime.date(2019, 6, 3),
#   'GMT_ACT_DEP_TIME': datetime.time(7, 27)},
#  {'ROUTE': 'LHRINV',
#   'COUNTRY_CD': 'GB',
#   'COUNTRY_NM': 'United Kingdom and Northern Ireland',
#   'CORP_GEOG_CTRY_GRP_NM': 'UK',
#   'CORP_GEOG_CONTINENT_NM': 'UK'},
#  {'IATA_AC_TYP_CD': '320',
#   'ACT_AC_TYP_CD': 'A3',
#   'WB_NB_CAT': 'NB',
#   'FIRST_SEATS_QTY': 0,
#   'CLUB_SEATS_QTY': 24,
#   'PREM_ECONOMY_SEATS_QTY': 0,
#   'ECONOMY_SEATS_QTY': 132}]

# %% [markdown]
# <br>
# <div class="alert alert-" style = "border-radius:10px;border-width:3px;border-color:lightblue;font-family:Verdana,sans-serif;font-size:16px;">
#
# <font size="3">**Exercise 2:** Join the tables below
#
#     - df_flight_info
#     - df_country
#     - df_acft_typ
#
# to the table df_lounge_eligibility to generate a final dataset.
#
# </font>
#
# </ol>
# </div>

# %%
headers_and_first_row(df_lounge_eligibility), headers_and_first_row(df_flight_info)
# Out:
# ({'Skew_Id': '2019-08-101414',
#   'OPERATING_AIRLINE_CD': 'BA',
#   'OPERATING_FLT_NO': 1414,
#   'GMT_UPLIFT_DT': datetime.date(2019, 8, 10),
#   'UPLIFT_STN_CD': 'LHR',
#   'DISCHARGE_STN_CD': 'BHD',
#   'BOOKED_CABIN_CD': 'M',
#   'TRAVEL_CABIN_CD': 'M',
#   'BA_PAX_TIER': 'Gold',
#   'ONEWORLD_TIER': 'EMER',
#   'Lounge_eligibility_tier': 'Tier 2',
#   'pax': 3},
#  {'OPG_ALN_CD': 'BA',
#   'OPG_FLT_NO': 548,
#   'ACT_DEP_STN_CD': 'LHR',
#   'ACT_DEP_TML_CD': '5',
#   'PLND_ARR_STN_CD': 'FCO',
#   'ACT_ARR_STN_CD': 'FCO',
#   'IATA_AC_TYP_CD': '321',
#   'ACT_AC_TYP_CD': 'V6',
#   'ROUTE': 'LHRFCO',
#   'COUNTRY_CD': 'IT',
#   'COUNTRY_NM': 'Italy',
#   'CORP_GEOG_CTRY_GRP_NM': 'MEDITERRANEAN',
#   'CORP_GEOG_CONTINENT_NM': 'EUROPE EXC UK',
#   'GMT_PLND_DEP_DATE': datetime.date(2019, 6, 3),
#   'GMT_PLND_DEP_TIME': datetime.time(7, 30),
#   'GMT_ACT_DEP_DATE': datetime.date(2019, 6, 3),
#   'GMT_ACT_DEP_TIME': datetime.time(7, 27)})

# %% [markdown]
# Here are the equvilances between `df_lounge_eligibility` and `df_flight_info`:
# - `'OPERATING_AIRLINE_CD'` = `'OPG_ALN_CD'`
# - `'OPERATING_FLT_NO'` = `'OPG_FLT_NO'`
# - `'GMT_UPLIFT_DT'` = `'GMT_PLND_DEP_DATE'`
# - `'DISCHARGE_STN_CD'` = `'ACT_ARR_STN_CD'`

# %%
# Example

# joining df_lounge_eligibility and df_flight_info

df_lounge_elig_flight_info = pd.merge(df_lounge_eligibility,# left table
                                     df_flight_info, # right table
                                     left_on = ['OPERATING_AIRLINE_CD','OPERATING_FLT_NO','GMT_UPLIFT_DT','DISCHARGE_STN_CD'], # left on? e.g. which columns from the left table are you joining on to?
                                     right_on = ['OPG_ALN_CD','OPG_FLT_NO','GMT_PLND_DEP_DATE','ACT_ARR_STN_CD'] , # right on? # left on? e.g. which columns from the right table are you joining on to?
                                     how = "left" # how? e.g. left, right, inner,etc
                                     )

# df_lounge_elig_flight_info = df_lounge_elig_flight_info.drop_duplicates()

df_lounge_elig_flight_info.head(20)
# Out:
#            Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 0   2019-08-101414                   BA              1414    2019-08-10
# 1   2019-08-101414                   BA              1414    2019-08-10
# 2   2019-08-101414                   BA              1414    2019-08-10
# 3   2019-08-101414                   BA              1414    2019-08-10
# 4   2019-08-101414                   BA              1414    2019-08-10
# 5   2019-08-101414                   BA              1414    2019-08-10
# 6   2019-08-101414                   BA              1414    2019-08-10
# 7   2019-08-101414                   BA              1414    2019-08-10
# 8   2019-08-101414                   BA              1414    2019-08-10
# 9   2019-08-101414                   BA              1414    2019-08-10
# 10   2023-05-17920                   BA               920    2023-05-17
# 11   2023-05-17920                   BA               920    2023-05-17
# 12   2023-05-17920                   BA               920    2023-05-17
# 13   2023-05-17920                   BA               920    2023-05-17
# 14   2023-05-17920                   BA               920    2023-05-17
# 15   2019-04-15770                   BA               770    2019-04-15
# 16   2019-04-15770                   BA               770    2019-04-15
# 17   2019-04-15770                   BA               770    2019-04-15
# 18   2019-04-15770                   BA               770    2019-04-15
# 19   2019-04-15770                   BA               770    2019-04-15
#
#    UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD BA_PAX_TIER  \
# 0            LHR              BHD               M               M        Gold
# 1            LHR              BHD               M               M
# 2            LHR              BHD               C               C
# 3            LHR              BHD               M               M      Silver
# 4            LHR              BHD               C               C
# 5            LHR              BHD               C               C        Gold
# 6            LHR              BHD               C               M        Gold
# 7            LHR              BHD               C               C      Silver
# 8            LHR              BHD               C               C
# 9            LHR              BHD               M               M
# 10           LHR              STR               C               C
# 11           LHR              STR               M               M
# 12           LHR              STR               M               M        Gold
# 13           LHR              STR               M               M      Silver
# 14           LHR              STR               M               M
# 15           LHR              OSL               M               M
# 16           LHR              OSL               M               M        Gold
# 17           LHR              OSL               M               M      Silver
# 18           LHR              OSL               C               C        Gold
# 19           LHR              OSL               C               C      Silver
#
#    ONEWORLD_TIER Lounge_eligibility_tier  pax OPG_ALN_CD  OPG_FLT_NO  \
# 0           EMER                  Tier 2    3         BA        1414
# 1                           Not eligible  114         BA        1414
# 2           EMER                  Tier 2    3         BA        1414
# 3           SAPP                  Tier 3    7         BA        1414
# 4           SAPP                  Tier 3    1         BA        1414
# 5           EMER                  Tier 2    4         BA        1414
# 6           EMER                  Tier 2    1         BA        1414
# 7           SAPP                  Tier 3    4         BA        1414
# 8                                 Tier 3   10         BA        1414
# 9           SAPP                  Tier 3    2         BA        1414
# 10                                Tier 3   13         BA         920
# 11          SAPP                  Tier 3    1         BA         920
# 12          EMER                  Tier 2    1         BA         920
# 13          SAPP                  Tier 3    1         BA         920
# 14                          Not eligible   72         BA         920
# 15                          Not eligible   75         BA         770
# 16          EMER                  Tier 2    1         BA         770
# 17          SAPP                  Tier 3    1         BA         770
# 18          EMER                  Tier 2    1         BA         770
# 19          SAPP                  Tier 3    2         BA         770
#
#    ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD  \
# 0             LHR              5             BHD            BHD
# 1             LHR              5             BHD            BHD
# 2             LHR              5             BHD            BHD
# 3             LHR              5             BHD            BHD
# 4             LHR              5             BHD            BHD
# 5             LHR              5             BHD            BHD
# 6             LHR              5             BHD            BHD
# 7             LHR              5             BHD            BHD
# 8             LHR              5             BHD            BHD
# 9             LHR              5             BHD            BHD
# 10            LHR              3             STR            STR
# 11            LHR              3             STR            STR
# 12            LHR              3             STR            STR
# 13            LHR              3             STR            STR
# 14            LHR              3             STR            STR
# 15            LHR              5             OSL            OSL
# 16            LHR              5             OSL            OSL
# 17            LHR              5             OSL            OSL
# 18            LHR              5             OSL            OSL
# 19            LHR              5             OSL            OSL
#
#    IATA_AC_TYP_CD ACT_AC_TYP_CD   ROUTE COUNTRY_CD  \
# 0             320            A3  LHRBHD         GB
# 1             320            A3  LHRBHD         GB
# 2             320            A3  LHRBHD         GB
# 3             320            A3  LHRBHD         GB
# 4             320            A3  LHRBHD         GB
# 5             320            A3  LHRBHD         GB
# 6             320            A3  LHRBHD         GB
# 7             320            A3  LHRBHD         GB
# 8             320            A3  LHRBHD         GB
# 9             320            A3  LHRBHD         GB
# 10            319            M4  LHRSTR         DE
# 11            319            M4  LHRSTR         DE
# 12            319            M4  LHRSTR         DE
# 13            319            M4  LHRSTR         DE
# 14            319            M4  LHRSTR         DE
# 15            32A            H3  LHROSL         NO
# 16            32A            H3  LHROSL         NO
# 17            32A            H3  LHROSL         NO
# 18            32A            H3  LHROSL         NO
# 19            32A            H3  LHROSL         NO
#
#                              COUNTRY_NM CORP_GEOG_CTRY_GRP_NM  \
# 0   United Kingdom and Northern Ireland                    UK
# 1   United Kingdom and Northern Ireland                    UK
# 2   United Kingdom and Northern Ireland                    UK
# 3   United Kingdom and Northern Ireland                    UK
# 4   United Kingdom and Northern Ireland                    UK
# 5   United Kingdom and Northern Ireland                    UK
# 6   United Kingdom and Northern Ireland                    UK
# 7   United Kingdom and Northern Ireland                    UK
# 8   United Kingdom and Northern Ireland                    UK
# 9   United Kingdom and Northern Ireland                    UK
# 10                              Germany           WEST EUROPE
# 11                              Germany           WEST EUROPE
# 12                              Germany           WEST EUROPE
# 13                              Germany           WEST EUROPE
# 14                              Germany           WEST EUROPE
# 15                               Norway           SCANDINAVIA
# 16                               Norway           SCANDINAVIA
# 17                               Norway           SCANDINAVIA
# 18                               Norway           SCANDINAVIA
# 19                               Norway           SCANDINAVIA
#
#    CORP_GEOG_CONTINENT_NM GMT_PLND_DEP_DATE GMT_PLND_DEP_TIME  \
# 0                      UK        2019-08-10          06:10:00
# 1                      UK        2019-08-10          06:10:00
# 2                      UK        2019-08-10          06:10:00
# 3                      UK        2019-08-10          06:10:00
# 4                      UK        2019-08-10          06:10:00
# 5                      UK        2019-08-10          06:10:00
# 6                      UK        2019-08-10          06:10:00
# 7                      UK        2019-08-10          06:10:00
# 8                      UK        2019-08-10          06:10:00
# 9                      UK        2019-08-10          06:10:00
# 10          EUROPE EXC UK        2023-05-17          16:35:00
# 11          EUROPE EXC UK        2023-05-17          16:35:00
# 12          EUROPE EXC UK        2023-05-17          16:35:00
# 13          EUROPE EXC UK        2023-05-17          16:35:00
# 14          EUROPE EXC UK        2023-05-17          16:35:00
# 15          EUROPE EXC UK        2019-04-15          18:25:00
# 16          EUROPE EXC UK        2019-04-15          18:25:00
# 17          EUROPE EXC UK        2019-04-15          18:25:00
# 18          EUROPE EXC UK        2019-04-15          18:25:00
# 19          EUROPE EXC UK        2019-04-15          18:25:00
#
#    GMT_ACT_DEP_DATE GMT_ACT_DEP_TIME
# 0        2019-08-10         06:11:00
# 1        2019-08-10         06:11:00
# 2        2019-08-10         06:11:00
# 3        2019-08-10         06:11:00
# 4        2019-08-10         06:11:00
# 5        2019-08-10         06:11:00
# 6        2019-08-10         06:11:00
# 7        2019-08-10         06:11:00
# 8        2019-08-10         06:11:00
# 9        2019-08-10         06:11:00
# 10       2023-05-17         16:43:00
# 11       2023-05-17         16:43:00
# 12       2023-05-17         16:43:00
# 13       2023-05-17         16:43:00
# 14       2023-05-17         16:43:00
# 15       2019-04-15         18:52:00
# 16       2019-04-15         18:52:00
# 17       2019-04-15         18:52:00
# 18       2019-04-15         18:52:00
# 19       2019-04-15         18:52:00

# %%
print(df_lounge_elig_flight_info.shape, df_lounge_eligibility.shape)
headers_and_first_row(df_lounge_elig_flight_info)
# Out:
# (1442285, 29) (1561588, 12)
# {'Skew_Id': '2019-08-101414',
#  'OPERATING_AIRLINE_CD': 'BA',
#  'OPERATING_FLT_NO': 1414,
#  'GMT_UPLIFT_DT': datetime.date(2019, 8, 10),
#  'UPLIFT_STN_CD': 'LHR',
#  'DISCHARGE_STN_CD': 'BHD',
#  'BOOKED_CABIN_CD': 'M',
#  'TRAVEL_CABIN_CD': 'M',
#  'BA_PAX_TIER': 'Gold',
#  'ONEWORLD_TIER': 'EMER',
#  'Lounge_eligibility_tier': 'Tier 2',
#  'pax': 3,
#  'OPG_ALN_CD': 'BA',
#  'OPG_FLT_NO': 1414,
#  'ACT_DEP_STN_CD': 'LHR',
#  'ACT_DEP_TML_CD': '5',
#  'PLND_ARR_STN_CD': 'BHD',
#  'ACT_ARR_STN_CD': 'BHD',
#  'IATA_AC_TYP_CD': '320',
#  'ACT_AC_TYP_CD': 'A3',
#  'ROUTE': 'LHRBHD',
#  'COUNTRY_CD': 'GB',
#  'COUNTRY_NM': 'United Kingdom and Northern Ireland',
#  'CORP_GEOG_CTRY_GRP_NM': 'UK',
#  'CORP_GEOG_CONTINENT_NM': 'UK',
#  'GMT_PLND_DEP_DATE': datetime.date(2019, 8, 10),
#  'GMT_PLND_DEP_TIME': datetime.time(6, 10),
#  'GMT_ACT_DEP_DATE': datetime.date(2019, 8, 10),
#  'GMT_ACT_DEP_TIME': datetime.time(6, 11)}

# %% [markdown]
# Merge `df_country`

# %%
# Check dataframe
headers_and_first_row(df_lounge_elig_flight_info), headers_and_first_row(df_country)
# Out:
# ({'Skew_Id': '2019-08-101414',
#   'OPERATING_AIRLINE_CD': 'BA',
#   'OPERATING_FLT_NO': 1414,
#   'GMT_UPLIFT_DT': datetime.date(2019, 8, 10),
#   'UPLIFT_STN_CD': 'LHR',
#   'DISCHARGE_STN_CD': 'BHD',
#   'BOOKED_CABIN_CD': 'M',
#   'TRAVEL_CABIN_CD': 'M',
#   'BA_PAX_TIER': 'Gold',
#   'ONEWORLD_TIER': 'EMER',
#   'Lounge_eligibility_tier': 'Tier 2',
#   'pax': 3,
#   'OPG_ALN_CD': 'BA',
#   'OPG_FLT_NO': 1414,
#   'ACT_DEP_STN_CD': 'LHR',
#   'ACT_DEP_TML_CD': '5',
#   'PLND_ARR_STN_CD': 'BHD',
#   'ACT_ARR_STN_CD': 'BHD',
#   'IATA_AC_TYP_CD': '320',
#   'ACT_AC_TYP_CD': 'A3',
#   'ROUTE': 'LHRBHD',
#   'COUNTRY_CD': 'GB',
#   'COUNTRY_NM': 'United Kingdom and Northern Ireland',
#   'CORP_GEOG_CTRY_GRP_NM': 'UK',
#   'CORP_GEOG_CONTINENT_NM': 'UK',
#   'GMT_PLND_DEP_DATE': datetime.date(2019, 8, 10),
#   'GMT_PLND_DEP_TIME': datetime.time(6, 10),
#   'GMT_ACT_DEP_DATE': datetime.date(2019, 8, 10),
#   'GMT_ACT_DEP_TIME': datetime.time(6, 11)},
#  {'ROUTE': 'LHRINV',
#   'COUNTRY_CD': 'GB',
#   'COUNTRY_NM': 'United Kingdom and Northern Ireland',
#   'CORP_GEOG_CTRY_GRP_NM': 'UK',
#   'CORP_GEOG_CONTINENT_NM': 'UK'})

# %% [markdown]
# Here we can see the links are: `'ROUTE'`=`'ROUTE'`

# %%
df_lounge_elig_flight_info_country = pd.merge(  df_lounge_elig_flight_info,
                                                df_country,
                                                left_on = ['ROUTE'],
                                                right_on = ['ROUTE'],
                                                how = "left")

df_lounge_elig_flight_info_country.head(20)
# Out:
#            Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 0   2019-08-101414                   BA              1414    2019-08-10
# 1   2019-08-101414                   BA              1414    2019-08-10
# 2   2019-08-101414                   BA              1414    2019-08-10
# 3   2019-08-101414                   BA              1414    2019-08-10
# 4   2019-08-101414                   BA              1414    2019-08-10
# 5   2019-08-101414                   BA              1414    2019-08-10
# 6   2019-08-101414                   BA              1414    2019-08-10
# 7   2019-08-101414                   BA              1414    2019-08-10
# 8   2019-08-101414                   BA              1414    2019-08-10
# 9   2019-08-101414                   BA              1414    2019-08-10
# 10   2023-05-17920                   BA               920    2023-05-17
# 11   2023-05-17920                   BA               920    2023-05-17
# 12   2023-05-17920                   BA               920    2023-05-17
# 13   2023-05-17920                   BA               920    2023-05-17
# 14   2023-05-17920                   BA               920    2023-05-17
# 15   2019-04-15770                   BA               770    2019-04-15
# 16   2019-04-15770                   BA               770    2019-04-15
# 17   2019-04-15770                   BA               770    2019-04-15
# 18   2019-04-15770                   BA               770    2019-04-15
# 19   2019-04-15770                   BA               770    2019-04-15
#
#    UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD BA_PAX_TIER  \
# 0            LHR              BHD               M               M        Gold
# 1            LHR              BHD               M               M
# 2            LHR              BHD               C               C
# 3            LHR              BHD               M               M      Silver
# 4            LHR              BHD               C               C
# 5            LHR              BHD               C               C        Gold
# 6            LHR              BHD               C               M        Gold
# 7            LHR              BHD               C               C      Silver
# 8            LHR              BHD               C               C
# 9            LHR              BHD               M               M
# 10           LHR              STR               C               C
# 11           LHR              STR               M               M
# 12           LHR              STR               M               M        Gold
# 13           LHR              STR               M               M      Silver
# 14           LHR              STR               M               M
# 15           LHR              OSL               M               M
# 16           LHR              OSL               M               M        Gold
# 17           LHR              OSL               M               M      Silver
# 18           LHR              OSL               C               C        Gold
# 19           LHR              OSL               C               C      Silver
#
#    ONEWORLD_TIER Lounge_eligibility_tier  pax OPG_ALN_CD  OPG_FLT_NO  \
# 0           EMER                  Tier 2    3         BA        1414
# 1                           Not eligible  114         BA        1414
# 2           EMER                  Tier 2    3         BA        1414
# 3           SAPP                  Tier 3    7         BA        1414
# 4           SAPP                  Tier 3    1         BA        1414
# 5           EMER                  Tier 2    4         BA        1414
# 6           EMER                  Tier 2    1         BA        1414
# 7           SAPP                  Tier 3    4         BA        1414
# 8                                 Tier 3   10         BA        1414
# 9           SAPP                  Tier 3    2         BA        1414
# 10                                Tier 3   13         BA         920
# 11          SAPP                  Tier 3    1         BA         920
# 12          EMER                  Tier 2    1         BA         920
# 13          SAPP                  Tier 3    1         BA         920
# 14                          Not eligible   72         BA         920
# 15                          Not eligible   75         BA         770
# 16          EMER                  Tier 2    1         BA         770
# 17          SAPP                  Tier 3    1         BA         770
# 18          EMER                  Tier 2    1         BA         770
# 19          SAPP                  Tier 3    2         BA         770
#
#    ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD  \
# 0             LHR              5             BHD            BHD
# 1             LHR              5             BHD            BHD
# 2             LHR              5             BHD            BHD
# 3             LHR              5             BHD            BHD
# 4             LHR              5             BHD            BHD
# 5             LHR              5             BHD            BHD
# 6             LHR              5             BHD            BHD
# 7             LHR              5             BHD            BHD
# 8             LHR              5             BHD            BHD
# 9             LHR              5             BHD            BHD
# 10            LHR              3             STR            STR
# 11            LHR              3             STR            STR
# 12            LHR              3             STR            STR
# 13            LHR              3             STR            STR
# 14            LHR              3             STR            STR
# 15            LHR              5             OSL            OSL
# 16            LHR              5             OSL            OSL
# 17            LHR              5             OSL            OSL
# 18            LHR              5             OSL            OSL
# 19            LHR              5             OSL            OSL
#
#    IATA_AC_TYP_CD ACT_AC_TYP_CD   ROUTE COUNTRY_CD_x  \
# 0             320            A3  LHRBHD           GB
# 1             320            A3  LHRBHD           GB
# 2             320            A3  LHRBHD           GB
# 3             320            A3  LHRBHD           GB
# 4             320            A3  LHRBHD           GB
# 5             320            A3  LHRBHD           GB
# 6             320            A3  LHRBHD           GB
# 7             320            A3  LHRBHD           GB
# 8             320            A3  LHRBHD           GB
# 9             320            A3  LHRBHD           GB
# 10            319            M4  LHRSTR           DE
# 11            319            M4  LHRSTR           DE
# 12            319            M4  LHRSTR           DE
# 13            319            M4  LHRSTR           DE
# 14            319            M4  LHRSTR           DE
# 15            32A            H3  LHROSL           NO
# 16            32A            H3  LHROSL           NO
# 17            32A            H3  LHROSL           NO
# 18            32A            H3  LHROSL           NO
# 19            32A            H3  LHROSL           NO
#
#                            COUNTRY_NM_x CORP_GEOG_CTRY_GRP_NM_x  \
# 0   United Kingdom and Northern Ireland                      UK
# 1   United Kingdom and Northern Ireland                      UK
# 2   United Kingdom and Northern Ireland                      UK
# 3   United Kingdom and Northern Ireland                      UK
# 4   United Kingdom and Northern Ireland                      UK
# 5   United Kingdom and Northern Ireland                      UK
# 6   United Kingdom and Northern Ireland                      UK
# 7   United Kingdom and Northern Ireland                      UK
# 8   United Kingdom and Northern Ireland                      UK
# 9   United Kingdom and Northern Ireland                      UK
# 10                              Germany             WEST EUROPE
# 11                              Germany             WEST EUROPE
# 12                              Germany             WEST EUROPE
# 13                              Germany             WEST EUROPE
# 14                              Germany             WEST EUROPE
# 15                               Norway             SCANDINAVIA
# 16                               Norway             SCANDINAVIA
# 17                               Norway             SCANDINAVIA
# 18                               Norway             SCANDINAVIA
# 19                               Norway             SCANDINAVIA
#
#    CORP_GEOG_CONTINENT_NM_x GMT_PLND_DEP_DATE GMT_PLND_DEP_TIME  \
# 0                        UK        2019-08-10          06:10:00
# 1                        UK        2019-08-10          06:10:00
# 2                        UK        2019-08-10          06:10:00
# 3                        UK        2019-08-10          06:10:00
# 4                        UK        2019-08-10          06:10:00
# 5                        UK        2019-08-10          06:10:00
# 6                        UK        2019-08-10          06:10:00
# 7                        UK        2019-08-10          06:10:00
# 8                        UK        2019-08-10          06:10:00
# 9                        UK        2019-08-10          06:10:00
# 10            EUROPE EXC UK        2023-05-17          16:35:00
# 11            EUROPE EXC UK        2023-05-17          16:35:00
# 12            EUROPE EXC UK        2023-05-17          16:35:00
# 13            EUROPE EXC UK        2023-05-17          16:35:00
# 14            EUROPE EXC UK        2023-05-17          16:35:00
# 15            EUROPE EXC UK        2019-04-15          18:25:00
# 16            EUROPE EXC UK        2019-04-15          18:25:00
# 17            EUROPE EXC UK        2019-04-15          18:25:00
# 18            EUROPE EXC UK        2019-04-15          18:25:00
# 19            EUROPE EXC UK        2019-04-15          18:25:00
#
#    GMT_ACT_DEP_DATE GMT_ACT_DEP_TIME COUNTRY_CD_y  \
# 0        2019-08-10         06:11:00           GB
# 1        2019-08-10         06:11:00           GB
# 2        2019-08-10         06:11:00           GB
# 3        2019-08-10         06:11:00           GB
# 4        2019-08-10         06:11:00           GB
# 5        2019-08-10         06:11:00           GB
# 6        2019-08-10         06:11:00           GB
# 7        2019-08-10         06:11:00           GB
# 8        2019-08-10         06:11:00           GB
# 9        2019-08-10         06:11:00           GB
# 10       2023-05-17         16:43:00           DE
# 11       2023-05-17         16:43:00           DE
# 12       2023-05-17         16:43:00           DE
# 13       2023-05-17         16:43:00           DE
# 14       2023-05-17         16:43:00           DE
# 15       2019-04-15         18:52:00           NO
# 16       2019-04-15         18:52:00           NO
# 17       2019-04-15         18:52:00           NO
# 18       2019-04-15         18:52:00           NO
# 19       2019-04-15         18:52:00           NO
#
#                            COUNTRY_NM_y CORP_GEOG_CTRY_GRP_NM_y  \
# 0   United Kingdom and Northern Ireland                      UK
# 1   United Kingdom and Northern Ireland                      UK
# 2   United Kingdom and Northern Ireland                      UK
# 3   United Kingdom and Northern Ireland                      UK
# 4   United Kingdom and Northern Ireland                      UK
# 5   United Kingdom and Northern Ireland                      UK
# 6   United Kingdom and Northern Ireland                      UK
# 7   United Kingdom and Northern Ireland                      UK
# 8   United Kingdom and Northern Ireland                      UK
# 9   United Kingdom and Northern Ireland                      UK
# 10                              Germany             WEST EUROPE
# 11                              Germany             WEST EUROPE
# 12                              Germany             WEST EUROPE
# 13                              Germany             WEST EUROPE
# 14                              Germany             WEST EUROPE
# 15                               Norway             SCANDINAVIA
# 16                               Norway             SCANDINAVIA
# 17                               Norway             SCANDINAVIA
# 18                               Norway             SCANDINAVIA
# 19                               Norway             SCANDINAVIA
#
#    CORP_GEOG_CONTINENT_NM_y
# 0                        UK
# 1                        UK
# 2                        UK
# 3                        UK
# 4                        UK
# 5                        UK
# 6                        UK
# 7                        UK
# 8                        UK
# 9                        UK
# 10            EUROPE EXC UK
# 11            EUROPE EXC UK
# 12            EUROPE EXC UK
# 13            EUROPE EXC UK
# 14            EUROPE EXC UK
# 15            EUROPE EXC UK
# 16            EUROPE EXC UK
# 17            EUROPE EXC UK
# 18            EUROPE EXC UK
# 19            EUROPE EXC UK

# %%
df_lounge_elig_flight_info_country.shape, df_lounge_elig_flight_info.shape
# Out:
# ((1442285, 33), (1442285, 29))

# %% [markdown]
# Merge `df_acft_typ`

# %%
headers_and_first_row(df_lounge_elig_flight_info_country), headers_and_first_row(df_acft_typ)
# Out:
# ({'Skew_Id': '2019-08-101414',
#   'OPERATING_AIRLINE_CD': 'BA',
#   'OPERATING_FLT_NO': 1414,
#   'GMT_UPLIFT_DT': datetime.date(2019, 8, 10),
#   'UPLIFT_STN_CD': 'LHR',
#   'DISCHARGE_STN_CD': 'BHD',
#   'BOOKED_CABIN_CD': 'M',
#   'TRAVEL_CABIN_CD': 'M',
#   'BA_PAX_TIER': 'Gold',
#   'ONEWORLD_TIER': 'EMER',
#   'Lounge_eligibility_tier': 'Tier 2',
#   'pax': 3,
#   'OPG_ALN_CD': 'BA',
#   'OPG_FLT_NO': 1414,
#   'ACT_DEP_STN_CD': 'LHR',
#   'ACT_DEP_TML_CD': '5',
#   'PLND_ARR_STN_CD': 'BHD',
#   'ACT_ARR_STN_CD': 'BHD',
#   'IATA_AC_TYP_CD': '320',
#   'ACT_AC_TYP_CD': 'A3',
#   'ROUTE': 'LHRBHD',
#   'COUNTRY_CD_x': 'GB',
#   'COUNTRY_NM_x': 'United Kingdom and Northern Ireland',
#   'CORP_GEOG_CTRY_GRP_NM_x': 'UK',
#   'CORP_GEOG_CONTINENT_NM_x': 'UK',
#   'GMT_PLND_DEP_DATE': datetime.date(2019, 8, 10),
#   'GMT_PLND_DEP_TIME': datetime.time(6, 10),
#   'GMT_ACT_DEP_DATE': datetime.date(2019, 8, 10),
#   'GMT_ACT_DEP_TIME': datetime.time(6, 11),
#   'COUNTRY_CD_y': 'GB',
#   'COUNTRY_NM_y': 'United Kingdom and Northern Ireland',
#   'CORP_GEOG_CTRY_GRP_NM_y': 'UK',
#   'CORP_GEOG_CONTINENT_NM_y': 'UK'},
#  {'IATA_AC_TYP_CD': '320',
#   'ACT_AC_TYP_CD': 'A3',
#   'WB_NB_CAT': 'NB',
#   'FIRST_SEATS_QTY': 0,
#   'CLUB_SEATS_QTY': 24,
#   'PREM_ECONOMY_SEATS_QTY': 0,
#   'ECONOMY_SEATS_QTY': 132})

# %% [markdown]
# The lnks are: `'IATA_AC_TYP_CD','ACT_AC_TYP_CD'` = `'IATA_AC_TYP_CD','ACT_AC_TYP_CD'`

# %%
df_lounge_elig_flight_info_country_acft_typ = pd.merge(   df_lounge_elig_flight_info_country,
                                    df_acft_typ,
                                    left_on = ['IATA_AC_TYP_CD','ACT_AC_TYP_CD'],
                                    right_on = ['IATA_AC_TYP_CD','ACT_AC_TYP_CD'],
                                    how = "left")

df_lounge_elig_flight_info_country_acft_typ.head(20)
# Out:
#            Skew_Id OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT  \
# 0   2019-08-101414                   BA              1414    2019-08-10
# 1   2019-08-101414                   BA              1414    2019-08-10
# 2   2019-08-101414                   BA              1414    2019-08-10
# 3   2019-08-101414                   BA              1414    2019-08-10
# 4   2019-08-101414                   BA              1414    2019-08-10
# 5   2019-08-101414                   BA              1414    2019-08-10
# 6   2019-08-101414                   BA              1414    2019-08-10
# 7   2019-08-101414                   BA              1414    2019-08-10
# 8   2019-08-101414                   BA              1414    2019-08-10
# 9   2019-08-101414                   BA              1414    2019-08-10
# 10   2023-05-17920                   BA               920    2023-05-17
# 11   2023-05-17920                   BA               920    2023-05-17
# 12   2023-05-17920                   BA               920    2023-05-17
# 13   2023-05-17920                   BA               920    2023-05-17
# 14   2023-05-17920                   BA               920    2023-05-17
# 15   2019-04-15770                   BA               770    2019-04-15
# 16   2019-04-15770                   BA               770    2019-04-15
# 17   2019-04-15770                   BA               770    2019-04-15
# 18   2019-04-15770                   BA               770    2019-04-15
# 19   2019-04-15770                   BA               770    2019-04-15
#
#    UPLIFT_STN_CD DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD BA_PAX_TIER  \
# 0            LHR              BHD               M               M        Gold
# 1            LHR              BHD               M               M
# 2            LHR              BHD               C               C
# 3            LHR              BHD               M               M      Silver
# 4            LHR              BHD               C               C
# 5            LHR              BHD               C               C        Gold
# 6            LHR              BHD               C               M        Gold
# 7            LHR              BHD               C               C      Silver
# 8            LHR              BHD               C               C
# 9            LHR              BHD               M               M
# 10           LHR              STR               C               C
# 11           LHR              STR               M               M
# 12           LHR              STR               M               M        Gold
# 13           LHR              STR               M               M      Silver
# 14           LHR              STR               M               M
# 15           LHR              OSL               M               M
# 16           LHR              OSL               M               M        Gold
# 17           LHR              OSL               M               M      Silver
# 18           LHR              OSL               C               C        Gold
# 19           LHR              OSL               C               C      Silver
#
#    ONEWORLD_TIER Lounge_eligibility_tier  pax OPG_ALN_CD  OPG_FLT_NO  \
# 0           EMER                  Tier 2    3         BA        1414
# 1                           Not eligible  114         BA        1414
# 2           EMER                  Tier 2    3         BA        1414
# 3           SAPP                  Tier 3    7         BA        1414
# 4           SAPP                  Tier 3    1         BA        1414
# 5           EMER                  Tier 2    4         BA        1414
# 6           EMER                  Tier 2    1         BA        1414
# 7           SAPP                  Tier 3    4         BA        1414
# 8                                 Tier 3   10         BA        1414
# 9           SAPP                  Tier 3    2         BA        1414
# 10                                Tier 3   13         BA         920
# 11          SAPP                  Tier 3    1         BA         920
# 12          EMER                  Tier 2    1         BA         920
# 13          SAPP                  Tier 3    1         BA         920
# 14                          Not eligible   72         BA         920
# 15                          Not eligible   75         BA         770
# 16          EMER                  Tier 2    1         BA         770
# 17          SAPP                  Tier 3    1         BA         770
# 18          EMER                  Tier 2    1         BA         770
# 19          SAPP                  Tier 3    2         BA         770
#
#    ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD ACT_ARR_STN_CD  \
# 0             LHR              5             BHD            BHD
# 1             LHR              5             BHD            BHD
# 2             LHR              5             BHD            BHD
# 3             LHR              5             BHD            BHD
# 4             LHR              5             BHD            BHD
# 5             LHR              5             BHD            BHD
# 6             LHR              5             BHD            BHD
# 7             LHR              5             BHD            BHD
# 8             LHR              5             BHD            BHD
# 9             LHR              5             BHD            BHD
# 10            LHR              3             STR            STR
# 11            LHR              3             STR            STR
# 12            LHR              3             STR            STR
# 13            LHR              3             STR            STR
# 14            LHR              3             STR            STR
# 15            LHR              5             OSL            OSL
# 16            LHR              5             OSL            OSL
# 17            LHR              5             OSL            OSL
# 18            LHR              5             OSL            OSL
# 19            LHR              5             OSL            OSL
#
#    IATA_AC_TYP_CD ACT_AC_TYP_CD   ROUTE COUNTRY_CD_x  \
# 0             320            A3  LHRBHD           GB
# 1             320            A3  LHRBHD           GB
# 2             320            A3  LHRBHD           GB
# 3             320            A3  LHRBHD           GB
# 4             320            A3  LHRBHD           GB
# 5             320            A3  LHRBHD           GB
# 6             320            A3  LHRBHD           GB
# 7             320            A3  LHRBHD           GB
# 8             320            A3  LHRBHD           GB
# 9             320            A3  LHRBHD           GB
# 10            319            M4  LHRSTR           DE
# 11            319            M4  LHRSTR           DE
# 12            319            M4  LHRSTR           DE
# 13            319            M4  LHRSTR           DE
# 14            319            M4  LHRSTR           DE
# 15            32A            H3  LHROSL           NO
# 16            32A            H3  LHROSL           NO
# 17            32A            H3  LHROSL           NO
# 18            32A            H3  LHROSL           NO
# 19            32A            H3  LHROSL           NO
#
#                            COUNTRY_NM_x CORP_GEOG_CTRY_GRP_NM_x  \
# 0   United Kingdom and Northern Ireland                      UK
# 1   United Kingdom and Northern Ireland                      UK
# 2   United Kingdom and Northern Ireland                      UK
# 3   United Kingdom and Northern Ireland                      UK
# 4   United Kingdom and Northern Ireland                      UK
# 5   United Kingdom and Northern Ireland                      UK
# 6   United Kingdom and Northern Ireland                      UK
# 7   United Kingdom and Northern Ireland                      UK
# 8   United Kingdom and Northern Ireland                      UK
# 9   United Kingdom and Northern Ireland                      UK
# 10                              Germany             WEST EUROPE
# 11                              Germany             WEST EUROPE
# 12                              Germany             WEST EUROPE
# 13                              Germany             WEST EUROPE
# 14                              Germany             WEST EUROPE
# 15                               Norway             SCANDINAVIA
# 16                               Norway             SCANDINAVIA
# 17                               Norway             SCANDINAVIA
# 18                               Norway             SCANDINAVIA
# 19                               Norway             SCANDINAVIA
#
#    CORP_GEOG_CONTINENT_NM_x GMT_PLND_DEP_DATE GMT_PLND_DEP_TIME  \
# 0                        UK        2019-08-10          06:10:00
# 1                        UK        2019-08-10          06:10:00
# 2                        UK        2019-08-10          06:10:00
# 3                        UK        2019-08-10          06:10:00
# 4                        UK        2019-08-10          06:10:00
# 5                        UK        2019-08-10          06:10:00
# 6                        UK        2019-08-10          06:10:00
# 7                        UK        2019-08-10          06:10:00
# 8                        UK        2019-08-10          06:10:00
# 9                        UK        2019-08-10          06:10:00
# 10            EUROPE EXC UK        2023-05-17          16:35:00
# 11            EUROPE EXC UK        2023-05-17          16:35:00
# 12            EUROPE EXC UK        2023-05-17          16:35:00
# 13            EUROPE EXC UK        2023-05-17          16:35:00
# 14            EUROPE EXC UK        2023-05-17          16:35:00
# 15            EUROPE EXC UK        2019-04-15          18:25:00
# 16            EUROPE EXC UK        2019-04-15          18:25:00
# 17            EUROPE EXC UK        2019-04-15          18:25:00
# 18            EUROPE EXC UK        2019-04-15          18:25:00
# 19            EUROPE EXC UK        2019-04-15          18:25:00
#
#    GMT_ACT_DEP_DATE GMT_ACT_DEP_TIME COUNTRY_CD_y  \
# 0        2019-08-10         06:11:00           GB
# 1        2019-08-10         06:11:00           GB
# 2        2019-08-10         06:11:00           GB
# 3        2019-08-10         06:11:00           GB
# 4        2019-08-10         06:11:00           GB
# 5        2019-08-10         06:11:00           GB
# 6        2019-08-10         06:11:00           GB
# 7        2019-08-10         06:11:00           GB
# 8        2019-08-10         06:11:00           GB
# 9        2019-08-10         06:11:00           GB
# 10       2023-05-17         16:43:00           DE
# 11       2023-05-17         16:43:00           DE
# 12       2023-05-17         16:43:00           DE
# 13       2023-05-17         16:43:00           DE
# 14       2023-05-17         16:43:00           DE
# 15       2019-04-15         18:52:00           NO
# 16       2019-04-15         18:52:00           NO
# 17       2019-04-15         18:52:00           NO
# 18       2019-04-15         18:52:00           NO
# 19       2019-04-15         18:52:00           NO
#
#                            COUNTRY_NM_y CORP_GEOG_CTRY_GRP_NM_y  \
# 0   United Kingdom and Northern Ireland                      UK
# 1   United Kingdom and Northern Ireland                      UK
# 2   United Kingdom and Northern Ireland                      UK
# 3   United Kingdom and Northern Ireland                      UK
# 4   United Kingdom and Northern Ireland                      UK
# 5   United Kingdom and Northern Ireland                      UK
# 6   United Kingdom and Northern Ireland                      UK
# 7   United Kingdom and Northern Ireland                      UK
# 8   United Kingdom and Northern Ireland                      UK
# 9   United Kingdom and Northern Ireland                      UK
# 10                              Germany             WEST EUROPE
# 11                              Germany             WEST EUROPE
# 12                              Germany             WEST EUROPE
# 13                              Germany             WEST EUROPE
# 14                              Germany             WEST EUROPE
# 15                               Norway             SCANDINAVIA
# 16                               Norway             SCANDINAVIA
# 17                               Norway             SCANDINAVIA
# 18                               Norway             SCANDINAVIA
# 19                               Norway             SCANDINAVIA
#
#    CORP_GEOG_CONTINENT_NM_y WB_NB_CAT  FIRST_SEATS_QTY  CLUB_SEATS_QTY  \
# 0                        UK        NB              0.0            24.0
# 1                        UK        NB              0.0            24.0
# 2                        UK        NB              0.0            24.0
# 3                        UK        NB              0.0            24.0
# 4                        UK        NB              0.0            24.0
# 5                        UK        NB              0.0            24.0
# 6                        UK        NB              0.0            24.0
# 7                        UK        NB              0.0            24.0
# 8                        UK        NB              0.0            24.0
# 9                        UK        NB              0.0            24.0
# 10            EUROPE EXC UK       NaN              NaN             NaN
# 11            EUROPE EXC UK       NaN              NaN             NaN
# 12            EUROPE EXC UK       NaN              NaN             NaN
# 13            EUROPE EXC UK       NaN              NaN             NaN
# 14            EUROPE EXC UK       NaN              NaN             NaN
# 15            EUROPE EXC UK        NB              0.0            20.0
# 16            EUROPE EXC UK        NB              0.0            20.0
# 17            EUROPE EXC UK        NB              0.0            20.0
# 18            EUROPE EXC UK        NB              0.0            20.0
# 19            EUROPE EXC UK        NB              0.0            20.0
#
#     PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY
# 0                      0.0              132.0
# 1                      0.0              132.0
# 2                      0.0              132.0
# 3                      0.0              132.0
# 4                      0.0              132.0
# 5                      0.0              132.0
# 6                      0.0              132.0
# 7                      0.0              132.0
# 8                      0.0              132.0
# 9                      0.0              132.0
# 10                     NaN                NaN
# 11                     NaN                NaN
# 12                     NaN                NaN
# 13                     NaN                NaN
# 14                     NaN                NaN
# 15                     0.0              150.0
# 16                     0.0              150.0
# 17                     0.0              150.0
# 18                     0.0              150.0
# 19                     0.0              150.0

# %%
df_lounge_elig_flight_info_country.shape, df_lounge_elig_flight_info_country_acft_typ.shape
# Out:
# ((1442285, 33), (1442285, 38))

# %% [markdown]
# <br><br>
# <div class="alert alert-" style = "border-radius:10px;border-width:3px;border-color:lightblue;font-family:Verdana,sans-serif;font-size:16px;">
#
# <font size="3">Exercise 3: Based on S2019/S2023 data, provide a lookup table of Lounge eligibility assumptions that can be applied to a future schedule. To do so, answer each of the following questions in the Markdown cell provided below.
#
# - What level of granularity do you use?
# - What metric do you use to come up with Lounge eligibility profiles?
#
#
# Note 1: **Provide evidence for your assumptions.** This can be in the form of tables, graphs, correlation matrix, etc.
#
# Note 2: Make use of the examples below to give structure to your answer. Feel free to attend the Hackathon Clinics if you have any questions.
# </font>
#
#
#
# </ol>
# </div>

# %% [markdown]
# **Reasoning (Example 1)**:

# %% [markdown]
# Assume:
# - Data has been preprocessed.
# - Data has been joined, and a final dataset has been created. This dataset is the result of joining the 4 tables.
#
# The final dataset has been called `df_lounge_elig_flight_info_country_acft_typ`.

# %% [markdown]
# <u>What level of granularity do you use?</u>
# - I have decided to split all flights in the network based on their aircraft type. I will therefore have a lookup table with two categories: Narrowbody and Widebody.
#
# <u>What metric do you use to come up with Lounge eligibility profiles?</u>
# - I have sumed up all the passengers by Aircraft Type, by Tier. Then I have divided them by the total number of passengers by Aircraft Type. For example:
#     - For NB aircrafts, and for Tier 1 passengers: In S19 we had 41,728 pax eligible for Tier 1 out of 7,222,830 pax flying on Narrowbody aircraft. This represents 0.6% of the costumers and I assume that this will be the number of costumers elegible for this specific Lounge in a future schedule.

# %%
# your code here!

# %%
# columns that you want to group by
list_groupby = ['WB_NB_CAT','Lounge_eligibility_tier']

# grouping by WB_NB_CAT and Lounge_eligibility_tier
df_groupby_wb_nb = df_lounge_elig_flight_info_country_acft_typ.groupby(list_groupby).agg(
                pax_count = ('pax','sum')
).reset_index()

# %%
# a look at the data
df_groupby_wb_nb
# Out:
#   WB_NB_CAT Lounge_eligibility_tier  pax_count
# 0        NB            Not eligible    6997475
# 1        NB                  Tier 1      40874
# 2        NB                  Tier 2     551966
# 3        NB                  Tier 3    1604030
# 4        WB            Not eligible    4031646
# 5        WB                  Tier 1     194733
# 6        WB                  Tier 2     278606
# 7        WB                  Tier 3    1088483

# %%
# getting the number of pax by aircraft type

# columns that you want to group by
list_groupby = ['WB_NB_CAT']

# grouping by WB_NB_CAT
df_groupby_wb_nb_ttl = df_lounge_elig_flight_info_country_acft_typ.groupby(list_groupby).agg(
                pax_count_ttl = ('pax','sum')
).reset_index()

# %%
# a look at the data
df_groupby_wb_nb_ttl
# Out:
#   WB_NB_CAT  pax_count_ttl
# 0        NB        9194345
# 1        WB        5593468

# %%
# now, let's left join df_groupby_wb_nb_ttl onto df_groupby_wb_nb
# this adds a new column to the df_groupby_wb_nb table (pax_count_ttl) that will be used to get the percentage of passenger eligible by Tier

df_groupby_wb_nb = pd.merge(df_groupby_wb_nb,
                            df_groupby_wb_nb_ttl,
                            on = ['WB_NB_CAT'],
                            how = 'left'
                           )

# %%
# a look at the data
df_groupby_wb_nb
# Out:
#   WB_NB_CAT Lounge_eligibility_tier  pax_count  pax_count_ttl
# 0        NB            Not eligible    6997475        9194345
# 1        NB                  Tier 1      40874        9194345
# 2        NB                  Tier 2     551966        9194345
# 3        NB                  Tier 3    1604030        9194345
# 4        WB            Not eligible    4031646        5593468
# 5        WB                  Tier 1     194733        5593468
# 6        WB                  Tier 2     278606        5593468
# 7        WB                  Tier 3    1088483        5593468

# %%
# getting the percentage of pax elegible for each of the Tiers

df_groupby_wb_nb['pax_eligible%'] = (df_groupby_wb_nb['pax_count'] / df_groupby_wb_nb['pax_count_ttl'] )*100 

# getting the pax_elegible% column in the right format
df_groupby_wb_nb['pax_eligible%'] = df_groupby_wb_nb['pax_eligible%'].map('{:,.1f}%'.format)

# %%
# dropping pax_count, pax_count_ttl columns - not needed anymore
df_groupby_wb_nb.drop(columns=['pax_count','pax_count_ttl'],inplace = True)

# %%
# a look at the data
df_groupby_wb_nb
# Out:
#   WB_NB_CAT Lounge_eligibility_tier pax_eligible%
# 0        NB            Not eligible         76.1%
# 1        NB                  Tier 1          0.4%
# 2        NB                  Tier 2          6.0%
# 3        NB                  Tier 3         17.4%
# 4        WB            Not eligible         72.1%
# 5        WB                  Tier 1          3.5%
# 6        WB                  Tier 2          5.0%
# 7        WB                  Tier 3         19.5%

# %%
# dropping 'not eligible' rows - not needed anymore
mask = df_groupby_wb_nb['Lounge_eligibility_tier'] == 'Not eligible'

df_groupby_wb_nb = df_groupby_wb_nb[~mask].copy()

# %% [markdown]
# <br>
#
# Please save your final lookup table below in the form of a pandas dataframe. It must contain the categories you have come up with as rows, and the Tier 1, Tier 2, and Tier 3 percentage of costumers as columns.

# %%
# using set_index to come up with the final lookup table
df_groupby_wb_nb = df_groupby_wb_nb.set_index(['WB_NB_CAT','Lounge_eligibility_tier'],drop = True).unstack('Lounge_eligibility_tier')

# %%
# final table
df_groupby_wb_nb
# Out:
#                         pax_eligible%
# Lounge_eligibility_tier        Tier 1 Tier 2 Tier 3
# WB_NB_CAT
# NB                               0.4%   6.0%  17.4%
# WB                               3.5%   5.0%  19.5%

# %% [markdown]
# <br>
#
# **Feedback:** This analysis provides a lookup table in the format needed to be input into a future schedule. Nevertheless, this analysis is too high level and you haven't provided any evidence for your assumptions. To further enhance your answer use insights from the data and provide evidence for your assumptions. Please find some ideas below:
#
# - Using the same categories (WB,NB), plot data overtime to better understand the peaks for the different lounges.
# - Is there a way to split Widebody into more categories? Do the Haul, Region, Time of Day, or Country play a role in the number of passengers that are eligible in Tier 1, Tier 2 and Tier 3? Etc...

# %% [markdown]
# <br><br>
#
# **Reasoning (Example 2)**:

# %% [markdown]
# <u>What level of granularity do you use?</u>
# - I have decided to split all flights in the network based on their flight number. I will therefore have a lookup table with a lot of categories as each flight number is a category.
#
# <u>What metric do you use to come up with Lounge eligibility profiles?</u>
# - I have sumed up all the passengers by flight number, by Tier. Then I have divided them by the total number of passengers flight number.

# %%
# your code here!

# %%
# columns that you want to group by
list_groupby = ['OPERATING_FLT_NO','DISCHARGE_STN_CD','Lounge_eligibility_tier']

# grouping by OPERATING_FLT_NO, DISCHARGE_STN_CD and Lounge_eligibility_tier
df_groupby_flt_no = df_lounge_elig_flight_info_country_acft_typ.groupby(list_groupby).agg(
                pax_count = ('pax','sum')
).reset_index()

# a look at the data
df_groupby_flt_no.head(4)
# Out:
#    OPERATING_FLT_NO DISCHARGE_STN_CD Lounge_eligibility_tier  pax_count
# 0                 5              HND            Not eligible      13230
# 1                 5              HND                  Tier 1        110
# 2                 5              HND                  Tier 2        785
# 3                 5              HND                  Tier 3       3751

# %%
# getting the number of pax by OPERATING_FLT_NO and DISCHARGE_STN_CD

# columns that you want to group by
list_groupby = ['OPERATING_FLT_NO','DISCHARGE_STN_CD']

# grouping by WB_NB_CAT
df_groupby_flt_no_ttl = df_lounge_elig_flight_info_country_acft_typ.groupby(list_groupby).agg(
                pax_count_ttl = ('pax','sum')
).reset_index()

# %%
# a look at the data
df_groupby_flt_no_ttl.head(2)
# Out:
#    OPERATING_FLT_NO DISCHARGE_STN_CD  pax_count_ttl
# 0                 5              HND          17876
# 1                 5              NRT          38378

# %%
# now, let's left join df_groupby_flt_no_ttl onto df_groupby_flt_no
# this adds a new column to the df_groupby_flt_no table (pax_count_ttl) that will be used to get the percentage of passenger eligible by Tier

df_groupby_flt_no = pd.merge(df_groupby_flt_no,
                            df_groupby_flt_no_ttl,
                            on = ['OPERATING_FLT_NO','DISCHARGE_STN_CD'],
                            how = 'left'
                           )

# %%
# a look at the data
df_groupby_flt_no.head(4)
# Out:
#    OPERATING_FLT_NO DISCHARGE_STN_CD Lounge_eligibility_tier  pax_count  \
# 0                 5              HND            Not eligible      13230
# 1                 5              HND                  Tier 1        110
# 2                 5              HND                  Tier 2        785
# 3                 5              HND                  Tier 3       3751
#
#    pax_count_ttl
# 0          17876
# 1          17876
# 2          17876
# 3          17876

# %%
# getting the percentage of pax elegible for each of the Tiers

df_groupby_flt_no['pax_eligible%'] = (df_groupby_flt_no['pax_count'] / df_groupby_flt_no['pax_count_ttl'] )*100 

# getting the pax_elegible% column in the right format
df_groupby_flt_no['pax_eligible%'] = df_groupby_flt_no['pax_eligible%'].map('{:,.1f}%'.format)

# dropping pax_count, pax_count_ttl columns - not needed anymore
df_groupby_flt_no.drop(columns=['pax_count','pax_count_ttl'],inplace = True)

# %%
# a look at the data
df_groupby_flt_no.head(4)
# Out:
#    OPERATING_FLT_NO DISCHARGE_STN_CD Lounge_eligibility_tier pax_eligible%
# 0                 5              HND            Not eligible         74.0%
# 1                 5              HND                  Tier 1          0.6%
# 2                 5              HND                  Tier 2          4.4%
# 3                 5              HND                  Tier 3         21.0%

# %%
# dropping 'not eligible' rows - not needed anymore
mask = df_groupby_flt_no['Lounge_eligibility_tier'] == 'Not eligible'

df_groupby_flt_no = df_groupby_flt_no[~mask].copy()

# %% [markdown]
# <br>
#
# Please save your final lookup table below in the form of a pandas dataframe. It must contain the categories you have come up with as rows, and the Tier 1, Tier 2, and Tier 3 percentage of costumers as columns.

# %%
# using set_index to come up with the final lookup table
df_groupby_flt_no = df_groupby_flt_no.set_index(['OPERATING_FLT_NO','DISCHARGE_STN_CD','Lounge_eligibility_tier'],drop = True).unstack('Lounge_eligibility_tier')

# %%
# final table
df_groupby_flt_no.head(4)
# Out:
#                                   pax_eligible%
# Lounge_eligibility_tier                  Tier 1 Tier 2 Tier 3
# OPERATING_FLT_NO DISCHARGE_STN_CD
# 5                HND                       1.0%   4.1%  20.9%
#                  NRT                       3.6%   4.8%  19.1%
# 7                HND                       3.3%   5.2%  19.8%
# 9                BKK                       0.3%   4.2%  15.9%

# %% [markdown]
# <br>
#
# **Feedback:** This analysis goes at a very granular level, we might come up with missing values if we apply this lounge eligibility profiles to a future schedule. Here are some ideas to further enhance your answer:
#
# - What would happen if we fly to a new destination in the future? How do we ensure we have a lounge eligibility profile for this new route?
# - As you can see in the example above: Pax eligible for Tier 1 for the BKK flight is significantly different from the rest. What's the most used aircraft type for this route? And why it differs that much from the rest? Is it because of the route characteristics instead?
# - For SH routes, we might change the time of departure for a specific flight number from one year to the next. Explore the possibility of using a clasification that takes that into account, like using Time of Day instead of flight number.

# %% [markdown]
# <br><br><br>

# %%
#--------------------------------
#
# Your turn!!!
#
#--------------------------------

# %% [markdown]
# <u>What level of granularity do you use?</u>
# - ... (your answer here)
#
# <u>What metric do you use to come up with Lounge eligibility profiles?</u>
# - ... (your answer here)

# %%
# your code here

# %% [markdown]
# <br>
#
# Please save your final lookup table below in the form of a pandas dataframe. It must contain the categories you have come up with as rows, and the Tier 1, Tier 2, and Tier 3 percentage of costumers as columns.
